# %%
import pandas as pd
import numpy as np
import pickle
import re
from nltk import pos_tag
from nltk.corpus import stopwords
from collections import Counter
from itertools import chain
import warnings
warnings.filterwarnings('ignore')
import nltk
import time
#nltk.download('stopwords')

# %% [markdown]
# ### Notes on Prediction
# This notebook contains all the code necessary to predict NER topics on input queries using the saved NER model.

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(), 
                                                           s['POS'].values.tolist(), 
                                                           s['Tag'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True
    return features
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]
def sent2labels(sent):
    return [label for token, postag, label in sent]
def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
# Load saved NER model
filename = 'crf_ner_model.sav'

crf = pickle.load(open(filename, 'rb'))

# %%
# Prepare the input query by tagging for POS
def prep_query(phrase):
    split_query = re.findall(r"[\w']+|[.,!?;]", phrase)
    
    pos_tags = pos_tag(split_query)
    
    df_query = pd.DataFrame({'Sentence #':['Sentence: 1'] * len(pos_tags),
                            'Word':[pair[0] for pair in pos_tags],
                            'POS':[pair[1] for pair in pos_tags],
                            'Tag':[None] * len(pos_tags)})
       
    return df_query

# %%
# Try predicting on some sample queries
s = "Donald Trump is a former host on The Apprentice. He is an American businessman and former President."
s = 'hello how are you'
s = 'The Second World War started in 1914 and ended in 1918'
s = 'The Korean War started in 1939 and ended in 1945'
s = 'Iraq and Iran were once at war. Saddam Hussein was involved'
s = 'The World Cup is a quadrennial sporting event. FIFA is the governing body involved.'
s = 'Biden under pressure over Afghanistan and Covid as approval ratings slide'
s = 'But the Taliban warned on Monday there would be “consequences” if the US and its allies linger beyond that date.'
s = 'Thousands of American troops have poured back into the country to oversee the chaotic airlift of foreigners and \
selected Afghans from Kabul airport, and Biden is being called upon to extend a 31 August deadline for full US withdrawal'
s = 'As it leaves Afghanistan in chaos, America’s decline mirrors Britain’s a century ago. It may also invite wider \
conflict, warns a historian'
s = 'In March the joint study reported that it was “extremely unlikely” that the virus had been released in a laboratory \
accident. Dr Ben Embarek revealed that this conclusion did not come from a balanced assessment of all the relevant \
evidence but from a steadfast refusal by the Chinese members of the joint study to support anything stronger.'

x = prep_query(s)

# %%
def concat_ents(ents_list):
    all_named_ents = {}
    counter = 0
    counts = {}
      
    full_named_ent = ents_list[0][1]

    for i in range(1,len(ents_list) - 1):
        if ents_list[i][0][0] == 'I':
            full_named_ent = full_named_ent + ' ' + ents_list[i][1]
            if ents_list[i + 1][0][0] == 'B':
                if full_named_ent in all_named_ents.keys():
                    all_named_ents[full_named_ent] += 1
                    full_named_ent = ''
                else:
                    all_named_ents[full_named_ent] = 1
                    full_named_ent = ''
            else:
                continue
                full_named_ent = full_named_ent + ' ' + ents_list[i + 1][1]
                           
        elif ents_list[i][0][0] == 'B':
            full_named_ent = ents_list[i][1]
            if ents_list[i + 1][0][0] == 'B':
                if full_named_ent in all_named_ents.keys():
                    all_named_ents[full_named_ent] += 1
                    full_named_ent = ''
                else:
                    all_named_ents[full_named_ent] = 1
                    full_named_ent = '' 

    return all_named_ents

# %%
''' The output from the NER tagging is a collection of individual words with a "B" or "I" tag, depending on whether the 
word is at the beginning or interior of the named entity. This function puts each named entity together from its constituent 
words
'''
def concat_ents(ents_list):
    all_named_ents = {}
    counter = 0
    counts = {}
       
    full_named_ent = ents_list[0][1]

    for i in range(1,len(ents_list) - 1):
        if ents_list[i][0][0] == 'I':
            full_named_ent = full_named_ent + ' ' + ents_list[i][1] # State name
            if ents_list[i + 1][0][0] == 'B':              
                if full_named_ent + ents_list[i][0][1:] in all_named_ents.keys():
                    all_named_ents[full_named_ent+ ents_list[i][0][1:]] += 1            # Add
                    full_named_ent = ''
                else:
                    all_named_ents[full_named_ent+ ents_list[i][0][1:]] = 1             # Add
                    full_named_ent = ''
            else:
                continue
                full_named_ent = full_named_ent + ' ' + ents_list[i + 1][1]
                           
        elif ents_list[i][0][0] == 'B':
            full_named_ent = ents_list[i][1]
            if ents_list[i + 1][0][0] == 'B':
                if full_named_ent + ents_list[i][0][1:] in all_named_ents.keys():
                    all_named_ents[full_named_ent+ ents_list[i][0][1:]] += 1           # Add
                    full_named_ent = ''
                else:
                    all_named_ents[full_named_ent+ ents_list[i][0][1:]] = 1            # Add
                    full_named_ent = '' 
                              
    return all_named_ents

# %%
'''For each dictionary of NEs, add up the number of time each key (i.e. each word) appears'''

def get_totals(dicts):
    totals = {}
    for _dict in dicts:
        for key in _dict.keys():
            if key not in totals.keys():
                totals[key] = _dict[key]
            else:
                totals[key] += _dict[key]
    return totals

# %%
''' Extract the named entities from a given string. 
Return a list of NEs of the form: [('B-tim', 'March'),
                                   ('B-per', 'Dr'),
                                   ('I-per', 'Ben'),
                                   ('I-per', 'Embarek'),
                                   ('B-gpe', 'Chinese')]'''
def get_nes(string):
    x = prep_query(string)
    getter_query = SentenceGetter(x)
    sentences_query = getter_query.sentences

    X_query = [sent2features(s) for s in sentences_query]
    X_words = [s[0] for s in sentences_query[0]]
    
    # Obtain NEs from the prediction model
    pred = crf.predict(X_query)

    ents = list(zip(pred[0],X_words))
    # Leave behind anything not designated as a named entity
    named_ents = [pair for pair in ents if pair[0] != 'O']
    return named_ents

# %%
df_ht = pd.read_csv('GLG/models/14passes_265_topics_df_ht_lda.csv')
df_ht.head(1)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                 date  year  month  \
# 0           0             7               7  2018-05-02 17:09:00  2018    5.0
#
#    day             author                                             title  \
# 0    2  Caroline Williams  You Can Trick Your Brain Into Being More Focused
#
#                                              article  \
# 0  If only every day could be like this. You can’...
#
#                                                  url section publication  \
# 0  https://www.vice.com/en_us/article/9kgp4v/how-...  Health        Vice
#
#                                        article_words  lda_topic  \
# 0  ['every', 'day', 'could', 'like', 'put', 'fing...        257
#
#      other_topics
# 0  [61, 166, 227]

# %%
df_ht['lda_topic'].nunique()
# Out:
# 247

# %%
''' Here we create the dictionary of named entities from the LDA output. Ultimately each key will
be a topic number, and the value for that key will be a dict containing the most commonly 
occurring named entities in the training data for that topic. 
The goal that when an input query is found to belong to a particular LDA topic, those top named 
entities will be reported along with the topic name. '''

#8:21
start = time.time()
ner_dict = {}

for i in range(265):
    topic = i
    mini_df = df_ht[df_ht['lda_topic'] == topic]
    mini_df['named_ents'] = [get_nes(article) for article in mini_df['article']]
    #mini_df['counted_ents'] = [concat_ents(ents) for ents in mini_df['named_ents']]
    mini_df['counted_ents'] = [concat_ents(mini_df.loc[i,'named_ents']) if len(mini_df.loc[i,'named_ents']) > 0 else {} for i in mini_df.index]
    
    topic_ner_dict = get_totals([ents for ents in mini_df['counted_ents']])
    topic_ner_dict = {k: v for k, v in sorted(topic_ner_dict.items(), key=lambda item: item[1],reverse=True)}
    ner_dict[i] = topic_ner_dict
    
interval = round((time.time() - start)/60,1)
print(f'That took {interval} mins.')
# Out:
# That took 148.9 mins.

# %%
ner_dict_cleaned = ner_dict.copy()

# %%
''' Clean up the output: Filter out any NEs of length <= 2 charcters, with the exception of some
allowed NEs listed below. Remove some that are an artifact of the news reporting service.'''

allowed = ['US','BA','UK','GB','AP','BP','LG','EA','DA','IQ','HR','AA','TB',
           'VR','VC','UX','UV','XX','XY','QE','TV','AG','VW','UN','EU','AK','AS','AZ','AR','CA','CO','CT',
           'DE','DC','FL','GA','HI','ID','IL','IN','IA','KS','KY',
           'LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH',
           'NJ','NM','NY','NC','ND','MP','OH','OK','OR','PA','PR','RI',
           'SC','SD','TN','TX','UT','VT','VA','VI','WA','WV','WI','WY']

not_allowed = ['Reuters','VICE','Vice','The Wall Street Journal','WSJ',
              'Reuters Saudi Arabia','NYT','New York Times']

ent_types = ['gpe','org','per','geo']

ner_dict_stripped =  {}

for key in ner_dict_cleaned.keys():
    key_dict = {}
    
    # If length of NE < 7 (allowing for the '-geo' suffix) then remove
    # Unless NE belongs to the allowed list
    keys_to_delete = []
    for k in ner_dict_cleaned[key].keys():  
        if ((len(k) < 7) & (k[:2] not in allowed)) | (k[0].islower()):
            keys_to_delete.append(k)
    # Remove these keys from the dict    
    for k in keys_to_delete:
        del ner_dict_cleaned[key][k]

    # Strip NEs down to the top 5 only, in each category
    # and put in final stripped dict
    for ent_type in ent_types:
        mini_dict = {key:val for (key,val) in ner_dict_cleaned[key].items() if (key[-3:] == ent_type) & (key[:-4] not in not_allowed)}
        top_5_ent_names = list(mini_dict)[:5]
        top_5_ents = {key:val for (key,val) in mini_dict.items() if key in top_5_ent_names}
        key_dict.update(top_5_ents)
    ner_dict_stripped[key] = key_dict

# %%
#Example output from the NER determination
for item in ner_dict_stripped[1]:
    print(item)
# Out:
# American-gpe
# Chinese-gpe
# African-gpe
# German-gpe
# Americans-gpe
# Google-org
# University-org
# US-org
# CNN-org
# University of California-org
# Sendler-per
# Johnson-per
# Trump-per
# Redfield-per
# Harvard-per
# United States-geo
# China-geo
# New York-geo
# Washington-geo
# California-geo

# %%
ner_dict_stripped
# Out:
# {0: {},
#  1: {'American-gpe': 195,
#   'Chinese-gpe': 168,
#   'African-gpe': 71,
#   'German-gpe': 50,
#   'Americans-gpe': 45,
#   'Google-org': 300,
#   'University-org': 155,
#   'US-org': 151,
#   'CNN-org': 137,
#   'University of California-org': 123,
#   'Sendler-per': 88,
#   'Johnson-per': 73,
#   'Trump-per': 59,
#   'Redfield-per': 42,
#   'Harvard-per': 39,
#   'United States-geo': 232,
#   'China-geo': 177,
#   'New York-geo': 116,
#   'Washington-geo': 102,
#   'California-geo': 89},
#  2: {},
#  3: {'African-gpe': 144,
#   'British-gpe': 108,
#   'French-gpe': 86,
#   'German-gpe': 84,
#   'Chinese-gpe': 75,
#   'Nov-org': 79,
#   'Reuters A-org': 62,
#   'Reuters South Africa-org': 54,
#   'Google-org': 50,
#   'Eskom-org': 49,
#   'Noor Zainab Hussain-per': 69,
#   'Tanisha Heiberg-per': 29,
#   'Nikhil Kurian Nainan-per': 23,
#   'Alexander Cornwell-per': 23,
#   'Yadarisa Shabong-per': 22,
#   'Bengaluru-geo': 593,
#   'China-geo': 163,
#   'South Africa-geo': 113,
#   'Jan-geo': 97,
#   'United States-geo': 96},
#  4: {'Swiss-gpe': 403,
#   'Americans-gpe': 143,
#   'British-gpe': 119,
#   'Chinese-gpe': 118,
#   'Indian-gpe': 82,
#   'FDA-org': 2062,
#   'Food and Drug Administration-org': 694,
#   'Roche-org': 415,
#   'NDMA-org': 194,
#   'GSK-org': 185,
#   'Novartis-per': 482,
#   'Sanofi-per': 196,
#   'Pfizer-per': 183,
#   'John Miller-per': 171,
#   'Amgen-per': 118,
#   'United States-geo': 916,
#   'Bengaluru-geo': 542,
#   'Europe-geo': 360,
#   'China-geo': 329,
#   'Teva-geo': 271},
#  5: {'Japanese-gpe': 25,
#   'Chinese-gpe': 14,
#   'Korean-gpe': 7,
#   'Italian-gpe': 6,
#   'French-gpe': 6,
#   'CES-org': 72,
#   'Google-org': 59,
#   'CTA-org': 41,
#   'Pepper-org': 29,
#   'ABB-org': 18,
#   'Boston Dynamics-per': 62,
#   'Raibert-per': 25,
#   'Lora DiCarlo-per': 24,
#   'Amazon-per': 20,
#   'Marc Raibert-per': 11,
#   'Boston Dynamics-geo': 86,
#   'Spot-geo': 46,
#   'Atlas-geo': 41,
#   'Japan-geo': 40,
#   'Amazon-geo': 32},
#  6: {'Indian-gpe': 348,
#   'Malaysian-gpe': 27,
#   'Nepal-gpe': 22,
#   'Chinese-gpe': 17,
#   'Indians-gpe': 15,
#   'Apple-org': 86,
#   'NEW DELHI-org': 39,
#   'Reuters India-org': 38,
#   'Sankalp Phartiyal-org': 31,
#   'Supreme Court-org': 22,
#   'Prime Minister Narendra Modi-per': 61,
#   'Amazon-per': 24,
#   'Modi-per': 19,
#   'Vodafone Idea-per': 15,
#   'Sanjeev Miglani-per': 13,
#   'India-geo': 668,
#   'New Delhi-geo': 73,
#   'China-geo': 55,
#   'Modi-geo': 44,
#   'Amazon-geo': 44},
#  7: {'Canadian-gpe': 7,
#   'American-gpe': 5,
#   'Americans-gpe': 4,
#   'Vegetarian-gpe': 3,
#   'British-gpe': 2,
#   'FDA-org': 20,
#   'Impossible Foods-org': 15,
#   'Whopper-org': 11,
#   'Burger King-org': 11,
#   'USDA-org': 10,
#   'Beyond Meat-per': 102,
#   'Burger King-per': 48,
#   'Tyson-per': 20,
#   'Brown-per': 17,
#   'Impossible Burger-per': 15,
#   'United States-geo': 29,
#   'Beyond Meat-geo': 27,
#   'Missouri-geo': 20,
#   'Canada-geo': 17,
#   'Bengaluru-geo': 12},
#  8: {'American-gpe': 3,
#   'Chilean-gpe': 2,
#   'Fish-gpe': 1,
#   'Alaskan-gpe': 1,
#   'Americans-gpe': 1,
#   "UC Berkeley's Alternative Meats Lab-org": 2,
#   'NFI-org': 2,
#   'Reuters Chile-org': 1,
#   'SRS-org': 1,
#   'ISA-org': 1,
#   'Auerbach-per': 7,
#   'Jupiter-per': 5,
#   'Orobetz-per': 4,
#   'Lauren Jupiter-per': 2,
#   'Alpha Foods-per': 2,
#   'Red-geo': 7,
#   'Chile-geo': 3,
#   'Boston-geo': 3,
#   'Oceana-geo': 3,
#   'Sea-geo': 3},
#  9: {'Israeli-gpe': 10,
#   'Australian-gpe': 4,
#   'Japanese-gpe': 3,
#   'Chinese-gpe': 1,
#   'Elovitch-gpe': 1,
#   'TEL AVIV-org': 3,
#   'B Communications-org': 3,
#   'Tel Aviv-org': 3,
#   'Tel Aviv Stock Exchange-org': 3,
#   'Bezeq-org': 3,
#   'Asahi-per': 11,
#   'Twistlock-per': 4,
#   'Ari Rabinovitch-per': 4,
#   'Steven Scheer-per': 4,
#   'Bezeq-per': 4,
#   'Bezeq-geo': 17,
#   'Israel-geo': 14,
#   'Eurocom-geo': 4,
#   'Huawei-geo': 4,
#   'Asahi-geo': 4},
#  10: {'French-gpe': 55,
#   'Chinese-gpe': 30,
#   'German-gpe': 20,
#   'Indian-gpe': 15,
#   'American-gpe': 14,
#   'AT T-org': 138,
#   'Justice Department-org': 55,
#   'CNN-org': 47,
#   'NXP-org': 45,
#   'CBS-org': 45,
#   'Time Warner-per': 81,
#   'Qualcomm-per': 30,
#   'T Mobile-per': 21,
#   'Trump-per': 17,
#   'Stephenson-per': 15,
#   'Qualcomm-geo': 57,
#   'Broadcom-geo': 51,
#   'Viacom-geo': 43,
#   'Cigna-geo': 30,
#   'Comcast-geo': 27},
#  11: {'Ecuadorian-gpe': 12,
#   'British-gpe': 4,
#   'Julian-gpe': 2,
#   'American-gpe': 2,
#   'Harare-gpe': 1,
#   'Motherboard-org': 6,
#   'US-org': 5,
#   'Wikileaks-org': 3,
#   'UK-org': 3,
#   'United Nations High Commissioner for Human Rights-org': 2,
#   'Assange-per': 9,
#   'Love-per': 8,
#   'Crosby-per': 5,
#   'Motherboard-per': 3,
#   'Chelsea Manning-per': 3,
#   'Assange-geo': 20,
#   'Ecuador-geo': 9,
#   'London-geo': 8,
#   'United States-geo': 8,
#   'Ecuadorean-geo': 5},
#  12: {'Chinese-gpe': 16,
#   'British-gpe': 9,
#   'Americans-gpe': 8,
#   'American-gpe': 8,
#   'Greek-gpe': 5,
#   'Airbnb-org': 51,
#   'CNBC-org': 26,
#   'American Hotel and Lodging Association-org': 10,
#   'US-org': 9,
#   'Airbnb Plus-org': 8,
#   'Airbnb-per': 152,
#   'Chesky-per': 33,
#   'Brian Chesky-per': 22,
#   'Grewal-per': 13,
#   'Bishop-per': 9,
#   'Airbnb-geo': 458,
#   'San Francisco-geo': 45,
#   'New York-geo': 30,
#   'Paris-geo': 29,
#   'New York City-geo': 21},
#  13: {'Japanese-gpe': 42,
#   'Chinese-gpe': 38,
#   'French-gpe': 34,
#   'American-gpe': 26,
#   'German-gpe': 15,
#   'Apple-org': 3963,
#   'Microsoft-org': 1738,
#   'Google-org': 1195,
#   'USB C-org': 1023,
#   'Windows-org': 763,
#   'Mac-per': 1069,
#   'MacBook Pro-per': 543,
#   'Mac Pro-per': 293,
#   'Click-per': 279,
#   'Chrome OS-per': 242,
#   'Pro-geo': 901,
#   'Android-geo': 511,
#   'Samsung-geo': 422,
#   'Chrome-geo': 387,
#   'Amazon-geo': 334},
#  14: {'Chinese-gpe': 16,
#   'American-gpe': 9,
#   'Japanese-gpe': 9,
#   'Americans-gpe': 7,
#   'British-gpe': 5,
#   'Apple-org': 151,
#   'Sony-org': 63,
#   'Microsoft-org': 31,
#   'Google-org': 31,
#   'USB C-org': 28,
#   'Bose-per': 49,
#   'Beats-per': 17,
#   'Doppler-per': 16,
#   'Siri-per': 14,
#   'Doppler Labs-per': 12,
#   'Bluetooth-geo': 79,
#   'Beats-geo': 25,
#   'Amazon-geo': 22,
#   'Android-geo': 21,
#   'Spotify-geo': 18},
#  15: {'USGS-org': 15,
#   'Swift-org': 8,
#   'NPS-org': 8,
#   'DOI-org': 4,
#   'FOIA-org': 4,
#   'Fagre-per': 7,
#   'Motherboard-per': 6,
#   'Trump-per': 6,
#   'Dan Fagre-per': 3,
#   'Mains-per': 3,
#   'Fagre-geo': 8,
#   'Zuckerberg-geo': 3,
#   'Mains-geo': 2,
#   'Interior-geo': 2,
#   'Swift-geo': 2},
#  16: {'Russian-gpe': 3476,
#   'Chinese-gpe': 1467,
#   'Korean-gpe': 1403,
#   'Iranian-gpe': 914,
#   'Japanese-gpe': 801,
#   'White House-org': 917,
#   'NATO-org': 729,
#   'Reuters U-org': 545,
#   'Putin-org': 532,
#   'Kremlin-org': 487,
#   'Trump-per': 2813,
#   'President Donald Trump-per': 1349,
#   'President Vladimir Putin-per': 434,
#   'Kim-per': 333,
#   'Mike Pompeo-per': 286,
#   'United States-geo': 4481,
#   'Russia-geo': 3467,
#   'China-geo': 3348,
#   'Iran-geo': 2850,
#   'North Korea-geo': 2105},
#  17: {'Russian-gpe': 71,
#   'American-gpe': 43,
#   'Americans-gpe': 38,
#   'Chinese-gpe': 20,
#   'African-gpe': 16,
#   'Google-org': 1027,
#   'Facebook-org': 777,
#   'Snapchat-org': 169,
#   'CNBC-org': 169,
#   'Apple-org': 129,
#   'Facebook-per': 302,
#   'Amazon-per': 75,
#   'Snap-per': 64,
#   'Twitter-per': 56,
#   'Instant Articles-per': 43,
#   'Snap-geo': 221,
#   'Amazon-geo': 219,
#   'Instagram-geo': 183,
#   'Snapchat-geo': 153,
#   'United States-geo': 87},
#  18: {'Express Scripts-org': 8,
#   'Express Scripts CEO Tim Wentworth-org': 1,
#   'CNBC-org': 1,
#   'PBM-org': 1,
#   'CVS Health-org': 1,
#   'Anthem-per': 2,
#   'Closing Bell-per': 1,
#   'Carl Icahn-per': 1,
#   'Express Scripts-per': 1,
#   'David Faber-per': 1,
#   'Cigna-geo': 6,
#   'Anthem-geo': 4,
#   'Wentworth-geo': 3,
#   'Aug-geo': 1},
#  19: {'American-gpe': 42,
#   'Canadian-gpe': 39,
#   'Americans-gpe': 36,
#   'British-gpe': 19,
#   'French-gpe': 15,
#   'CBD-org': 1232,
#   'FDA-org': 613,
#   'THC-org': 598,
#   'DEA-org': 124,
#   'Food and Drug Administration-org': 70,
#   'Gottlieb-per': 41,
#   'Cannabis-per': 33,
#   'Scott Gottlieb-per': 26,
#   'Miller-per': 17,
#   'Giordano-per': 16,
#   'Colorado-geo': 122,
#   'California-geo': 119,
#   'United States-geo': 99,
#   'Canada-geo': 91,
#   'Marijuana-geo': 69},
#  20: {'Chinese-gpe': 143,
#   'American-gpe': 91,
#   'French-gpe': 72,
#   'Indian-gpe': 63,
#   'German-gpe': 59,
#   'Lyft-org': 1793,
#   'Uber-org': 1273,
#   'Uber and Lyft-org': 468,
#   'US-org': 323,
#   'Google-org': 214,
#   'Uber-per': 2331,
#   'Lime-per': 332,
#   'Khosrowshahi-per': 237,
#   'Bird-per': 172,
#   'Travis Kalanick-per': 136,
#   'San Francisco-geo': 887,
#   'London-geo': 623,
#   'New York City-geo': 413,
#   'Lyft-geo': 384,
#   'New York-geo': 361},
#  21: {},
#  22: {'French-gpe': 1,
#   'Apple-org': 46,
#   'USB C-org': 12,
#   'Apple Watch-org': 12,
#   'Google-org': 8,
#   'PMA-org': 7,
#   'Mophie-per': 11,
#   'Samsung-per': 6,
#   'Starbucks-per': 3,
#   'Dickson-per': 3,
#   'Quick Charge-per': 2,
#   'Samsung-geo': 10,
#   'Belkin-geo': 4,
#   'Tesla-geo': 3,
#   'Qualcomm-geo': 3,
#   'Android-geo': 2},
#  23: {'American-gpe': 36,
#   'African-gpe': 26,
#   'Americans-gpe': 17,
#   'British-gpe': 11,
#   'German-gpe': 9,
#   'Google-org': 214,
#   'US-org': 38,
#   'STEM-org': 38,
#   'Apple-org': 33,
#   'PTSD-org': 25,
#   'Lynn-per': 17,
#   'Clinton-per': 15,
#   'Women-per': 13,
#   'Wonder Woman-per': 13,
#   'James Damore-per': 12,
#   'United States-geo': 40,
#   'Strumia-geo': 34,
#   'Women-geo': 24,
#   'China-geo': 21,
#   'America-geo': 20},
#  24: {'Jordan-gpe': 115,
#   'Pelicans-gpe': 83,
#   'Damian-gpe': 27,
#   'Marquese-gpe': 10,
#   'Jerian-gpe': 9,
#   'NBA-org': 997,
#   'Rockets-org': 542,
#   'Pacers-org': 508,
#   'Hornets-org': 475,
#   'Magic-org': 391,
#   'James-per': 402,
#   'Westbrook-per': 282,
#   'Thomas-per': 260,
#   'Curry-per': 250,
#   'Harden-per': 215,
#   'Utah-geo': 604,
#   'Washington-geo': 548,
#   'Boston-geo': 529,
#   'Miami-geo': 509,
#   'Houston-geo': 502},
#  25: {'African-gpe': 34,
#   'French-gpe': 10,
#   'Nigerian-gpe': 7,
#   'Kenyan-gpe': 6,
#   'Chinese-gpe': 4,
#   'Hyperloop-org': 12,
#   'MTN-org': 10,
#   'CFA-org': 7,
#   'Uganda-org': 4,
#   'Mombasa-org': 4,
#   'Hyperloop One-per': 14,
#   'Elon Musk-per': 8,
#   'Kenya Railways-per': 6,
#   'Shervin Pishevar-per': 4,
#   'Guinea Bissau-per': 3,
#   'Nigeria-geo': 22,
#   'Kenya-geo': 15,
#   'Nairobi-geo': 11,
#   'Africa-geo': 11,
#   'South Africa-geo': 9},
#  26: {'Chinese-gpe': 232,
#   'German-gpe': 72,
#   'British-gpe': 71,
#   'Indian-gpe': 66,
#   'French-gpe': 64,
#   'Amazon-org': 343,
#   'Apple-org': 314,
#   'Walmart-org': 181,
#   'Google-org': 150,
#   'CNBC-org': 134,
#   'Amazon-per': 452,
#   'Prime-per': 138,
#   'Inc-per': 59,
#   'Black-per': 41,
#   'Target-per': 39,
#   'Amazon-geo': 1050,
#   'China-geo': 322,
#   'United States-geo': 203,
#   'Alibaba-geo': 173,
#   'India-geo': 136},
#  27: {'French-gpe': 491,
#   'German-gpe': 97,
#   'British-gpe': 30,
#   'Chinese-gpe': 20,
#   'Italian-gpe': 9,
#   'EDF-org': 649,
#   'ASN-org': 211,
#   'Bate Felix-org': 63,
#   'Geert De Clercq-org': 41,
#   'Hinkley Point-org': 32,
#   'Jean Bernard Levy-per': 31,
#   'Le Maire-per': 18,
#   'President Emmanuel Macron-per': 17,
#   'Levy-per': 17,
#   'Hinkley Point-per': 14,
#   'France-geo': 255,
#   'Flamanville-geo': 94,
#   'Areva-geo': 90,
#   'Britain-geo': 77,
#   'Germany-geo': 52},
#  28: {'Chinese-gpe': 4,
#   'Canadian-gpe': 2,
#   'French-gpe': 2,
#   'Nepal-gpe': 1,
#   'German-gpe': 1,
#   'TSS-org': 10,
#   'Moon Cup-org': 3,
#   'Blossom Cup-org': 2,
#   'Goop-org': 2,
#   'Liverpool School of Tropical Medicine-org': 2,
#   'Gunter-per': 9,
#   'Jen Gunter-per': 3,
#   'Diva Cup-per': 2,
#   'Emma-per': 2,
#   'Gerard Lina-per': 1,
#   'United States-geo': 4,
#   'New York-geo': 4,
#   'Thinx-geo': 3,
#   'Staphylococcus-geo': 2,
#   'Gunter-geo': 2},
#  29: {'Swiss-gpe': 151,
#   'Americans-gpe': 96,
#   'American-gpe': 95,
#   'British-gpe': 81,
#   'French-gpe': 37,
#   'FDA-org': 565,
#   'Food and Drug Administration-org': 314,
#   'Roche-org': 261,
#   'Merck-org': 222,
#   'CAR T-org': 192,
#   'Tecentriq-per': 112,
#   'Novartis-per': 93,
#   'Bristol Myers-per': 89,
#   'Bristol Myers Squibb-per': 75,
#   'Pfizer-per': 62,
#   'United States-geo': 435,
#   'Keytruda-geo': 345,
#   'Bengaluru-geo': 343,
#   'Opdivo-geo': 197,
#   'Alzheimer-geo': 195},
#  30: {},
#  31: {'Chinese-gpe': 377,
#   'American-gpe': 83,
#   'Indian-gpe': 81,
#   'Japanese-gpe': 37,
#   'French-gpe': 22,
#   'Apple-org': 14141,
#   'Apple Watch-org': 902,
#   'Apple TV-org': 451,
#   'Bloomberg-org': 367,
#   'CNBC-org': 318,
#   'Cook-per': 796,
#   'Mac-per': 492,
#   'Mac Pro-per': 381,
#   'Tim Cook-per': 372,
#   'Trump-per': 275,
#   'China-geo': 1074,
#   'Pro-geo': 451,
#   'India-geo': 351,
#   'Samsung-geo': 261,
#   'United States-geo': 226},
#  32: {'German-gpe': 84,
#   'Egyptian-gpe': 36,
#   'Sebastian-gpe': 32,
#   'Italian-gpe': 30,
#   'Briton-gpe': 28,
#   'Formula E-org': 98,
#   'Vettel-org': 58,
#   'Renault-org': 43,
#   'Grand Prix-org': 39,
#   'Williams-org': 34,
#   'Larson-per': 123,
#   'Alan Baldwin-per': 92,
#   'Busch-per': 71,
#   'Chevrolet-per': 65,
#   'Harvick-per': 58,
#   'Ferrari-geo': 144,
#   'Mercedes-geo': 101,
#   'Hamilton-geo': 79,
#   'Formula One-geo': 62,
#   'Formula E-geo': 51},
#  33: {'Americans-gpe': 125,
#   'American-gpe': 69,
#   'British-gpe': 54,
#   'French-gpe': 41,
#   'Canadian-gpe': 35,
#   'CDC-org': 1603,
#   'FDA-org': 603,
#   'Centers for Disease Control and Prevention-org': 300,
#   'US-org': 284,
#   'US Centers for Disease Control and Prevention-org': 218,
#   'Kentucky-per': 64,
#   'Clinton-per': 43,
#   'Schaffner-per': 43,
#   'Taylor-per': 33,
#   'Johnson-per': 27,
#   'United States-geo': 387,
#   'California-geo': 260,
#   'New York-geo': 175,
#   'Illinois-geo': 171,
#   'Salmonella-geo': 163},
#  34: {'Americans-gpe': 1761,
#   'American-gpe': 513,
#   'Chinese-gpe': 58,
#   'Mexican-gpe': 58,
#   'Canadian-gpe': 53,
#   'Congress-org': 2216,
#   'Senate-org': 2092,
#   'House-org': 1473,
#   'Affordable Care Act-org': 1301,
#   'ACA-org': 1001,
#   'Trump-per': 2310,
#   'President Donald Trump-per': 624,
#   'Obama-per': 543,
#   'Obamacare-per': 386,
#   'President Trump-per': 297,
#   'Obamacare-geo': 1419,
#   'Medicaid-geo': 1346,
#   'Medicare-geo': 1045,
#   'Trump-geo': 870,
#   'Washington-geo': 591},
#  35: {'Japanese-gpe': 13,
#   'Chinese-gpe': 1,
#   'Japan-gpe': 1,
#   'KOREA-org': 2,
#   'Reuters U-org': 2,
#   'TOKYO Reuters Taiwan-org': 1,
#   'Hon Hai Precision Industry Co Ltd-org': 1,
#   'Sharp-org': 1,
#   'Prime-per': 5,
#   'Shinzo Abe-per': 5,
#   'Aso-per': 3,
#   'Chris Gallagher-per': 2,
#   'President Donald Trump-per': 2,
#   'Japan-geo': 6,
#   'Tokyo-geo': 4,
#   'Nikkei-geo': 3,
#   'Kiyoshi Takenaka-geo': 2,
#   'United States-geo': 1},
#  36: {'American-gpe': 8,
#   'Weiss-gpe': 7,
#   'British-gpe': 6,
#   'Swedish-gpe': 6,
#   'Australian-gpe': 5,
#   'LIGO-org': 572,
#   'LISA-org': 64,
#   'Nobel Prize-org': 59,
#   'LISA Pathfinder-org': 52,
#   'Gizmodo-org': 49,
#   'Einstein-per': 76,
#   'Albert Einstein-per': 71,
#   'Milky Way-per': 27,
#   'Kip Thorne-per': 23,
#   'Weiss-per': 19,
#   'Earth-geo': 175,
#   'Einstein-geo': 86,
#   'Sun-geo': 73,
#   'Virgo-geo': 70,
#   'Louisiana-geo': 57},
#  37: {'Chinese-gpe': 2204,
#   'American-gpe': 154,
#   'Korean-gpe': 81,
#   'Japanese-gpe': 65,
#   'German-gpe': 58,
#   'Apple-org': 463,
#   'Reuters China-org': 191,
#   'Xinhua-org': 185,
#   'Google-org': 169,
#   'Brenda Goh-org': 95,
#   'Foxconn-per': 229,
#   'Liu-per': 151,
#   'President Xi Jinping-per': 117,
#   'Josh Horwitz-per': 64,
#   'Ben Blanchard-per': 60,
#   'China-geo': 4223,
#   'Beijing-geo': 850,
#   'United States-geo': 469,
#   'Shanghai-geo': 300,
#   'Alibaba-geo': 297},
#  38: {'Mexican-gpe': 26,
#   'Spanish-gpe': 7,
#   'American-gpe': 6,
#   'Chinese-gpe': 5,
#   'Chilean-gpe': 3,
#   'GTD-org': 5,
#   'Nov-org': 5,
#   'America Movil-org': 4,
#   'AT T-org': 4,
#   'IFT-org': 3,
#   'President Andres Manuel Lopez Obrador-per': 12,
#   'Lopez Obrador-per': 8,
#   'Carlos Slim-per': 4,
#   'Julia Love-per': 4,
#   'Aya-per': 4,
#   'Mexico-geo': 23,
#   'MEXICO CITY-geo': 18,
#   'Chile-geo': 13,
#   'Latin America-geo': 8,
#   'Mexico City-geo': 8},
#  39: {'Chinese-gpe': 2610,
#   'American-gpe': 583,
#   'Mexican-gpe': 411,
#   'Japanese-gpe': 165,
#   'Canadian-gpe': 101,
#   'EU-org': 453,
#   'White House-org': 444,
#   'WTO-org': 322,
#   'Reuters U-org': 258,
#   'Apple-org': 243,
#   'Trump-per': 2063,
#   'President Donald Trump-per': 732,
#   'Robert Lighthizer-per': 226,
#   'David Lawder-per': 200,
#   'President Xi Jinping-per': 190,
#   'China-geo': 4179,
#   'United States-geo': 2447,
#   'Washington-geo': 1198,
#   'Beijing-geo': 1063,
#   'Mexico-geo': 784},
#  40: {'French-gpe': 185,
#   'Japanese-gpe': 103,
#   'German-gpe': 61,
#   'Italian-gpe': 52,
#   'Chinese-gpe': 42,
#   'Nissan-org': 391,
#   'Renault-org': 328,
#   'Ford-org': 181,
#   'BMW-org': 158,
#   'SUV-org': 132,
#   'Mercedes Benz-per': 81,
#   'Ghosn-per': 57,
#   'Android Auto-per': 51,
#   'Carlos Ghosn-per': 49,
#   'Toyota-per': 45,
#   'Tesla-geo': 140,
#   'Volvo-geo': 131,
#   'Audi-geo': 96,
#   'Porsche-geo': 84,
#   'Ghosn-geo': 75},
#  41: {'Gibraltar-gpe': 1,
#   'Nordea International Private Banking-org': 2,
#   'Jyske Bank-org': 2,
#   'Reuters Nordeas-org': 1,
#   'Jens Lauritzen fra Jyske Bank Private Banking-org': 1,
#   'Jens Lauritzen-org': 1,
#   'Torben Laustsen-per': 4,
#   'Også Danske Banks-per': 1,
#   'Stig Pristed-per': 1,
#   'København-per': 1,
#   'Norden-per': 1,
#   'Luxembourg-geo': 2,
#   'Nordea-geo': 1,
#   'Panama-geo': 1},
#  42: {'Chinese-gpe': 53,
#   'Japanese-gpe': 34,
#   'American-gpe': 22,
#   'Taiwanese-gpe': 14,
#   'British-gpe': 9,
#   'VR-org': 2739,
#   'Google-org': 919,
#   'Microsoft-org': 700,
#   'Apple-org': 531,
#   'AR-org': 460,
#   'Oculus Rift-per': 130,
#   'Gear VR-per': 102,
#   'Oculus-per': 93,
#   'Facebook-per': 89,
#   'Zuckerberg-per': 58,
#   'Oculus-geo': 683,
#   'VR-geo': 254,
#   'Samsung-geo': 216,
#   'Daydream-geo': 114,
#   'Android-geo': 110},
#  43: {'Americans-gpe': 11,
#   'African-gpe': 4,
#   'American-gpe': 3,
#   'Chinese-gpe': 1,
#   'Dutch-gpe': 1,
#   'HIV-org': 59,
#   'UNOS-org': 15,
#   'United Network for Organ Sharing-org': 12,
#   'US-org': 11,
#   'UCLA-org': 5,
#   'Klassen-per': 27,
#   'Segev-per': 12,
#   'Johns Hopkins-per': 10,
#   'Monahan-per': 8,
#   'David Klassen-per': 7,
#   'United States-geo': 51,
#   'Veale-geo': 11,
#   'South Africa-geo': 10,
#   'Durand-geo': 9,
#   'New York-geo': 7},
#  44: {'Indian-gpe': 43,
#   'British-gpe': 38,
#   'Swedish-gpe': 15,
#   'Japanese-gpe': 12,
#   'Americans-gpe': 10,
#   'Apple Music-org': 452,
#   'Apple-org': 336,
#   'Google-org': 134,
#   'YouTube Music-org': 116,
#   'Google Play Music-org': 72,
#   'Spotify-per': 153,
#   'Taylor Swift-per': 38,
#   'Drake-per': 35,
#   'Prime-per': 33,
#   'Tidal-per': 24,
#   'Spotify-geo': 567,
#   'Pandora-geo': 147,
#   'Amazon-geo': 65,
#   'Tidal-geo': 58,
#   'India-geo': 58},
#  45: {'Russian-gpe': 32,
#   'Chinese-gpe': 25,
#   'American-gpe': 25,
#   'Korean-gpe': 17,
#   'British-gpe': 16,
#   'Instagram-org': 503,
#   'Facebook-org': 409,
#   'Snapchat-org': 281,
#   'Google-org': 127,
#   'Instagram Stories-org': 113,
#   'Instagram-per': 171,
#   'Facebook-per': 114,
#   'Snapchat-per': 87,
#   'Snap-per': 44,
#   'Motherboard-per': 37,
#   'Instagram-geo': 1307,
#   'Snapchat-geo': 363,
#   'Snap-geo': 103,
#   'Tumblr-geo': 97,
#   'Pinterest-geo': 64},
#  46: {'Indian-gpe': 13,
#   'Chinese-gpe': 12,
#   'American-gpe': 11,
#   'Americans-gpe': 10,
#   'German-gpe': 7,
#   'Google-org': 598,
#   'Apple-org': 433,
#   'Google Assistant-org': 315,
#   'Amazon-org': 193,
#   'Google Home-org': 171,
#   'Siri-per': 318,
#   'Amazon-per': 284,
#   'Alexa-per': 197,
#   'Google Home-per': 122,
#   'Echo Dot-per': 48,
#   'Alexa-geo': 1063,
#   'Echo-geo': 630,
#   'Amazon-geo': 499,
#   'Cortana-geo': 153,
#   'Sonos-geo': 123},
#  47: {'American-gpe': 111,
#   'German-gpe': 77,
#   'British-gpe': 65,
#   'Japanese-gpe': 48,
#   'Chinese-gpe': 47,
#   'Apple-org': 283,
#   "Daily Dispatch and Editor's Picks-org": 208,
#   'NASA-org': 158,
#   'CO2-org': 147,
#   'MIT-org': 107,
#   'Click-per': 66,
#   'Laufer-per': 34,
#   'Dyson-per': 24,
#   'Belcher-per': 24,
#   'Elon Musk-per': 21,
#   'Earth-geo': 208,
#   'China-geo': 120,
#   'United States-geo': 98,
#   'Mars-geo': 93,
#   'Japan-geo': 86},
#  48: {'Iranian-gpe': 1821,
#   'Chinese-gpe': 1369,
#   'Russian-gpe': 1098,
#   'American-gpe': 427,
#   'Venezuelan-gpe': 285,
#   'OPEC-org': 14208,
#   'WTI-org': 1571,
#   'Petroleum Exporting Countries-org': 1506,
#   'Reuters Oil-org': 1042,
#   'EIA-org': 1030,
#   'Brent-per': 3059,
#   'Saudi Arabia-per': 1441,
#   'President Donald Trump-per': 1042,
#   'Trump-per': 904,
#   'Aaron Sheldrick-per': 506,
#   'China-geo': 4941,
#   'Iran-geo': 4723,
#   'Russia-geo': 4586,
#   'United States-geo': 3846,
#   'Saudi Arabia-geo': 2337},
#  49: {'Chinese-gpe': 297,
#   'American-gpe': 226,
#   'Americans-gpe': 198,
#   'Europeans-gpe': 110,
#   'German-gpe': 105,
#   'Google-org': 2146,
#   'Apple-org': 1251,
#   'Facebook-org': 1112,
#   'Motherboard-org': 529,
#   'EU-org': 410,
#   'Facebook-per': 426,
#   'Motherboard-per': 285,
#   'Amazon-per': 145,
#   'T Mobile-per': 104,
#   'Siri-per': 98,
#   'United States-geo': 471,
#   'Europe-geo': 362,
#   'China-geo': 308,
#   'Amazon-geo': 305,
#   'Equifax-geo': 283},
#  50: {'African-gpe': 509,
#   'Brazilian-gpe': 363,
#   'Chinese-gpe': 195,
#   'German-gpe': 65,
#   'Canadian-gpe': 50,
#   'H5N8-org': 234,
#   'ASF-org': 97,
#   'BEIJING Reuters China-org': 87,
#   'H7N9-org': 84,
#   'SAO PAULO-org': 75,
#   'Dominique Patton-per': 103,
#   'Hallie Gu-per': 73,
#   'Sybille de La Hamaide-per': 54,
#   'Ana Mano-per': 43,
#   'President Jair Bolsonaro-per': 38,
#   'China-geo': 928,
#   'Brazil-geo': 497,
#   'Vietnam-geo': 183,
#   'South Korea-geo': 163,
#   'Europe-geo': 161},
#  51: {'Korean-gpe': 14,
#   'American-gpe': 8,
#   'Americans-gpe': 6,
#   'Indian-gpe': 6,
#   'African-gpe': 2,
#   'SPF-org': 124,
#   'UV-org': 94,
#   'FDA-org': 57,
#   'UVB-org': 43,
#   'UVA-org': 40,
#   'Lim-per': 16,
#   'Consumer Reports-per': 8,
#   'Sunscreen-per': 7,
#   'Diaz-per': 7,
#   'Face ID-per': 7,
#   'Hale-geo': 17,
#   'United States-geo': 16,
#   'Skin-geo': 12,
#   'Sun-geo': 10,
#   'Thau-geo': 8},
#  52: {'African-gpe': 42,
#   'Chinese-gpe': 26,
#   'Vietnamese-gpe': 9,
#   'American-gpe': 7,
#   'Laotian-gpe': 7,
#   'CITES-org': 20,
#   'US-org': 19,
#   'IMO-org': 13,
#   'Science Times-org': 13,
#   'World Wildlife Fund-org': 11,
#   'Wasser-per': 15,
#   "O'Brien-per": 8,
#   'Tricorache-per': 7,
#   'Hylaeus-per': 6,
#   'Peyman-per': 6,
#   'China-geo': 62,
#   'South Africa-geo': 42,
#   'Africa-geo': 39,
#   'United States-geo': 28,
#   'Vietnam-geo': 24},
#  53: {'Siberian-gpe': 2,
#   'African-gpe': 2,
#   'British-gpe': 1,
#   'Namibian-gpe': 1,
#   'Apple-org': 4,
#   'Born Free Foundation-org': 2,
#   'ITV News-org': 1,
#   'Verge-org': 1,
#   'Big Cat Rescue-org': 1,
#   'Harbin Siberian Tiger Park-per': 3,
#   'Campbell-per': 3,
#   'John-per': 1,
#   'Platt-per': 1,
#   'Will Travers-per': 1,
#   'China-geo': 5,
#   'Deaf-geo': 2,
#   'Wow-geo': 1,
#   'Russia-geo': 1,
#   'Emojipedia-geo': 1},
#  54: {'Americans-gpe': 70,
#   'American-gpe': 63,
#   'Chinese-gpe': 40,
#   'Australian-gpe': 34,
#   'Turkish-gpe': 27,
#   'Apple-org': 2947,
#   'FBI-org': 1264,
#   'Justice Department-org': 202,
#   'Congress-org': 184,
#   'Google-org': 174,
#   'Cook-per': 188,
#   'James Comey-per': 74,
#   'Trump-per': 73,
#   'Tim Cook-per': 67,
#   'Syed Farook-per': 54,
#   'San Bernardino-geo': 675,
#   'California-geo': 145,
#   'New York-geo': 138,
#   'Comey-geo': 111,
#   'United States-geo': 104},
#  55: {'Americans-gpe': 201,
#   'American-gpe': 188,
#   'Chinese-gpe': 69,
#   'French-gpe': 68,
#   'British-gpe': 60,
#   'FDA-org': 231,
#   'US-org': 142,
#   'Academy of Nutrition and Dietetics-org': 93,
#   'USDA-org': 91,
#   'UK-org': 83,
#   'Lisa Drayer-per': 89,
#   'Drayer-per': 77,
#   'Jameson-per': 59,
#   'Young-per': 39,
#   'Freuman-per': 33,
#   'United States-geo': 211,
#   'Mediterranean-geo': 92,
#   'New York-geo': 89,
#   'Mexico-geo': 81,
#   'California-geo': 79},
#  56: {'American-gpe': 42,
#   'Canadian-gpe': 38,
#   'Russian-gpe': 31,
#   'Jordan Eberle-gpe': 30,
#   'Sharks-gpe': 25,
#   'NHL-org': 1276,
#   'Blues-org': 466,
#   'Pittsburgh-org': 452,
#   'Blue Jackets-org': 418,
#   'Wild-org': 372,
#   'Louis-per': 400,
#   'Anaheim-per': 254,
#   'Miller-per': 192,
#   'Smith-per': 164,
#   'Nashville-per': 147,
#   'Washington-geo': 585,
#   'San Jose-geo': 583,
#   'Chicago-geo': 521,
#   'Detroit-geo': 500,
#   'Minnesota-geo': 492},
#  57: {},
#  58: {'Def Con-org': 14,
#   'PCB-org': 4,
#   'Queer Con-org': 3,
#   'FBI-org': 3,
#   'Shitty Add-org': 3,
#   'Def Con-per': 19,
#   'Merrill-per': 7,
#   'Grand-per': 4,
#   'Queer Con-per': 4,
#   'Whisker-per': 2,
#   'Grand-geo': 16,
#   'China-geo': 5,
#   'Def Con-geo': 4,
#   'Las Vegas-geo': 3,
#   'Caesars-geo': 2},
#  59: {'Americans-gpe': 12,
#   'American-gpe': 10,
#   'British-gpe': 7,
#   'Swiss-gpe': 5,
#   'Mexican-gpe': 5,
#   'MDMA-org': 242,
#   'LSD-org': 162,
#   'PTSD-org': 108,
#   'FDA-org': 60,
#   'MAPS-org': 48,
#   'Medina Kirchner-per': 23,
#   'Greenfield-per': 22,
#   'Giordano-per': 14,
#   'Johnson-per': 14,
#   'Strassman-per': 13,
#   'California-geo': 32,
#   'San Francisco-geo': 21,
#   'New York City-geo': 20,
#   'United States-geo': 20,
#   'Colorado-geo': 19},
#  60: {'American-gpe': 475,
#   'Chinese-gpe': 240,
#   'Canadian-gpe': 236,
#   'Americans-gpe': 224,
#   'Mexican-gpe': 197,
#   'EPA-org': 1115,
#   'Congress-org': 503,
#   'White House-org': 486,
#   'FCC-org': 326,
#   'US-org': 280,
#   'Trump-per': 1120,
#   'Obama-per': 665,
#   'President Donald Trump-per': 316,
#   'President Trump-per': 185,
#   'Pruitt-per': 176,
#   'United States-geo': 754,
#   'Trump-geo': 596,
#   'California-geo': 532,
#   'China-geo': 508,
#   'Canada-geo': 354},
#  61: {'American-gpe': 639,
#   'Chinese-gpe': 430,
#   'Americans-gpe': 426,
#   'British-gpe': 256,
#   'Japanese-gpe': 192,
#   'Apple-org': 3039,
#   'Google-org': 3017,
#   'Microsoft-org': 1061,
#   'US-org': 941,
#   'Facebook-org': 871,
#   'Trump-per': 886,
#   'Well-per': 498,
#   'Amazon-per': 303,
#   'Mike-per': 255,
#   'Siri-per': 225,
#   'Amazon-geo': 1086,
#   'China-geo': 866,
#   'Instagram-geo': 817,
#   'United States-geo': 793,
#   'New York-geo': 749},
#  62: {'French-gpe': 291,
#   'German-gpe': 209,
#   'Chinese-gpe': 147,
#   'American-gpe': 110,
#   'Australian-gpe': 95,
#   'Eskom-org': 374,
#   'EDF-org': 228,
#   'Google-org': 174,
#   'US-org': 167,
#   'UK-org': 113,
#   'Trump-per': 116,
#   'Engie-per': 60,
#   'President Donald Trump-per': 56,
#   'Vattenfall-per': 53,
#   'Siemens-per': 49,
#   'China-geo': 461,
#   'Tesla-geo': 344,
#   'Germany-geo': 292,
#   'Australia-geo': 263,
#   'India-geo': 237},
#  63: {'Chinese-gpe': 328,
#   'American-gpe': 166,
#   'Russian-gpe': 149,
#   'German-gpe': 114,
#   'British-gpe': 68,
#   'FAA-org': 446,
#   'Air Force-org': 400,
#   'US-org': 352,
#   'DJI-org': 305,
#   'Pentagon-org': 296,
#   'Trump-per': 112,
#   'Kitty Hawk-per': 83,
#   'Uber-per': 66,
#   'Amazon-per': 46,
#   'Lockheed Martin-per': 44,
#   'China-geo': 512,
#   'United States-geo': 312,
#   'Russia-geo': 187,
#   'Japan-geo': 131,
#   'Washington-geo': 129},
#  64: {'Cubans-gpe': 6,
#   'Chinese-gpe': 3,
#   'American-gpe': 3,
#   'Canadian-gpe': 2,
#   'Americans-gpe': 1,
#   'Wi Fi-org': 223,
#   'Google-org': 114,
#   'Google Wifi-org': 67,
#   'AT T-org': 50,
#   'US-org': 32,
#   'Wi Fi-per': 140,
#   'Orbi-per': 14,
#   'Starry-per': 11,
#   'Patouraux-per': 11,
#   'Amazon-per': 10,
#   'Eero-geo': 72,
#   'Wi Fi-geo': 37,
#   'Amazon-geo': 25,
#   'London-geo': 24,
#   'Earth-geo': 23},
#  65: {'Italian-gpe': 50,
#   'French-gpe': 41,
#   'Chinese-gpe': 41,
#   'German-gpe': 17,
#   'Cuban-gpe': 12,
#   'CNBC-org': 274,
#   'Bloomberg-org': 247,
#   'Apple-org': 214,
#   'TIM-org': 133,
#   'Google-org': 95,
#   'Open Fiber-per': 40,
#   'Trump-per': 36,
#   'Amazon-per': 30,
#   'Cramer-per': 25,
#   'President Donald Trump-per': 22,
#   'Vivendi-geo': 92,
#   'Bengaluru-geo': 89,
#   'China-geo': 77,
#   'Amazon-geo': 69,
#   'Italy-geo': 38},
#  66: {'Americans-gpe': 36,
#   'American-gpe': 36,
#   'Australian-gpe': 13,
#   'British-gpe': 13,
#   'Kardashian-gpe': 9,
#   'BMI-org': 76,
#   'Weight Watchers-org': 35,
#   'University-org': 32,
#   'HIIT-org': 32,
#   'US-org': 28,
#   'Spears-per': 53,
#   'Jameson-per': 53,
#   'Berry-per': 23,
#   'Hall-per': 21,
#   'Cummings-per': 19,
#   'Instagram-geo': 82,
#   'Peloton-geo': 64,
#   'Ngo-geo': 46,
#   'New York City-geo': 38,
#   'New York-geo': 36},
#  67: {'Swiss-gpe': 222,
#   'American-gpe': 219,
#   'Americans-gpe': 192,
#   'Russian-gpe': 70,
#   'Mexican-gpe': 58,
#   'White House-org': 501,
#   'Sanders-org': 216,
#   'Google-org': 172,
#   'Bloomberg-org': 166,
#   'Senate-org': 157,
#   'Trump-per': 2599,
#   'Clinton-per': 942,
#   'Donald Trump-per': 493,
#   'Obama-per': 435,
#   'Hillary Clinton-per': 344,
#   'Iowa-geo': 432,
#   'Trump-geo': 380,
#   'Cruz-geo': 351,
#   'New Hampshire-geo': 283,
#   'United States-geo': 275},
#  68: {'Egyptian-gpe': 60,
#   'Arab-gpe': 47,
#   'Turkish-gpe': 40,
#   'Iranian-gpe': 35,
#   'Syrian-gpe': 28,
#   'Qatar-org': 218,
#   'Egypt-org': 76,
#   'OPEC-org': 57,
#   'Kuwait-org': 56,
#   'Turkey-org': 48,
#   'Saudi Arabia-per': 133,
#   'Riyadh-per': 49,
#   'Trump-per': 39,
#   'Abu Dhabi-per': 36,
#   'Saudi Aramco-per': 35,
#   'Saudi Arabia-geo': 248,
#   'Iran-geo': 231,
#   'Egypt-geo': 209,
#   'UAE-geo': 175,
#   'Middle East-geo': 157},
#  69: {'Zambian-gpe': 18,
#   'Americans-gpe': 6,
#   'American-gpe': 4,
#   'Brazilian-gpe': 1,
#   'Irish-gpe': 1,
#   'KCM-org': 32,
#   'FDA-org': 19,
#   'US-org': 12,
#   'NMDA-org': 11,
#   'ICD-org': 10,
#   'Fisher-per': 18,
#   'Johnson Johnson-per': 9,
#   'Poznyak-per': 8,
#   'Janssen-per': 7,
#   'Nathan-per': 6,
#   'Vedanta-geo': 23,
#   'Zambia-geo': 20,
#   'Spravato-geo': 11,
#   'Prozac-geo': 9,
#   'New York-geo': 9},
#  70: {'Americans-gpe': 672,
#   'American-gpe': 273,
#   'Chinese-gpe': 97,
#   'African-gpe': 90,
#   'British-gpe': 47,
#   'US-org': 469,
#   'CDC-org': 386,
#   'HIV-org': 243,
#   'UK-org': 166,
#   'Centers for Disease Control and Prevention-org': 151,
#   'Trump-per': 53,
#   'Kentucky-per': 48,
#   'Overall-per': 41,
#   'President Donald Trump-per': 28,
#   'Ward-per': 27,
#   'United States-geo': 863,
#   'China-geo': 255,
#   'Japan-geo': 181,
#   'Canada-geo': 171,
#   'Europe-geo': 119},
#  71: {'Italian-gpe': 1,
#   'Chinese-gpe': 1,
#   'Google-org': 55,
#   'Uber-org': 16,
#   'Tiramisu-org': 7,
#   'Waymo-org': 6,
#   'Fifth Amendment-org': 4,
#   'Levandowski-per': 21,
#   'Waymo-per': 20,
#   'Uber-per': 18,
#   'Anthony Levandowski-per': 14,
#   'Travis Kalanick-per': 6,
#   'Levandowski-geo': 32,
#   'Waymo-geo': 25,
#   'Ottomotto-geo': 13,
#   'Otto-geo': 11,
#   'Tiramisu-geo': 4},
#  72: {'American-gpe': 4,
#   'French-gpe': 3,
#   'Australian-gpe': 1,
#   'Americans-gpe': 1,
#   'Korean-gpe': 1,
#   'FDA-org': 70,
#   'BIA ALCL-org': 57,
#   'Food and Drug Administration-org': 8,
#   'ALCL-org': 8,
#   'American Society of Plastic Surgeons-org': 7,
#   'Biocell-per': 21,
#   'Allergan-per': 14,
#   'Jeff Shuren-per': 5,
#   'Foley-per': 4,
#   'Microcell-per': 4,
#   'Allergan-geo': 27,
#   'United States-geo': 18,
#   'Europe-geo': 15,
#   'Canada-geo': 13,
#   'Bengaluru-geo': 8},
#  73: {'American-gpe': 215,
#   'Chinese-gpe': 127,
#   'British-gpe': 78,
#   'Japanese-gpe': 68,
#   'Russian-gpe': 60,
#   'Apple-org': 170,
#   'US-org': 155,
#   'Google-org': 104,
#   'NASA-org': 89,
#   'Yahoo-org': 62,
#   'Peter-per': 180,
#   'Paul-per': 77,
#   'Caswick-per': 67,
#   'Ward-per': 61,
#   'Well-per': 56,
#   'Earth-geo': 175,
#   'United States-geo': 171,
#   'San Francisco-geo': 157,
#   'New York-geo': 156,
#   'California-geo': 146},
#  74: {'Chinese-gpe': 1400,
#   'Swiss-gpe': 1107,
#   'British-gpe': 770,
#   'German-gpe': 729,
#   'French-gpe': 509,
#   'Apple-org': 2349,
#   'IBES-org': 1593,
#   'EBITDA-org': 1168,
#   'Google-org': 636,
#   'UK-org': 634,
#   'Thomson Reuters-per': 670,
#   'Cook-per': 331,
#   'Street-per': 288,
#   'Amazon-per': 280,
#   'Shares-per': 211,
#   'China-geo': 4217,
#   'Bengaluru-geo': 2829,
#   'Refinitiv-geo': 2305,
#   'United States-geo': 1587,
#   'Europe-geo': 1265},
#  75: {'Russian-gpe': 1134,
#   'American-gpe': 416,
#   'British-gpe': 303,
#   'Chinese-gpe': 243,
#   'Americans-gpe': 229,
#   'Facebook-org': 6853,
#   'Zuckerberg-org': 1252,
#   'Google-org': 1185,
#   'Cambridge Analytica-org': 1122,
#   'Congress-org': 619,
#   'Facebook-per': 2698,
#   'Zuckerberg-per': 1244,
#   'Mark Zuckerberg-per': 760,
#   'Cambridge Analytica-per': 697,
#   'Trump-per': 351,
#   'Zuckerberg-geo': 1134,
#   'Instagram-geo': 743,
#   'Facebook-geo': 544,
#   'United States-geo': 490,
#   'Russia-geo': 479},
#  76: {'French-gpe': 55,
#   'American-gpe': 47,
#   'Chinese-gpe': 31,
#   'Japanese-gpe': 27,
#   'Indian-gpe': 24,
#   'Apple-org': 697,
#   'Disney-org': 202,
#   'Apple TV-org': 137,
#   'YouTube-org': 112,
#   'Google-org': 85,
#   'Netflix-per': 58,
#   'Amazon-per': 58,
#   'Warner Bros-per': 47,
#   'Prime Video-per': 46,
#   'Jennifer Aniston-per': 30,
#   'Netflix-geo': 372,
#   'Amazon-geo': 124,
#   'Hollywood-geo': 116,
#   'China-geo': 63,
#   'Oscar-geo': 63},
#  77: {'Russian-gpe': 96,
#   'Chinese-gpe': 35,
#   'American-gpe': 30,
#   'Iranian-gpe': 29,
#   'Americans-gpe': 26,
#   'Google-org': 721,
#   'Motherboard-org': 459,
#   'Facebook-org': 263,
#   'Apple-org': 228,
#   'SIM-org': 213,
#   'Motherboard-per': 357,
#   'Facebook-per': 105,
#   'Twitter-per': 71,
#   'T Mobile-per': 65,
#   'Amazon-per': 34,
#   'Instagram-geo': 206,
#   'Gmail-geo': 151,
#   'Amazon-geo': 116,
#   'Reddit-geo': 77,
#   'Motherboard-geo': 64},
#  78: {'Japanese-gpe': 105,
#   'Switch-gpe': 60,
#   'Chinese-gpe': 31,
#   'American-gpe': 13,
#   'French-gpe': 7,
#   'Switch-org': 381,
#   'Wii U-org': 282,
#   'Nintendo Switch-org': 182,
#   'Super Mario Run-org': 128,
#   'Wild-org': 90,
#   'Nintendo-per': 112,
#   'Switch-per': 38,
#   'Mario Maker-per': 30,
#   'Miitomo-per': 29,
#   'Super Mario Odyssey-per': 29,
#   'Nintendo-geo': 1676,
#   'Switch-geo': 474,
#   'Mario-geo': 168,
#   'Wii-geo': 112,
#   'China-geo': 106},
#  79: {'American-gpe': 4,
#   'Americans-gpe': 3,
#   'Army-org': 12,
#   'Energy Transfer Partners-org': 12,
#   'Dakota Access Pipeline-org': 11,
#   'Army Corps of Engineers-org': 10,
#   'Corps-org': 9,
#   'Rock Sioux Tribe-per': 10,
#   'Rock Sioux-per': 6,
#   'Rock-per': 4,
#   'Lake Oahe-per': 4,
#   'Trump-per': 3,
#   'North Dakota-geo': 11,
#   'Lake Oahe-geo': 7,
#   'Dakota Access-geo': 6,
#   'Cannon Ball-geo': 6,
#   'Tribe-geo': 5},
#  80: {'American-gpe': 49,
#   'Mathematicians-gpe': 49,
#   'German-gpe': 32,
#   'Chinese-gpe': 30,
#   'French-gpe': 30,
#   'Gizmodo-org': 243,
#   'Quanta Magazine-org': 221,
#   'Big Bang-org': 177,
#   'LHC-org': 170,
#   'CERN-org': 152,
#   'Standard Model-per': 173,
#   'Large Hadron Collider-per': 118,
#   'Einstein-per': 85,
#   'Milky Way-per': 52,
#   'Bob-per': 48,
#   'Earth-geo': 539,
#   'Higgs-geo': 191,
#   'Einstein-geo': 108,
#   'First-geo': 73,
#   'Germany-geo': 69},
#  81: {'Canadian-gpe': 2443,
#   'Chinese-gpe': 2200,
#   'German-gpe': 1319,
#   'British-gpe': 1204,
#   'Japanese-gpe': 954,
#   'Fed-org': 4334,
#   'Federal Reserve-org': 1994,
#   'ECB-org': 1751,
#   'Treasury-org': 1232,
#   'European Union-org': 1043,
#   'President Donald Trump-per': 1038,
#   'Trump-per': 1017,
#   'Powell-per': 542,
#   'Jerome Powell-per': 249,
#   'Prime Minister Theresa May-per': 220,
#   'China-geo': 5114,
#   'United States-geo': 2063,
#   'Brexit-geo': 2009,
#   'Britain-geo': 1152,
#   'Europe-geo': 908},
#  82: {'Pese-gpe': 2,
#   'Dans-gpe': 1,
#   'Íris-gpe': 1,
#   'Chinese-gpe': 1,
#   'Apple-org': 11,
#   'Google-org': 9,
#   'ZTE-org': 8,
#   'Estados Unidos-org': 7,
#   'VPN-org': 7,
#   'Daniel-per': 24,
#   'Estados Unidos-per': 18,
#   'Gobierno-per': 12,
#   'João Lucas-per': 11,
#   'Etats Unis-per': 7,
#   'Ela-geo': 39,
#   'Sophia-geo': 21,
#   'Jaqueline-geo': 18,
#   'China-geo': 17,
#   'Brasil-geo': 16},
#  83: {'F 35A-org': 1,
#   'LRIP-org': 1,
#   'White House-org': 1,
#   "United Technologies' Pratt Whitney-org": 1,
#   'BAE Systems-org': 1,
#   'Trump-per': 2,
#   'Lockheed-per': 2,
#   "President Donald Trump's-per": 1,
#   'Martin-per': 1,
#   'Marillyn Hewson-per': 1,
#   'Lockheed-geo': 5,
#   'Fort Worth-geo': 1,
#   'Texas-geo': 1,
#   'Italy-geo': 1,
#   'Japan-geo': 1},
#  84: {'Murphy and Bing and Getty Images-org': 1,
#   'Mac-per': 1,
#   'Bots-geo': 3,
#   'Skype-geo': 1},
#  85: {'Japanese-gpe': 8,
#   'Korean-gpe': 7,
#   'Penilaian-gpe': 1,
#   'Ketidakpastian-gpe': 1,
#   'American-gpe': 1,
#   'LG Chem-org': 23,
#   'Bank Sinarmas-org': 11,
#   'SK Innovation-org': 11,
#   'Bank DKI-org': 11,
#   'Media Relations-org': 8,
#   'Leslie Tan-per': 8,
#   'IN ADDITION-per': 8,
#   'Tugu Pratama-per': 7,
#   'Satrio Kav-per': 6,
#   'Peringkat Dukungan-per': 5,
#   'Indonesia-geo': 43,
#   'Fitch-geo': 17,
#   'South Korea-geo': 10,
#   'Namun-geo': 8,
#   'Email-geo': 8},
#  86: {},
#  87: {'Chinese-gpe': 3094,
#   'Japanese-gpe': 747,
#   'American-gpe': 539,
#   'German-gpe': 514,
#   'Indian-gpe': 511,
#   'IPO-org': 2865,
#   'CNBC-org': 1422,
#   'Apple-org': 1361,
#   'Google-org': 1262,
#   'SoftBank-org': 922,
#   'Uber-per': 697,
#   'Goldman Sachs-per': 511,
#   'Morgan Stanley-per': 384,
#   'Amazon-per': 329,
#   'Neumann-per': 312,
#   'China-geo': 3657,
#   'Hong Kong-geo': 1444,
#   'United States-geo': 1395,
#   'New York-geo': 1309,
#   'Europe-geo': 1206},
#  88: {'Norwegian-gpe': 8,
#   'American-gpe': 7,
#   'Americans-gpe': 5,
#   'Canadian-gpe': 4,
#   'Australian-gpe': 4,
#   'US-org': 11,
#   'Cox-org': 11,
#   'Svalbard Global Seed Vault-org': 7,
#   'Stamets-org': 6,
#   'Science Times-org': 6,
#   'Kellhammer-per': 15,
#   'Moore-per': 11,
#   'Nowak-per': 10,
#   'Asdal-per': 7,
#   'Rizzo-per': 7,
#   'California-geo': 17,
#   'Cortes Island-geo': 12,
#   'China-geo': 10,
#   'United States-geo': 9,
#   'Cortes-geo': 9},
#  89: {'American-gpe': 32,
#   'Americans-gpe': 22,
#   'German-gpe': 14,
#   'Swiss-gpe': 8,
#   'Australian-gpe': 3,
#   'Army-org': 37,
#   'US-org': 29,
#   'Walmart-org': 29,
#   'Congress-org': 20,
#   'NRA-org': 18,
#   'Trump-per': 14,
#   'Kelley-per': 10,
#   'Heckler Koch-per': 8,
#   'Colt-per': 8,
#   'Musk-per': 8,
#   'Texas-geo': 49,
#   'California-geo': 46,
#   'United States-geo': 39,
#   'Parkland-geo': 25,
#   'Florida-geo': 23},
#  90: {'Venezuelan-gpe': 332,
#   'American-gpe': 77,
#   'Venezuelans-gpe': 36,
#   'Chinese-gpe': 32,
#   'Russian-gpe': 28,
#   'PDVSA-org': 520,
#   'OPEC-org': 97,
#   'Treasury Department-org': 54,
#   'Citgo-org': 48,
#   'Treasury-org': 43,
#   'President Nicolas Maduro-per': 150,
#   'Juan Guaido-per': 97,
#   'Rosneft-per': 58,
#   'Luc Cohen-per': 49,
#   'Guaido-per': 47,
#   'Venezuela-geo': 710,
#   'Maduro-geo': 397,
#   'United States-geo': 247,
#   'Guaido-geo': 164,
#   'Caracas-geo': 161},
#  91: {'American-gpe': 101,
#   'Chinese-gpe': 83,
#   'Martian-gpe': 80,
#   'Indian-gpe': 78,
#   'Israeli-gpe': 54,
#   'NASA-org': 2606,
#   'Moon-org': 1271,
#   'Congress-org': 180,
#   'Bridenstine-org': 163,
#   'Moon Express-org': 148,
#   'Trump-per': 112,
#   'Jim Bridenstine-per': 73,
#   'Neil Armstrong-per': 64,
#   'Chang-per': 57,
#   'Vice President Mike Pence-per': 56,
#   'Mars-geo': 1238,
#   'Earth-geo': 658,
#   'China-geo': 257,
#   'India-geo': 182,
#   'Apollo-geo': 174},
#  92: {'Americans-gpe': 29,
#   'American-gpe': 14,
#   'Circadian-gpe': 8,
#   'German-gpe': 7,
#   'Dutch-gpe': 6,
#   'REM-org': 60,
#   'US-org': 29,
#   'Apple-org': 29,
#   'DST-org': 28,
#   'National Sleep Foundation-org': 23,
#   'Breus-per': 29,
#   'Winter-per': 21,
#   'Sophie-per': 19,
#   'Mander-per': 16,
#   'Wyatt-per': 14,
#   'Fitbit-geo': 50,
#   'Sleep-geo': 33,
#   'New York-geo': 16,
#   'Night-geo': 14,
#   'United States-geo': 14},
#  93: {'Chinese-gpe': 2172,
#   'Americans-gpe': 804,
#   'American-gpe': 590,
#   'Japanese-gpe': 419,
#   'Italian-gpe': 383,
#   'CDC-org': 1626,
#   'WHO-org': 1275,
#   'World Health Organization-org': 745,
#   'US-org': 736,
#   'COVID-org': 641,
#   'Trump-per': 898,
#   'President Donald Trump-per': 485,
#   'Cuomo-per': 449,
#   'Andrew Cuomo-per': 246,
#   'Wuhan-per': 243,
#   'China-geo': 7931,
#   'Wuhan-geo': 2328,
#   'Italy-geo': 2084,
#   'United States-geo': 1976,
#   'South Korea-geo': 1104},
#  94: {'French-gpe': 464,
#   'American-gpe': 197,
#   'Irish-gpe': 171,
#   'German-gpe': 134,
#   'British-gpe': 81,
#   'Google-org': 2379,
#   'EU-org': 1188,
#   'Apple-org': 916,
#   'Commission-org': 609,
#   'European Commission-org': 555,
#   'Vestager-per': 175,
#   'Amazon-per': 161,
#   'Margrethe Vestager-per': 107,
#   'Facebook-per': 103,
#   'Trump-per': 97,
#   'Europe-geo': 578,
#   'Amazon-geo': 428,
#   'Ireland-geo': 397,
#   'France-geo': 371,
#   'United States-geo': 314},
#  95: {'Indian-gpe': 7,
#   'Egyptian-gpe': 4,
#   'Australian-gpe': 3,
#   'Indians-gpe': 3,
#   'Americans-gpe': 3,
#   'CNN-org': 21,
#   'Academy-org': 14,
#   'RAINN-org': 12,
#   'National Sexual Assault Hotline-org': 7,
#   'Operation Safe Escape-org': 5,
#   'Trump-per': 14,
#   'Campbell-per': 9,
#   'Ray Jones-per': 7,
#   'Robbins-per': 6,
#   'Carson-per': 6,
#   'India-geo': 7,
#   'United States-geo': 6,
#   'Rawy-geo': 6,
#   'Sophia-geo': 5,
#   'Rape-geo': 4},
#  96: {'Chinese-gpe': 640,
#   'Russian-gpe': 606,
#   'American-gpe': 407,
#   'Americans-gpe': 228,
#   'German-gpe': 195,
#   'Facebook-org': 2775,
#   'Google-org': 2713,
#   'YouTube-org': 1772,
#   'Apple-org': 571,
#   'Motherboard-org': 546,
#   'Facebook-per': 1300,
#   'Trump-per': 678,
#   'Twitter-per': 385,
#   'Motherboard-per': 295,
#   'Jones-per': 288,
#   'China-geo': 809,
#   'Reddit-geo': 577,
#   'United States-geo': 464,
#   'Instagram-geo': 430,
#   'India-geo': 356},
#  97: {},
#  98: {'Creatine Magnesium-org': 1,
#   'Journal of Strength Conditioning Research-org': 1,
#   'Crea Trona-org': 1,
#   'International Society of Sports Nutrition-org': 1,
#   'Citrate-org': 1,
#   'Buffered CreatineThis-per': 1,
#   'Kre Alkalyn-per': 1,
#   'Creatine MalateBound-per': 1,
#   'Creatine GluconateThis-per': 1,
#   'Creatine PyruvateBound-per': 1,
#   'Creatine-geo': 4},
#  99: {'American-gpe': 1,
#   'FOOD-org': 4,
#   'REUTERS-org': 3,
#   'REUTERS POLL-org': 2,
#   'US Tire Manufacturers Association USTMA-org': 1,
#   'National Tire Safety Week-org': 1,
#   'Ars Technica-geo': 1},
#  100: {'FDA Find No Asbestos Oct-org': 1,
#   'Reuters Johnson Johnson Consumer Inc-org': 1,
#   'NEW-org': 1,
#   'CO-org': 1,
#   'ADULTS-org': 1,
#   'Johnson Johnson JOHNSON JOHNSON LAUNCHES HEARTLINE-per': 1,
#   'IN COLLABORATION WITH APPLE-per': 1},
#  101: {'Chinese-gpe': 413,
#   'Swiss-gpe': 178,
#   'Japanese-gpe': 129,
#   'American-gpe': 107,
#   'Korean-gpe': 104,
#   'SEC-org': 740,
#   'CNBC-org': 676,
#   'Ethereum-org': 525,
#   'Facebook-org': 503,
#   'ICO-org': 493,
#   'Bitcoin-per': 370,
#   'Coinbase-per': 186,
#   'Goldman Sachs-per': 147,
#   'Facebook-per': 147,
#   'Bitcoin Cash-per': 147,
#   'Bitcoin-geo': 1779,
#   'Libra-geo': 1331,
#   'China-geo': 654,
#   'New York-geo': 349,
#   'Blockchain-geo': 314},
#  102: {'Indian-gpe': 342,
#   'African-gpe': 310,
#   'British-gpe': 218,
#   'Nepal-gpe': 129,
#   'Niger-gpe': 96,
#   'Thomson Reuters Foundation-org': 2311,
#   'United Nations-org': 333,
#   'UNICEF-org': 258,
#   'World Bank-org': 199,
#   'HIV-org': 191,
#   'Thomson Reuters-per': 1144,
#   'Ros Russell-per': 345,
#   'Katie Nguyen-per': 122,
#   'Thomson Reuters Foundation-per': 79,
#   'Katy Migiro-per': 75,
#   'India-geo': 962,
#   'Editing-geo': 795,
#   'Britain-geo': 368,
#   'Kenya-geo': 359,
#   'Africa-geo': 355},
#  103: {'Australian-gpe': 1,
#   'HCV-org': 3,
#   'Got My Head Tattooed-org': 1,
#   'Danish Environmental Protection Agency-org': 1,
#   'European Society of Tattoo and Pigment Research-org': 1,
#   'Food and Drug Administration-org': 1,
#   'Harris Poll-per': 2,
#   'Bernhard Hesse-per': 1,
#   'Gynecology-per': 1,
#   'Eric Madfis-per': 1,
#   'Tammi Arford-per': 1,
#   'Tattoos-geo': 3,
#   'Tonic More-geo': 1,
#   'Hepatology-geo': 1,
#   'Hepatitis-geo': 1,
#   'Symbols-geo': 1},
#  104: {},
#  105: {'Chinese-gpe': 1688,
#   'British-gpe': 598,
#   'Taiwanese-gpe': 49,
#   'Portuguese-gpe': 34,
#   'Canadian-gpe': 24,
#   'HONG KONG-org': 325,
#   'Reuters Hong Kong-org': 224,
#   'Donny Kwok-org': 169,
#   'Communist Party-org': 154,
#   'Kowloon-org': 102,
#   'Carrie Lam-per': 268,
#   'Lam-per': 262,
#   'Anne Marie Roantree-per': 216,
#   'Farah Master-per': 141,
#   'Twinnie Siu-per': 124,
#   'Hong Kong-geo': 4210,
#   'China-geo': 2209,
#   'Beijing-geo': 1016,
#   "Hong Kong's-geo": 559,
#   'Taiwan-geo': 364},
#  106: {'British-gpe': 22,
#   'Japanese-gpe': 11,
#   'Chinese-gpe': 7,
#   'Russian-gpe': 4,
#   'Thai-gpe': 4,
#   'SEC-org': 92,
#   'Twitter-org': 60,
#   'CNBC-org': 24,
#   'Securities and Exchange Commission-org': 24,
#   'Tesla-org': 23,
#   'Musk-per': 209,
#   'Elon Musk-per': 91,
#   'Dorsey-per': 74,
#   'Twitter-per': 54,
#   'Jack Dorsey-per': 30,
#   'Musk-geo': 429,
#   'Tesla-geo': 313,
#   'Unsworth-geo': 66,
#   'Thailand-geo': 36,
#   'Aug-geo': 33},
#  107: {'Russian-gpe': 1440,
#   'Chinese-gpe': 736,
#   'American-gpe': 445,
#   'Iranian-gpe': 322,
#   'German-gpe': 262,
#   'Apple-org': 1238,
#   'Motherboard-org': 1136,
#   'FBI-org': 933,
#   'Microsoft-org': 751,
#   'Google-org': 727,
#   'Kaspersky-per': 414,
#   'Motherboard-per': 362,
#   'Kaspersky Lab-per': 271,
#   'Trump-per': 230,
#   'Phineas Fisher-per': 139,
#   'Russia-geo': 921,
#   'United States-geo': 752,
#   'China-geo': 705,
#   'Iran-geo': 430,
#   'Ukraine-geo': 366},
#  108: {'American-gpe': 2,
#   'Nepal-gpe': 1,
#   'German-gpe': 1,
#   'Canadian-gpe': 1,
#   'American Academy of Pediatrics-org': 8,
#   'US-org': 6,
#   'World Health Organization-org': 5,
#   'Palmquist-org': 5,
#   'AAP-org': 4,
#   'Reisman-per': 10,
#   'Davis-per': 8,
#   'Marga-per': 4,
#   'Modi-per': 4,
#   'Rezak-per': 3,
#   'United States-geo': 8,
#   'Breast-geo': 7,
#   'Marina-geo': 5,
#   'California-geo': 5,
#   'Formula-geo': 4},
#  109: {'African-gpe': 31,
#   'Chinese-gpe': 23,
#   'Poland-gpe': 20,
#   'Polish-gpe': 20,
#   'Tanzanian-gpe': 17,
#   'KCC-org': 21,
#   'Newmont-org': 19,
#   'Glencore-org': 18,
#   'PNG-org': 15,
#   'JSW-org': 13,
#   'Barrick-per': 46,
#   'Glencore-per': 22,
#   'Sibanye Stillwater-per': 22,
#   'Metalor-per': 20,
#   'Sibanye-per': 17,
#   'South Africa-geo': 50,
#   'Congo-geo': 40,
#   'Africa-geo': 37,
#   'Democratic Republic of Congo-geo': 34,
#   'Poland-geo': 33},
#  110: {'American-gpe': 47,
#   'Canadian-gpe': 20,
#   'Chinese-gpe': 20,
#   'Indian-gpe': 17,
#   'French-gpe': 15,
#   'Google-org': 313,
#   'Amazon-org': 291,
#   'MTA-org': 233,
#   'HQ2-org': 188,
#   'Apple-org': 153,
#   'Amazon-per': 405,
#   'Cuomo-per': 228,
#   'Andrew Cuomo-per': 101,
#   'Mayor Bill de Blasio-per': 72,
#   'Blasio-per': 50,
#   'New York-geo': 899,
#   'Amazon-geo': 628,
#   'New York City-geo': 613,
#   'Seattle-geo': 237,
#   'Long Island City-geo': 224},
#  111: {'Syrian-gpe': 789,
#   'Indian-gpe': 297,
#   'Russian-gpe': 290,
#   'Turkish-gpe': 250,
#   'French-gpe': 204,
#   'Islamic State-org': 583,
#   'Muslim-org': 192,
#   'Iraqi-org': 174,
#   'United Nations-org': 171,
#   'Turkey-org': 125,
#   'Trump-per': 120,
#   'Houthi-per': 78,
#   'Khan-per': 78,
#   'Shi-per': 72,
#   'President Donald Trump-per': 70,
#   'Syria-geo': 902,
#   'Pakistan-geo': 431,
#   'Iraq-geo': 385,
#   'Myanmar-geo': 365,
#   'United States-geo': 323},
#  112: {'Japanese-gpe': 8,
#   'Julian-gpe': 2,
#   'Adrian-gpe': 2,
#   'Americans-gpe': 2,
#   'Spanish-gpe': 2,
#   'The Creators Project-org': 6,
#   'Google-org': 6,
#   'Plath-org': 6,
#   'Apple-org': 5,
#   'Elliot-org': 4,
#   'Charrière-per': 6,
#   'Click-per': 5,
#   'Abney-per': 5,
#   'Horsman-per': 5,
#   'Olson-per': 5,
#   'London-geo': 7,
#   'Art-geo': 6,
#   'China-geo': 6,
#   'New York-geo': 5,
#   'Instagram-geo': 4},
#  113: {'Swiss-gpe': 6,
#   'Americans-gpe': 4,
#   'Chinese-gpe': 3,
#   'Canadian-gpe': 1,
#   'Norwegian-gpe': 1,
#   'Apple Watch-org': 169,
#   'Apple-org': 139,
#   'EKG-org': 29,
#   'FDA-org': 29,
#   'ECG-org': 25,
#   'Fitbit-per': 13,
#   'Montoye-per': 8,
#   'Pebble-per': 7,
#   'Garmin-per': 7,
#   'Siri-per': 6,
#   'Fitbit-geo': 171,
#   'Samsung-geo': 15,
#   'GPS-geo': 14,
#   'Blaze-geo': 10,
#   'Android-geo': 10},
#  114: {'German-gpe': 6,
#   'Chinese-gpe': 6,
#   'Norwegian-gpe': 5,
#   'Dutch-gpe': 3,
#   'Russian-gpe': 1,
#   'Uber Eats-org': 18,
#   'UK-org': 15,
#   'Seamless-org': 14,
#   'Just Eat-org': 11,
#   'US-org': 11,
#   'Uber Eats-per': 34,
#   'Grubhub-per': 17,
#   'Uber-per': 15,
#   'Amazon-per': 9,
#   'Caviar-per': 9,
#   'Grubhub-geo': 118,
#   'Postmates-geo': 29,
#   'Domino-geo': 24,
#   'Yelp-geo': 20,
#   'San Francisco-geo': 19},
#  115: {},
#  116: {'Korean-gpe': 154,
#   'Malaysian-gpe': 26,
#   'Japanese-gpe': 21,
#   'Chinese-gpe': 14,
#   'Koreans-gpe': 5,
#   'Reuters North Korea-org': 11,
#   'Reuters South Korea-org': 9,
#   'KCNA-org': 7,
#   'Unification Ministry-org': 5,
#   'KUALA LUMPUR-org': 5,
#   'Kim Jong Nam-per': 49,
#   'Kim-per': 29,
#   'Kim Jong Un-per': 28,
#   'Kim Jong Il-per': 13,
#   'Ju min Park-per': 13,
#   'North Korea-geo': 96,
#   'South Korea-geo': 81,
#   'Japan-geo': 34,
#   'Malaysia-geo': 34,
#   'China-geo': 28},
#  117: {'British-gpe': 180,
#   'American-gpe': 132,
#   'Americans-gpe': 128,
#   'Indian-gpe': 45,
#   'African-gpe': 43,
#   'FDA-org': 2142,
#   'CDC-org': 515,
#   'Food and Drug Administration-org': 492,
#   'THC-org': 483,
#   'Juul-org': 335,
#   'Juul-per': 789,
#   'Gottlieb-per': 347,
#   'Philip Morris-per': 236,
#   'Trump-per': 222,
#   'Scott Gottlieb-per': 207,
#   'Juul-geo': 2014,
#   'Altria-geo': 775,
#   'United States-geo': 515,
#   'San Francisco-geo': 300,
#   'New York-geo': 221},
#  118: {'Chinese-gpe': 357,
#   'African-gpe': 131,
#   'American-gpe': 113,
#   'British-gpe': 103,
#   'Americans-gpe': 74,
#   'DNA-org': 1492,
#   'CRISPR-org': 854,
#   'RNA-org': 441,
#   'FDA-org': 389,
#   'HIV-org': 351,
#   'Esvelt-per': 83,
#   'Liu-per': 71,
#   'Traywick-per': 48,
#   'Jennifer Doudna-per': 45,
#   'Davis-per': 44,
#   'China-geo': 364,
#   'Crispr-geo': 338,
#   'United States-geo': 270,
#   'Zika-geo': 156,
#   'Earth-geo': 148},
#  119: {'American-gpe': 29,
#   'Americans-gpe': 24,
#   'Canadian-gpe': 12,
#   'Russian-gpe': 12,
#   'African-gpe': 10,
# ...
#   'Karpeles-org': 4,
#   'TOKYO Reuters When Mt-org': 1,
#   'Karpeles-per': 10,
#   'Kobayashi-per': 5,
#   'Ver-per': 3,
#   'Tibanne-per': 2,
#   'Gox-per': 2,
#   'Tibanne-geo': 6,
#   'Japan-geo': 5,
#   'United States-geo': 5,
#   'Tokyo-geo': 4,
#   'Kobayashi-geo': 4},
#  218: {'American Cancer Society-org': 1,
#   'ACS-org': 1,
#   'American Congress of Obstetricians and Gynecologists-org': 1,
#   'US Preventative Services Task Force-org': 1,
#   'Congress-org': 1},
#  219: {'Chinese-gpe': 104,
#   'American-gpe': 65,
#   'British-gpe': 44,
#   'Japanese-gpe': 29,
#   'Russian-gpe': 25,
#   'Google-org': 777,
#   'Microsoft-org': 535,
#   'Apple-org': 484,
#   'Facebook-org': 121,
#   'CNBC-org': 120,
#   'Dyson-per': 92,
#   'Sidewalk Labs-per': 59,
#   'Amazon-per': 46,
#   'Facebook-per': 39,
#   'Raspberry Pi-per': 38,
#   'China-geo': 156,
#   'Java-geo': 155,
#   'Amazon-geo': 145,
#   'Android-geo': 133,
#   'Python-geo': 125},
#  220: {'Japanese-gpe': 3,
#   'German-gpe': 1,
#   'SoftBank-org': 35,
#   'Singapore-org': 10,
#   'IPO-org': 9,
#   'CCT-org': 8,
#   'HSBC-org': 4,
#   'Neumann-per': 26,
#   'Adam Neumann-per': 7,
#   'Christine Li-per': 4,
#   'Cushman-per': 4,
#   'Sayantani Ghosh-per': 4,
#   'China-geo': 8,
#   'Asda-geo': 5,
#   'New York-geo': 5,
#   'Company-geo': 5,
#   'HSBC-geo': 4},
#  221: {'Texans-gpe': 25,
#   'Titans-gpe': 23,
#   'Siemian-gpe': 22,
#   'Evans-gpe': 13,
#   'Spartans-gpe': 11,
#   'NFL-org': 338,
#   'Rams-org': 107,
#   'Broncos-org': 98,
#   'Saints-org': 98,
#   'LSU-org': 84,
#   'Jackson-per': 112,
#   'Clemson-per': 102,
#   'Wilson-per': 77,
#   'Johnson-per': 69,
#   'Smith-per': 66,
#   'Washington-geo': 201,
#   'Houston-geo': 185,
#   'Miami-geo': 144,
#   'Arizona-geo': 130,
#   'Florida-geo': 122},
#  222: {'American-gpe': 44,
#   'Chinese-gpe': 20,
#   'African-gpe': 14,
#   'Americans-gpe': 13,
#   'Spanish-gpe': 13,
#   'CNN-org': 84,
#   'American Academy of Pediatrics-org': 80,
#   'AAP-org': 78,
#   'ADHD-org': 69,
#   'US-org': 57,
#   'Children-per': 51,
#   'Facebook-per': 31,
#   'Messenger Kids-per': 24,
#   'Daniel-per': 22,
#   'Brown-per': 18,
#   'United States-geo': 113,
#   'California-geo': 27,
#   'Children-geo': 26,
#   'New York-geo': 25,
#   'Florida-geo': 24},
#  223: {'Taiwanese-gpe': 3,
#   'American-gpe': 3,
#   'Sebastian-gpe': 2,
#   'Vulkan-gpe': 2,
#   'French-gpe': 2,
#   'AMD-org': 270,
#   'Microsoft-org': 183,
#   'GPU-org': 157,
#   'RTX-org': 147,
#   'GTX-org': 134,
#   'Asus-per': 68,
#   'Razer-per': 52,
#   'Dell-per': 29,
#   'Battlefield V-per': 25,
#   'Mac-per': 21,
#   'Nvidia-geo': 631,
#   'Blade-geo': 35,
#   'Shadow-geo': 30,
#   'Lenovo-geo': 27,
#   'Razer-geo': 22},
#  224: {'Americans-gpe': 8,
#   'American-gpe': 5,
#   'British-gpe': 3,
#   'Russian-gpe': 2,
#   'Japanese-gpe': 2,
#   'Moon-org': 34,
#   'NASA-org': 33,
#   'US-org': 12,
#   'American Astronomical Society-org': 8,
#   'Alaska Airlines-org': 8,
#   'Savitsky-per': 4,
#   'Fienberg-per': 4,
#   'Ill-per': 4,
#   'Louis-per': 4,
#   'Deobhakta-per': 4,
#   'Earth-geo': 85,
#   'United States-geo': 56,
#   'Sun-geo': 30,
#   'Oregon-geo': 27,
#   'South Carolina-geo': 20},
#  225: {'XIAOMI-org': 2, 'DIDI-org': 1, 'MEGVII-org': 1},
#  226: {'German-gpe': 13,
#   'French-gpe': 5,
#   'Spanish-gpe': 5,
#   'American-gpe': 5,
#   'Americans-gpe': 4,
#   'FDA-org': 17,
#   'Mission Rabies-org': 13,
#   'DNA-org': 11,
#   'Science Times-org': 10,
#   'FIV-org': 6,
#   'Jackson-per': 17,
#   'Wynne-per': 13,
#   'Karlsson-per': 11,
#   'Owens-per': 9,
#   'Bagnall-per': 8,
#   'India-geo': 28,
#   'United States-geo': 15,
#   'Goa-geo': 14,
#   'Los Angeles-geo': 9,
#   'New York City-geo': 7},
#  227: {'Japanese-gpe': 254,
#   'American-gpe': 236,
#   'British-gpe': 149,
#   'Chinese-gpe': 99,
#   'French-gpe': 82,
#   'Apple-org': 507,
#   'Google-org': 438,
#   'VR-org': 368,
#   'Which-org': 280,
#   'Wild-org': 257,
#   'Follow Patrick-per': 173,
#   'Well-per': 150,
#   'Trump-per': 134,
#   'Tandy-per': 125,
#   'Click-per': 107,
#   'Nintendo-geo': 552,
#   'Earth-geo': 226,
#   'Sonic-geo': 221,
#   'Mario-geo': 218,
#   'Japan-geo': 194},
#  228: {},
#  229: {'Russian-gpe': 1099,
#   'Chinese-gpe': 473,
#   'Permian-gpe': 269,
#   'British-gpe': 207,
#   'Indian-gpe': 202,
#   'LNG-org': 1812,
#   'BP-org': 521,
#   'Singapore-org': 319,
#   'Gazprom-org': 291,
#   'Exxon-org': 252,
#   'Rosneft-per': 308,
#   'Shell-per': 281,
#   'Eni-per': 202,
#   'Trump-per': 164,
#   'Chevron-per': 146,
#   'Russia-geo': 1013,
#   'China-geo': 951,
#   'Europe-geo': 778,
#   'United States-geo': 684,
#   'Asia-geo': 446},
#  230: {'Russian-gpe': 328,
#   'American-gpe': 226,
#   'Chinese-gpe': 113,
#   'Japanese-gpe': 94,
#   'French-gpe': 71,
#   'NASA-org': 3643,
#   'Boeing-org': 979,
#   'Falcon Heavy-org': 978,
#   'ISS-org': 564,
#   'Crew Dragon-org': 493,
#   'Musk-per': 799,
#   'Elon Musk-per': 744,
#   'Blue Origin-per': 706,
#   'Virgin Galactic-per': 499,
#   'Branson-per': 268,
#   'Earth-geo': 2247,
#   'Musk-geo': 1185,
#   'Mars-geo': 1167,
#   'Florida-geo': 786,
#   'International Space Station-geo': 548},
#  231: {'Australian-gpe': 4,
#   'French-gpe': 1,
#   'Belizean-gpe': 1,
#   'Great Barrier Reef-org': 50,
#   'Hughes-org': 18,
#   'GBR-org': 14,
#   'NOAA-org': 5,
#   'ARC Centre of Excellence for Coral Reef Studies-org': 4,
#   'Terry Hughes-per': 6,
#   'Great Barrier Reef-per': 6,
#   'El Niño-per': 4,
#   'Vaughan-per': 4,
#   'Mark Eakin-per': 3,
#   'Australia-geo': 22,
#   'Earth-geo': 3,
#   'Unesco-geo': 3,
#   'Florida-geo': 2,
#   'Eakin-geo': 2},
#  232: {'Danish-gpe': 2,
#   'Turkish-gpe': 2,
#   'Sudan-gpe': 1,
#   'Australian-gpe': 1,
#   'American-gpe': 1,
#   'FBI-org': 66,
#   'NIT-org': 20,
#   'Playpen-org': 10,
#   'Department of Justice-org': 9,
#   'US-org': 8,
#   'Alfin-per': 10,
#   'Playpen-per': 6,
#   'Daniel Alfin-per': 4,
#   'Chase-per': 4,
#   'Colin Fieman-per': 3,
#   'Playpen-geo': 16,
#   'Sudan-geo': 7,
#   'Chile-geo': 4,
#   'Washington-geo': 3,
#   'Careem-geo': 3},
#  233: {'Calrissian-gpe': 1,
#   'Rise of Skywalker-org': 2,
#   'Star Wars Celebration-org': 2,
#   'Star Wars-org': 2,
#   'C3P0-org': 2,
#   'Star Wars Episode IX-org': 1,
#   'Finn-per': 2,
#   'George Lucas-per': 1,
#   'JJ Abrams-per': 1,
#   'Luke Skywalker-per': 1,
#   'Kylo Ren-per': 1,
#   'Rey-geo': 3,
#   'Poe-geo': 2,
#   'Chicago-geo': 1,
#   'Lando-geo': 1,
#   'Chewbacca-geo': 1},
#  234: {'MONDAY-org': 1,
#   'Reuters Walmart Inc WALMART WALMART U-org': 1,
#   'MILK-org': 1,
#   'EGGS-org': 1,
#   'HAND SANITIZER-org': 1,
#   'Danish-geo': 1},
#  235: {'Chinese-gpe': 442,
#   'Yuan-gpe': 9,
#   'American-gpe': 4,
#   'Iranian-gpe': 4,
#   'Japanese-gpe': 3,
#   "People's Bank of China PBOC-org": 262,
#   'MARKET Instrument Current Difference-org': 128,
#   'PBOC-org': 116,
#   "People's Bank of China-org": 48,
#   'Sino U-org': 46,
#   'Premium-per': 160,
#   'Winni Zhou-per': 141,
#   'Item Current Previous ChangeThomson-per': 100,
#   'President Donald Trump-per': 76,
#   'John Ruwitch-per': 59,
#   'China-geo': 403,
#   'Beijing-geo': 127,
#   'United States-geo': 118,
#   'Shanghai-geo': 114,
#   'Hong Kong-geo': 113},
#  236: {},
#  237: {'German-gpe': 1648,
#   'Italian-gpe': 931,
#   'Swiss-gpe': 886,
#   'French-gpe': 681,
#   'Chinese-gpe': 549,
#   'Deutsche Bank-org': 587,
#   'US-org': 457,
#   'UBS-org': 391,
#   'EU-org': 321,
#   'ECB-org': 279,
#   'Credit Suisse-per': 164,
#   'Goldman Sachs-per': 158,
#   'JP Morgan-per': 138,
#   'Arno Schuetze-per': 125,
#   'Thyssenkrupp-per': 108,
#   'Germany-geo': 733,
#   'Italy-geo': 705,
#   'Europe-geo': 701,
#   'China-geo': 611,
#   'Greece-geo': 361},
#  238: {},
#  239: {'Chinese-gpe': 103,
#   'German-gpe': 84,
#   'American-gpe': 45,
#   'Japanese-gpe': 43,
#   'Americans-gpe': 34,
#   'Google-org': 916,
#   'Apple-org': 463,
#   'Ford-org': 441,
#   'Waymo-org': 319,
#   'Uber-org': 287,
#   'Uber-per': 679,
#   'Waymo-per': 670,
#   'Mobileye-per': 92,
#   'Toyota-per': 77,
#   'Levandowski-per': 77,
#   'Tesla-geo': 767,
#   'Waymo-geo': 611,
#   'Arizona-geo': 562,
#   'California-geo': 525,
#   'San Francisco-geo': 295},
#  240: {'American-gpe': 1,
#   'US-org': 2,
#   'Hume Chicago-org': 1,
#   'Colabo-org': 1,
#   'Lauren Sudbrink Wish Piece and Open Heart Surgery Theatre In Silence From Dawn-org': 1,
#   'New York University-org': 1,
#   'Floor Rear-per': 4,
#   'Katie Waddell-per': 1,
#   'Nuit Blanche-per': 1,
#   'Waddell-per': 1,
#   'Till Dusk-per': 1,
#   'Chicago-geo': 2,
#   'Nuit Blanche-geo': 1,
#   'United States-geo': 1,
#   'Illinois-geo': 1,
#   'Indiana-geo': 1},
#  241: {'Americans-gpe': 17,
#   'Chinese-gpe': 13,
#   'Indian-gpe': 8,
#   'African-gpe': 5,
#   'American-gpe': 5,
#   'LGBT-org': 54,
#   'LGBTQ-org': 30,
#   'CNN-org': 20,
#   'Human Rights Campaign-org': 16,
#   'AIDS-org': 13,
#   'Thiel-per': 12,
#   'Obama-per': 11,
#   'Hikes-per': 8,
#   'Yann-per': 7,
#   'Rainbow Town-per': 7,
#   'North Carolina-geo': 32,
#   'India-geo': 22,
#   'United States-geo': 18,
#   'China-geo': 18,
#   'New York-geo': 16},
#  242: {'Chinese-gpe': 191,
#   'American-gpe': 106,
#   'Canadian-gpe': 65,
#   'British-gpe': 55,
#   'Australian-gpe': 50,
#   'Motherboard-org': 413,
#   'FBI-org': 221,
#   'US-org': 194,
#   'RCMP-org': 185,
#   'Ring-org': 179,
#   'Motherboard-per': 201,
#   'Amazon-per': 182,
#   'Smith-per': 73,
#   'Facebook-per': 60,
#   'Williams-per': 50,
#   'Amazon-geo': 316,
#   'China-geo': 299,
#   'Ring-geo': 215,
#   'California-geo': 177,
#   'United States-geo': 173},
#  243: {'German-gpe': 10,
#   'Swedish-gpe': 9,
#   'Knorr Bremse-org': 7,
#   'EGM-org': 3,
#   'EU-org': 3,
#   'Securities Council-org': 2,
#   'Reuters A-org': 1,
#   'Knorr Bremse-per': 13,
#   'ZF Friedrichshafen-per': 2,
#   'Haldex-per': 2,
#   'Klaus Deller-per': 1,
#   'Jorgen Durban-per': 1,
#   'Haldex-geo': 5,
#   'Knorr-geo': 2,
#   'Wabco-geo': 2,
#   'Knorr Bremse-geo': 1,
#   'Sweden-geo': 1},
#  244: {'American-gpe': 312,
#   'African-gpe': 289,
#   'Chinese-gpe': 167,
#   'Australian-gpe': 143,
#   'Americans-gpe': 126,
#   'Science Times-org': 650,
#   'DNA-org': 556,
#   'University-org': 216,
#   'University of California-org': 177,
#   "Daily Dispatch and Editor's Picks-org": 170,
#   'Homo-per': 103,
#   'Will Dunham-per': 97,
#   'Davis-per': 72,
#   'Smith-per': 64,
#   'Willerslev-per': 56,
#   'Africa-geo': 591,
#   'Earth-geo': 536,
#   'Europe-geo': 459,
#   'Australia-geo': 445,
#   'China-geo': 312},
#  245: {'Chinese-gpe': 3372,
#   'American-gpe': 1016,
#   'British-gpe': 246,
#   'Canadian-gpe': 196,
#   'German-gpe': 156,
#   'ZTE-org': 815,
#   'US-org': 751,
#   'Google-org': 413,
#   'Commerce Department-org': 404,
#   'CNBC-org': 324,
#   'Huawei-per': 1253,
#   'Trump-per': 384,
#   'Ericsson-per': 340,
#   'President Donald Trump-per': 233,
#   'Ren-per': 231,
#   'Huawei-geo': 8383,
#   'China-geo': 2351,
#   'United States-geo': 1935,
#   'Washington-geo': 685,
#   'Nokia-geo': 590},
#  246: {},
#  247: {},
#  248: {'Fitch-gpe': 101,
#   'Australian-gpe': 62,
#   'Mexican-gpe': 59,
#   'Chinese-gpe': 53,
#   'French-gpe': 49,
#   'AP-org': 191,
#   'Fitch-org': 139,
#   'US-org': 127,
#   'S P-org': 121,
#   'IDR-org': 88,
#   'Fitch-per': 119,
#   'Pemex-per': 57,
#   'IN ADDITION-per': 45,
#   'Status-per': 40,
#   'Long Term IDR-per': 39,
#   'Moody-geo': 70,
#   'China-geo': 63,
#   'Fitch-geo': 55,
#   'Email-geo': 45,
#   'Criteria-geo': 40},
#  249: {},
#  250: {'Russian-gpe': 419,
#   'American-gpe': 180,
#   'Canadian-gpe': 54,
#   'Chinese-gpe': 42,
#   'German-gpe': 36,
#   'NASA-org': 2306,
#   'ISS-org': 1070,
#   'Soyuz-org': 316,
#   'Boeing-org': 238,
#   'BEAM-org': 153,
#   'Whitson-per': 104,
#   'Scott Kelly-per': 83,
#   'Koch-per': 69,
#   'Trump-per': 53,
#   'Scott-per': 46,
#   'Earth-geo': 903,
#   'International Space Station-geo': 429,
#   'Mars-geo': 366,
#   'Russia-geo': 193,
#   'China-geo': 181},
#  251: {},
#  252: {'American-gpe': 154,
#   'German-gpe': 90,
#   'Chinese-gpe': 88,
#   'Americans-gpe': 76,
#   'British-gpe': 73,
#   'Google-org': 1120,
#   'Amazon-org': 341,
#   'Motherboard-org': 246,
#   'UAW-org': 189,
#   'CNBC-org': 175,
#   'Amazon-per': 392,
#   'Foxconn-per': 89,
#   'Trump-per': 80,
#   'Uber-per': 75,
#   'Prime-per': 62,
#   'Amazon-geo': 748,
#   'United States-geo': 272,
#   'California-geo': 265,
#   'Tesla-geo': 210,
#   'China-geo': 197},
#  253: {'Russian-gpe': 2,
#   'Indonesian-gpe': 2,
#   'Japanese-gpe': 2,
#   'Panamanians-gpe': 1,
#   'Panamanian-gpe': 1,
#   'Joint Institute for Nuclear Research-org': 3,
#   'Lawrence Livermore National Laboratory-org': 3,
#   'Panama Papers-org': 2,
#   'Iupac-org': 2,
#   'The International Union of Pure and Applied Chemistry IUPAC-org': 1,
#   'Astra Honda-per': 3,
#   'Yamaha Indonesia-per': 2,
#   'Iupac-per': 2,
#   'Kosuke Morita-per': 1,
#   'Ryoji Noyori-per': 1,
#   'Japan-geo': 7,
#   'Riken-geo': 4,
#   'Russia-geo': 3,
#   'California-geo': 2,
#   'Asia-geo': 2},
#  254: {'Japanese-gpe': 1,
#   'Microsoft-org': 2,
#   'Giving Pledge-org': 2,
#   "Bloomberg's Billionaires Index-org": 2,
#   'Gates Foundation-org': 1,
#   'World Health Organization-org': 1,
#   'Gates-per': 4,
#   'MacKenzie Bezos-per': 4,
#   'Bill-per': 3,
#   'Bill Gates-per': 2,
#   'Well-per': 2,
#   'Beijing-geo': 1,
#   'China-geo': 1,
#   'Glad Gates-geo': 1,
#   'Bezos-geo': 1,
#   'Amazon-geo': 1},
#  255: {'Chinese-gpe': 9,
#   'Swedish-gpe': 3,
#   'American-gpe': 2,
#   'Indian-gpe': 1,
#   'Mexican-gpe': 1,
#   'FDA-org': 55,
#   'CES-org': 42,
#   'NDEA-org': 23,
#   'NDMA-org': 20,
#   'Sony-org': 12,
#   'Calibri-per': 7,
#   'Follow Verge-per': 6,
#   'Zhejiang Huahai Pharmaceuticals-per': 5,
#   'Zhejiang Tianyu-per': 5,
#   'Adelle-per': 4,
#   'Helvetica-geo': 20,
#   'United States-geo': 12,
#   'Samsung-geo': 11,
#   'Lego-geo': 6,
#   'Hexoskin-geo': 5},
#  256: {'Japanese-gpe': 19,
#   'Korean-gpe': 17,
#   'Malaysian-gpe': 2,
#   'Singapore-org': 17,
#   'SK Hynix-org': 7,
#   'KS-org': 3,
#   'WTO-org': 3,
#   'JSR-org': 2,
#   'Kanto Denka Kogyo-per': 2,
#   'Nippon Steel-per': 2,
#   'David Dolan-per': 2,
#   'John Geddie-per': 2,
#   'Joyce Lee-per': 1,
#   'Japan-geo': 21,
#   'South Korea-geo': 16,
#   'Malaysia-geo': 6,
#   'Tokyo-geo': 5,
#   'Tuas-geo': 4},
#  257: {'Americans-gpe': 226,
#   'American-gpe': 178,
#   'British-gpe': 107,
#   'Japanese-gpe': 53,
#   'African-gpe': 46,
#   'PTSD-org': 325,
#   'OCD-org': 251,
#   'US-org': 228,
#   'MDMA-org': 192,
#   'UK-org': 163,
#   'Trump-per': 122,
#   'Well-per': 47,
#   'Brown-per': 47,
#   'John-per': 44,
#   'Hall-per': 42,
#   'New York-geo': 232,
#   'United States-geo': 187,
#   'Tonic-geo': 162,
#   'Instagram-geo': 159,
#   'California-geo': 146},
#  258: {'Chinese-gpe': 353,
#   'French-gpe': 245,
#   'American-gpe': 238,
#   'British-gpe': 203,
#   'Swiss-gpe': 172,
#   'Google-org': 2955,
#   'Apple-org': 952,
#   'Microsoft-org': 549,
#   'Uber-org': 512,
#   'CNBC-org': 472,
#   'Kalanick-per': 1079,
#   'Uber-per': 724,
#   'Trump-per': 509,
#   'Travis Kalanick-per': 337,
#   'Khosrowshahi-per': 312,
#   'China-geo': 633,
#   'Silicon Valley-geo': 630,
#   'Tesla-geo': 570,
#   'United States-geo': 430,
#   'Amazon-geo': 399},
#  259: {},
#  260: {'Americans-gpe': 368,
#   'American-gpe': 171,
#   'Chinese-gpe': 53,
#   'Canadian-gpe': 42,
#   'British-gpe': 42,
#   'FDA-org': 767,
#   'DEA-org': 390,
#   'US-org': 297,
#   'CDC-org': 245,
#   'Food and Drug Administration-org': 207,
#   'Johnson Johnson-per': 186,
#   'Trump-per': 156,
#   'Purdue Pharma-per': 114,
#   'President Donald Trump-per': 93,
#   'Sackler-per': 67,
#   'United States-geo': 625,
#   'Purdue-geo': 307,
#   'Purdue Pharma-geo': 290,
#   'Oklahoma-geo': 228,
#   'New York-geo': 221},
#  261: {'EPA-org': 6,
#   'Science Times-org': 3,
#   'Food Environment Reporting Network-org': 2,
#   'Adee-org': 2,
#   'Invertebrate Conservation-org': 1,
#   'Mackrill-per': 4,
#   'Coy-per': 3,
#   'Strogolov-per': 2,
#   'Zawislak-per': 2,
#   'Richard Coy-per': 1,
#   'Dicamba-geo': 5,
#   'Arkansas-geo': 4,
#   'California-geo': 4,
#   'North Dakota-geo': 4,
#   'Mortensen-geo': 3},
#  262: {},
#  263: {'Americans-gpe': 630,
#   'American-gpe': 537,
#   'British-gpe': 294,
#   'African-gpe': 177,
#   'Chinese-gpe': 116,
#   'Reuters Health-org': 1545,
#   'UK-org': 580,
#   'FDA-org': 550,
#   'US-org': 531,
#   'University-org': 492,
#   'Overall-per': 356,
#   'Chan School-per': 166,
#   'Andrew M-per': 136,
#   'Children-per': 98,
#   'Smith-per': 90,
#   'United States-geo': 939,
#   'Boston-geo': 382,
#   'New York-geo': 326,
#   'California-geo': 315,
#   'Canada-geo': 314},
#  264: {'Chinese-gpe': 194,
#   'Indian-gpe': 63,
#   'Russian-gpe': 61,
#   'Japanese-gpe': 54,
#   'German-gpe': 53,
#   'Google-org': 6206,
#   'Apple-org': 5798,
#   'Microsoft-org': 1645,
#   'App Store-org': 875,
#   'Facebook-org': 737,
#   'Siri-per': 548,
#   'Mac-per': 532,
#   'App Store-per': 262,
#   'Facebook-per': 238,
#   'Android-per': 220,
#   'Android-geo': 2374,
#   'Instagram-geo': 501,
#   'Samsung-geo': 452,
#   'Spotify-geo': 445,
#   'Gmail-geo': 430}}

# %%
filename = ('GLG/models/14passes_265_ents_dict(stripped_final).pkl')
pickle.dump(ner_dict_stripped,open(filename,'wb'))
