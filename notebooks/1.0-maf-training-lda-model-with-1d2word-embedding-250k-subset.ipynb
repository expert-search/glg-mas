# %%
import pandas as pd
import numpy as np
from nltk.tokenize import regexp_tokenize
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import gensim.corpora as corpora
import gensim
from datetime import datetime, timedelta
import time
import pickle
import pprint

import nltk
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fergu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\fergu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\fergu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### Model Topics Using LDA

# %%
''' This function takes in a df of pre-processed articles (or any other documents) and creates the
user-defined number of LDA topics. How many topics to use was a matter of trial and error, since any run of the function
took several hours, and so a rigorous determination as to the optimal number of topics was not practicable. 
There are  print statements throughout the code, just as a marker of progress and to show that this long-running 
algo is computing correctly'''

def lda_compute(df,num_topics,passes=7):
    start = time.time()
    print(f'The time is {datetime.now()}')
    # Define id2word
    id2word = corpora.Dictionary(df['article_words'])
    
    articles = df['article_words']
      
    corpus = [id2word.doc2bow(article) for article in articles]
         
    print('Now for LDA modeling...')
    
    # Instantiate LDA with desired # of topics and number of LDA passes
    lda_model = gensim.models.LdaModel(corpus=corpus,id2word=id2word,num_topics=num_topics,
                                           passes=passes,random_state=4)

    print('LDA done!')
    print('-' * 10)
    doc_lda = lda_model[corpus]
    
    
    lda_lists = [lda_model[article] for article in corpus]
    print(f'lda_lists[-1]: {lda_lists[-1]}')
    lda_coeffs = [[pair[1] for pair in article] for article in lda_lists]
    print(f'lda_coeffs[-1]: {lda_coeffs[-1]}')
    lda_inds = [[pair[0] for pair in article] for article in lda_lists]
    print(f'lda_inds[-1]: {lda_inds[-1]}')
    
    # Identify any 'rogue' rows where the LDA model was not able to assign any word to a topic
    rogues = [i for i in range(len(lda_inds)) if len(lda_inds[i])==0]
    
    lda_lists = [lda_lists[i] for i in range(len(lda_lists)) if i not in rogues]
    lda_coeffs = [lda_coeffs[i] for i in range(len(lda_coeffs)) if i not in rogues]
    lda_inds = [lda_inds[i] for i in range(len(lda_inds)) if i not in rogues]
    
    # Drop rogue rows as they will break further processing
    df.drop(rogues,inplace=True,axis=0)
    
    # Identify the lDA topic having the largest LDA coefficient
    # This will be considered the primary topic to which a given article 'belongs'
    lda_argmax = [np.argmax(tup) for tup in lda_coeffs]
      
    print(f'lda_argmax[-1]: {lda_argmax[-1]}')
    
    # Identify the main topic for every article
    lda_topics = [lda_inds[i][lda_argmax[i]] for i in range(len(lda_lists))]
    
    # Set a threshold for reporting any LDA topics beyond the primary one. 
    # Example: If primary topic has an LDA coeff of 0.60 and the sec_threshold is set to 0.5, 
    # any other topic would have to have an LDA coeff >= 0.3 to be considered a secondary topic. 
    # In this example, there can only be (at most) one secondary topic. If the primary topic had a 
    # lower LDA coeff, there could potentiallly be multiple secondary topics
    sec_threshold = 0.5
    

    # Define secondary topics (if any) according to the above criterion.
    secondary_topics = [[pair[0] for pair in lda_lists[i] if 1 > pair[1] / lda_coeffs[i][lda_argmax[i]] >= sec_threshold] for i in range(len(lda_lists))]
    
    # Put the primary and secondary topics into our dataframe
    df['lda_topic'] = lda_topics    
    df['other_topics'] = secondary_topics   
    
    interval = round((time.time() - start)/60,2)
    print(f'That  took {interval} mins.')
    return df, lda_model, corpus#, doc_lda

# %%
id2word = corpora.Dictionary(df_ht['article_words'])
filename = 'models/id2word_265.pkl'
pickle.dump(id2word,open(filename,'wb'))

# %%
# Run LDA on the dataset, setting desired number of topics and passes
df_ht, lda_model, corpus = lda_compute(df_ht,num_topics=265,passes=14)
# Out:
# Now for LDA modeling...
# LDA done!
# ----------
# lda_lists[-1]: [(26, 0.06111979), (33, 0.05380561), (60, 0.011781786), (61, 0.15894896), (93, 0.08945436), (96, 0.083074786), (110, 0.01735857), (114, 0.01212051), (120, 0.01918941), (158, 0.027230652), (167, 0.01825403), (188, 0.021116503), (201, 0.035287004), (222, 0.019063195), (235, 0.015335164), (252, 0.24858978), (257, 0.033509772), (260, 0.019460177)]
# lda_coeffs[-1]: [0.06111979, 0.05380561, 0.011781786, 0.15894896, 0.08945436, 0.083074786, 0.01735857, 0.01212051, 0.01918941, 0.027230652, 0.01825403, 0.021116503, 0.035287004, 0.019063195, 0.015335164, 0.24858978, 0.033509772, 0.019460177]
# lda_inds[-1]: [26, 33, 60, 61, 93, 96, 110, 114, 120, 158, 167, 188, 201, 222, 235, 252, 257, 260]
# lda_argmax[-1]: 15
# That  took 297.55 mins.

# %%
# Save df, model for later use
df_ht.to_csv('models/14passes_265_topics_df_ht_lda.csv')
lda_model.save('models/14passes_265_topics_ldamodel_ht')

# %%
df_ht.head(2)
# Out:
#    Unnamed: 0 Unnamed: 0.1                 date  year  month day  \
# 0           7            7  2018-05-02 17:09:00  2018    5.0   2
# 1          41           41  2018-10-05 19:35:00  2018   10.0   5
#
#               author                                              title  \
# 0  Caroline Williams   You Can Trick Your Brain Into Being More Focused
# 1   Caroline Haskins  Trash Geyser Spews Garbage In Yellowstone Nati...
#
#                                              article  \
# 0  If only every day could be like this. You can’...
# 1   Geyser eruptions are known as one of the most...
#
#                                                  url       section  \
# 0  https://www.vice.com/en_us/article/9kgp4v/how-...        Health
# 1  https://www.vice.com/en_us/article/evwq47/ear-...  Tech by VICE
#
#   publication                                      article_words  lda_topic  \
# 0        Vice  [every, day, could, like, put, finger, maybe, ...        257
# 1        Vice  [geyser, eruption, know, one, beautiful, event...        227
#
#      other_topics
# 0  [61, 166, 227]
# 1              []

# %% [markdown]
# ### Naming Topics
# Once LDA modeling is complete, we have to read through a sample of article titles, in order to discern a unifying theme and give an appropriate name to each topic. These topic names are added to a master dictionary. When predicting on test data, the numerical model output in the form of an LDA topic number, is mapped to a meaningful name according to the topic dictionary.

# %%
df_ht = pd.read_csv('models/14passes_265_topics_df_ht_lda.csv')

# %%
filename = 'models/14passes_265_topics_dict.pkl'
with open(filename,'wb') as file:
    pickle.dump(topics_dict,file)

# %%
# Import trained LDA model
lda_model = gensim.models.ldamodel.LdaModel.load('models/14passes_265_topics_ldamodel_ht')

# %%
print(lda_model)
# Out:
# LdaModel(num_terms=430329, num_topics=185, decay=0.5, chunksize=2000)

# %%
# A version of the hand-labeled topic dictionary

topics_dict = {0:'mexican telecommunications',1:'education & student life',2:'tfr',3:'intl big business',
               4:'drugs, clinical trials, approvals',5:'robots & robotics',6:'indian tech & business',7:'meat substitutes',
               8:'fish',9:'israeli tech & business',10:'tech m&a',11:'11',12:'lodging marketplaces',13:'laptops, mobile devices, gadgets',
               14:'audio tech',15:'climate science',16:'intl govt relations',17:'digital advertising',18:'tfr',19:'marijuana & CBD',
               20:'ridesharing services e-scooters & e-bikes',21:'tfr',22:'wireless charging technology',23:'diversity & discrimination',
               24:'basketball',25:'mass transit',26:'e-commerce & online delivery',27:'european alternative energy',28:'menstrual health',
               29:'cancer treatments & trials',30:'tfr',31:'apple devices',32:'motor racing',33:'food poisoning, allergies, household chemicals',
               34:'health insurance & washington legislation',35:'asian business',36:'astrophysics',37:'chinese big business',
               38:'latino-american business',39:'international trade, subsidies & tariffs',40:'automotive technology',41:'tfr',
               42:'virtual reality',43:'organ donation',44:'audio streaming and apps',45:'photo & video sharing',
               46:'virtual assistants, smart home tech',47:'',48:'international oil & gas',
               49:'data breaches & data privacy',50:'livestock viral diseases',51:'skincare',
               52:'endangered species, illegal animal trading',53:'tfr',54:'data protection & govt intervention',55:'food & diet',
               56:'ice hockey',57:'tfr',58:'tfr',59:'incarceration',60:'government legislation',61:'6',62:'power & renewable energy',
               63:'drones & unmanned aerial tech',64:'5g % mobile networks',65:'global big business',66:'fitness, exercise & diet',
               67:'us politics',68:'mid-east business',69:'mood disorders',70:'studies and polls',71:'autonomous vehicles',
               72:'product recalls',73:'73',74:'big business earnings',75:'facebook govt intervention',76:'tv and movies',
               77:'hacks & data theft',78:'gaming platforms',79:'dakota',80:'astrophysics',81:'global currency, equity and fixed income',
               82:'brazilian/french business',83:'italian politics',84:'tfr',85:'battery technology',86:'tfr',87:'tech investments, vc, new initiatives',
               88:'plants & trees',89:'guns and shootings',90:'venezuelan business',91:'space exploration',92:'sleep health',
               93:'infectious diseases',94:'big tech govt intervention',95:'sexual assault & harassment',96:'fake news, misinformation, dangerous online content',
               97:'tfr',98:'tfr',99:'uk',100:'tfr',101:'cryptocurrency',102:'human rights in developing world',103:'health aspects of body art',104:'tfr',
               105:'asia activism',106:'twitter',107:'cybersecurity',108:'infant nutrition',109:'mining',110:'cities & urban life',111:'mid-east politics, terrorism',
               112:'art and design',113:'wearable devices',114:'food delivery',115:'tfr',116:'north korea politics',117:'smoking, vaping & e-cigs',
               118:'gene editing, genetic engineering',119:'water resources',120:'bloodborne diseases & vaccines',121:'australasian business',
               122:'international equities/derivatives',123:'sports/esports',124:'rare earth minerals',125:'intl politics',
               126:'cutting-edge mobile devices, gadgets',127:'disney',128:'tfr',129:'quantum computing',130:'intl macroeconomics',
               131:'fintech & payments',132:'weed & legal matters',133:'puerto rico',134:'tfr',135:'microsoft apps, os, devices',136:'medical devices',
               137:'telecoms networks & providers',138:'intl banking & finance',139:'financial markets',140:'smartphone tech',
               141:'medical devices',142:'earth sciences',143:'global currency, equity and fixed income',144:'faang',145:'tfr',146:'sports',
               147:'climate science & technology',148:'148',149:'price movements & fluctuations',150:'baseball',151:'meteorology',152:'151',
               153:'aliens',154:'tfr',155:'automotive technology',156:'tech investments, vc, new initiatives',157:'artificial intelligence',
               158:'158',159:'tfr',160:'chips & processors',161:'tfr',162:'astronomy & astrophysics',163:'bacteria & viruses',164:'intl stock markets',
               165:'tfr',166:'the human brain',167:'fashion & apparel',168:'tfr',169:'tfr',170:'tfr',171:'tfr',172:'blood and blood diseases',
               173:'tfr',174:'global currency, equity and fixed income',175:'software/service glitches, bugs & outages',176:'tfr',177:'video games',
               178:'natural & man-made disasters',179:'tech investments, vc, new initiatives',180:'tfr',181:'nuclear tech',182:'tfr',183:'artificial intelligence',
               184:'tfr',185:'sex and relationships',186:'tfr',187:'commodities, natural resources',188:'clinical care',189:'sports',190:'european macroeconomics',
               191:'19',192:'intl banking & finance',193:'african govt affairs',194:'canadian business',195:'tfr',196:'tfr',197:'mid-east oil & gas',
               198:'emoji',199:'big business earnings',200:'bloodborne diseases & vaccines',201:'tfr',202:'tfr',203:'litigation & court rulings',
               204:'tfr',205:'tfr',206:'messaging platforms',207:'aviation & aerospace',208:'video games',209:'tfr',210:'amazon',
               211:'birth control & reproductive health',212:'212',213:'european business',214:'marine life & maritime affairs',215:'215',
               216:'216',217:'217',218:'tfr',219:'code & software',220:'co-working spaces',221:'221',222:"children's health",
               223:'computer peripherals',224:'astronomy & astrophysics',225:'tfr',226:'animals',227:'video games',228:'tfr',229:'international oil & gas',
               230:'satellites & rockets',231:'marine life & maritime affairs',232:'dark web & online privacy',233:'tfr',234:'supermarkets',
               235:'global currency, equity and fixed income',236:'tfr',237:'tech investments, vc, new initiatives',238:'tfr',239:'autonomous vehicles',       
               240:'tfr',241:'lgbtq issues',242:'surveillance tech',243:'tfr',244:'ecology, environment & archaeology',245:'mobile networks, carriers & eqpt',
               246:'tfr',247:'tfr',248:'global currency, equity and fixed income5',249:'tfr',250:'space exploration',251:'tfr',
               252:'employment issues',253:'tfr',254:'tfr',255:'cutting-edge mobile devices, gadgets',256:'256',257:'mental health & disorders',
               258:'executive level management',259:'tfr',260:'prescription drugs',261:'bees',262:'tfr',263:'experimental studies',
               264:'apps, gadgets & devices'
    
              }

# %%
filename = 'models/topics_dict.pkl'
pickle.dump(topics_dict,open(filename,'wb'))

# %%
# Iterate through the LDA topics
# For each topic, print out a number of article titles and try to discern a common theme 
# Name the topic accordingly
n = 61

test_df = df_ht[df_ht['lda_topic'] == n]
print(f'{len(test_df)} records:','\n','*' * 10)
for i in range(550):
    try:      
        print(test_df.iloc[i,8])
        print(test_df.iloc[i,11])
        print('-' * 15)
    except:
        break
# Out:
# 7623 records:
#  **********
# Discussing the Enduring Appeal of Abe with Oddworld Creator Lorne Lanning
# Games
# ---------------
# In Search for Any Excuse But Guns, Trump to Meet With Video Game Industry
# Games
# ---------------
# Shortages of Injectable Estrogen Are Screwing Over Trans Women
# Health
# ---------------
# What Are Whip Its? The Side Effects and Dangers of Doing Them
# Health
# ---------------
# I Worry That Everything I Eat Is Going to Give Me Food Poisoning
# Health
# ---------------
# Bloggers, Rejoice: Gage Skidmore Is at CPAC
# Tech by VICE
# ---------------
# ​Letters to the Editor: Waze Politics and Very Expensive Bicycles
# Tech by VICE
# ---------------
# Meet the 28-Year-Old Geneticist Fighting the Future of Superbugs
# Health
# ---------------
# Is It Worse to Sit or Squat on a Public Toilet?
# Health
# ---------------
# 19 Everyday Things That Trigger My OCD
# Health
# ---------------
# The Creator of the First Online Dating Site Is Still Dating Online
# Tech by VICE
# ---------------
# The Case for Giving Everyone Free Money
# Tech by VICE
# ---------------
# How Airlines Fell in Love with In-Flight Movies, and Why They're Breaking Up
# Tech by VICE
# ---------------
# What Porn Stars Look for When They Google Each Other
# Tech by VICE
# ---------------
# Doomsday Prepper Supply Companies Are the Real Winners of the Election
# Tech by VICE
# ---------------
# Adventures with Conspiracy Theorists, Aliens, and Robots
# Tech by VICE
# ---------------
# Tim Caulfield Tackles Wellness Hoaxes in 'A User's Guide to Cheating Death' on Netflix
# Health
# ---------------
# Meet the Domestic Robots Who Will Be Co-Parenting Your Kids
# Tech by VICE
# ---------------
# This 30-Second Video Can Teach You to Save Someone's Life
# Health
# ---------------
# What It's Like to Be a Popular 'Weird Twitter' Personality
# tech
# ---------------
# A Canadian Man Is Pissed That His Son Ran Up an $8,800 Xbox Bill in FIFA Purchases
# Games
# ---------------
# The Mental Health Effects of Being a Plane Crash Investigator
# Health
# ---------------
# The Secret Chatrooms Where Donald Trump Memes Are Born
# Tech by VICE
# ---------------
# We Asked Young People Who Should Pay for the Pill
# Health
# ---------------
# You Need Money to Make Money as a PC Building Star on YouTube
# Tech by VICE
# ---------------
# A New Mental Healthcare Law Would Help My Suicidal Partner
# Health
# ---------------
# 'I'm Not Trying to Be Hardcore About Running Through Chemo'
# Health
# ---------------
# Obama's EPA Head Is Very Worried About Our Health
# Tech by VICE
# ---------------
# I Survived a Suicide Attempt in Jail
# Health
# ---------------
# A Co-Creator of Know Your Meme Explains What the Hell a Meme Actually Is
# Tech by VICE
# ---------------
# Augmented Reality Will Take Off As Soon As It Doesn't Look Silly
# Tech by VICE
# ---------------
# The Best Part of Flying Business Class Isn't Quite What You Think
# Tech by VICE
# ---------------
# 'We're Totally Fucked': Scientists Explain Why They're Running for Office
# Tech by VICE
# ---------------
# There's A Gene Test That Tells You Which Antidepressant Will Work Best
# Health
# ---------------
# The People with Schizophrenia Embracing the Voices They Hear
# Health
# ---------------
# I Asked Experts to Explain Why I Orgasm When I Work Out
# Health
# ---------------
# What Do Game Developers Actually Get Out of Game Conventions?
# Games
# ---------------
# Why It's (Usually) Okay to Charge Your Phone Overnight
# Tech by VICE
# ---------------
# This Scientist Is Letting an Insect Grow in Him as a Rite of Passage
# Tech by VICE
# ---------------
# Pregnant Researchers Often Get No Lab Safety Guidance
# Tech by VICE
# ---------------
# UPDATE 1-Trump says did not send message to Tehran warning of attack
# Energy
# ---------------
# Here's the Teaser Trailer for 'Star Wars: The Last Jedi'
# Tech by VICE
# ---------------
# How Bad Is it if I Don't Use Soap When I Scrub a Dish?
# Health
# ---------------
# Self-Driving Cars Will Soon Be Programmed to Decide if They Should Kill You
# Tech by VICE
# ---------------
# The Moms Who Smoke Pot While Pregnant
# Health
# ---------------
# CryptoKitties Maker on $100,000 Digital Cats: 'It's Crazy'
# Tech by VICE
# ---------------
# Why Are Can Openers Still a Thing?
# Tech by VICE
# ---------------
# Chile’s ‘Uber of Recycling’ Is Sparking a Recycling Revolution
# Tech by VICE
# ---------------
# An NYC Couple Keeps Getting Letters for Santa, So They Asked Facebook for Help
# Motherboard
# ---------------
# An Amateur’s Guide to Taking Photos of the Perseid Meteor Shower
# Tech by VICE
# ---------------
# This Twitter Bot Tracks Nuclear Waste Criss-Crossing Britain By Rail
# Tech by VICE
# ---------------
# As Long As It Has 10 Fingers and Toes—and No Balls
# Health
# ---------------
# The Astonishing Failure of the Toy Company That Made Teddy Ruxpin
# Tech by VICE
# ---------------
# Remember When You Called Someone and Heard a Song?
# Tech by VICE
# ---------------
# Four Ways We Can Shorten the Organ Donor Waitlist
# Health
# ---------------
# These Invincible 'Super Rats' Are Genetically Resistant to Poison
# Tech by VICE
# ---------------
# Frustrated Spouses Keep Trying to Get Around This Porn-Blocking App
# Tech by VICE
# ---------------
# Can Slim People’s Poop Treat Obesity?
# Tech by VICE
# ---------------
# How Gross Is It to Let My Dog Sleep Next to Me?
# Health
# ---------------
# How to Find a Chiropractor Who Won’t Mess You Up
# Health
# ---------------
# Mastodon Is Like Twitter Without Nazis, So Why Are We Not Using It?
# Tech by VICE
# ---------------
# Why One Man Let Mosquitoes Bite Him 200 Times
# Health
# ---------------
# Meet the Woman Who Created a Coffee for Dogs Called ‘Rooffee’
# Tech by VICE
# ---------------
# An Interview with the Guy Who Invented My Antidepressants
# Health
# ---------------
# Bill Clinton Is 'Almost Certain' Hillary Is Healthier Than Donald Trump
# Health
# ---------------
# Joe Biden Tore into Trump for His Comments About PTSD
# Health
# ---------------
# E-Waste Recycler Heading to Prison: 'I Live For' Recycling and Right to Repair
# Tech by VICE
# ---------------
# A Weed Newbie's Guide to Legal Marijuana
# Tech by VICE
# ---------------
# iPhone X Teardown: The Logic Board Is Tiny and the Battery Is Gigantic
# Tech by VICE
# ---------------
# The Nebraska Zine Fest Turning Makers into Activists | #50StatesofArt
# Tech by VICE
# ---------------
# Will Cracking My Knuckles Give Me Arthritis?
# Health
# ---------------
# How Anti-Terrorism Tactics Are Being Used to Fight Elephant Poaching
# Tech by VICE
# ---------------
# We Spent an Hour Talking to Hello Games About Everything ‘No Man’s Sky’
# Games
# ---------------
# Why Counterfeit Lightning Cables Kill iPhones
# Tech by VICE
# ---------------
# America's Trippiest Chemist: Making Psychedelics 'Was Fun'
# Tech by VICE
# ---------------
# This Is Why People Constantly Flake on Their Plans
# Health
# ---------------
# ‘Evangelion’ Won't Stop Leering as It Explores Its Characters’ Sexuality
# Games
# ---------------
# Is the Five-Second Rule Legit?
# Health
# ---------------
# Check Out New Video Series and  Talk About Them On Our Forums All Week
# Games
# ---------------
# You Thought ‘Dark Souls’ Was Tough? Try Being the Guys Behind Its Official Guide
# Games
# ---------------
# New Dads Tell Us What Freaked Them Out in the Delivery Room
# Health
# ---------------
# Is This Photo Real or Fake?
# Tech by VICE
# ---------------
# How Games, Piracy, and Religion Come Together in Saudi Arabia
# Games
# ---------------
# Caregiver Forums Are Depressing, But They're Supposed to Be Depressing
# Health
# ---------------
# Inside the Fidget Spinner Gold Rush
# Tech by VICE
# ---------------
# We Asked People Which STI They're the Most Afraid Of
# Health
# ---------------
# Motherboard Is Not Spam
# Tech by VICE
# ---------------
# Help! I Found an SSRI That Works, but Now I Can't Cum
# Health
# ---------------
# The Exhausting Ten-Year Journey to Release 'Owlboy'
# Games
# ---------------
# How to Remove Political Rants from Your Facebook News Feed
# Tech by VICE
# ---------------
# Surprise! Scans Suggest Hackers Put IMSI-Catchers All Over Defcon
# Tech by VICE
# ---------------
# 10 Years Ago, I Almost Got Someone Fired While Reporting a Story
# Games
# ---------------
# Google Security Engineer Claims Android Is Now as Secure as the iPhone
# Tech by VICE
# ---------------
# I’ve Somehow Become Embroiled In a Byzantine VPN Scam
# Tech by VICE
# ---------------
# Why Do I Sweat a Puddle Every Night?
# Health
# ---------------
# The Museum of the Future Links Us to the Past
# Tech by VICE
# ---------------
# Britain warns of accidental war between United States and Iran
# Industrials
# ---------------
# Two Skaters Saved Some Kids Who Fell Through a Frozen Lake While Trying to Take a Selfie
# Tech by VICE
# ---------------
# ​This Is What Will Happen to Williamsburg Without the L Train
# Tech by VICE
# ---------------
# Kim Jong-un Travels With His Own Toilet to Protect His Feces
# Health
# ---------------
# Medical Marijuana Is Now Legal in Ohio
# Health
# ---------------
# The Switch and I: Early Adopters of Nintendo’s Console on its Joys and Cons
# Games
# ---------------
# What It's Like to Go on Antidepressants Before Puberty
# Health
# ---------------
# Digital Banks Are Moving Past the Idea of Passing Around Paper Money
# Tech by VICE
# ---------------
# This Website Proves That Getting into Berghain Really Is Virtually Impossible
# Tech by VICE
# ---------------
# How This Guy Won 1,000 Contests on Twitter
# Tech by VICE
# ---------------
# ‘No Man’s Sky’ Designer Sean Murray on New Gaming Horizons and Never Giving Up
# Games
# ---------------
# I Rented All the Expensive Tech I Can't Afford
# Tech by VICE
# ---------------
# Some Runners Feel Totally Lost After a Big Race
# Health
# ---------------
# I Outsourced My Social Media Presence to a Virtual Assistant for 48 Hours
# Tech by VICE
# ---------------
# Carl Zimmer Wants Us To Be Generous About Our Definition of Heredity
# Health
# ---------------
# Trying to Be Creative When You're on Antidepressants Isn't Easy
# Health
# ---------------
# Game Developers Speak Up in the Face of Obamacare Repeal
# Games
# ---------------
# Oh, You Forgot To Buy Your Drone a $189 Sweater for Christmas?
# Tech by VICE
# ---------------
# Here's the Full Transcript of Our Interview With DNC Hacker 'Guccifer 2.0'
# Tech by VICE
# ---------------
# A Big Phone Works for Everyone But You
# Tech by VICE
# ---------------
# How Drug Cartels Operate Like Silicon Valley Startups
# Tech by VICE
# ---------------
# Greta Van Susteren Is Using Sexual Harassment Scandals to Promote Her ‘Sorry’ App
# Tech by VICE
# ---------------
# Ten Questions You Always Wanted to Ask a Festival Security Guard
# Tech by VICE
# ---------------
# How ‘Bionic’ Sheep Could Be Armed Against Wolf Attacks
# Tech by VICE
# ---------------
# How to Determine If Solar Panels Make Sense for You
# Tech by VICE
# ---------------
# Skinning Human Bodies in Dr. Death's Taxidermy Lab
# Tech by VICE
# ---------------
# Brian Shared His Steam Account With His Dad. Then His Dad Stole It.
# Games
# ---------------
# The Man Who Turned His Parkinson's into an Art Project
# Health
# ---------------
# An Original iPhone Designer Embarks on Life After Apple
# Tech by VICE
# ---------------
# 'I See You': A Domestic Violence Survivor Talks About Being Surveilled By Her Ex
# Tech by VICE
# ---------------
# Don't Reward Nintendo For This SNES Classic Pre-Order Bullshit
# Games
# ---------------
# In Conversation with the King of Game Boy 'Tetris'
# Games
# ---------------
# I Got a $600 Brain 'Reboot' and It Changed My World
# Health
# ---------------
# Don’t Talk Trash on Slack
# Tech by VICE
# ---------------
# We Asked Young People About Losing Their Insurance Over Pre-Existing Conditions
# Health
# ---------------
# Valve Reveals 'Dota' Card Game to Disappointed Fans at The International
# Games
# ---------------
# How People with ADHD Deal with Constant Smartphone Notifications
# Health
# ---------------
# E3 Opened to the Public, and the Public Loved It
# Tech by VICE
# ---------------
# Future Home of the Living God
# Tech by VICE
# ---------------
# How Scared Should I Be of the Rise in STDs?
# Health
# ---------------
# These Devices Are Trying To Secure The Internet of (Hackable) Things
# Tech by VICE
# ---------------
# What Keeps ‘The Handmaid’s Tale’ Creators and Stars Up at Night
# Tech by VICE
# ---------------
# These Common Meds Could Make You More Likely to Get Sunburned
# Health
# ---------------
# Localizing Video Games for Different Markets Is a Minefield
# Tech by VICE
# ---------------
# Europe Is Spooked by America's Proposed Laptop Ban on Planes
# Tech by VICE
# ---------------
# Ten Questions for a Woman Who Remembers Every Moment of Her Life
# Tech by VICE
# ---------------
# This Student Is Getting Death Threats over a Gnarly Hand Dryer Experiment
# Tech by VICE
# ---------------
# Please Stop Ripping Off This Artist’s Sloth Drawing
# Tech by VICE
# ---------------
# Farmers Use Slack and Share Memes At Work, Too
# Tech by VICE
# ---------------
# The Graveyard Shift: We Talked to a Vice Night Editor About New York at 3 AM
# Tech by VICE
# ---------------
# How to Make a Pair of DIY Glasses to View the Solar Eclipse
# Tech by VICE
# ---------------
# Inventors of a Real Hoverboard Are Annoyed You Call ‘Hoverboards’ Hoverboards
# Tech by VICE
# ---------------
# Cryptocurrency Miners Are 'Limiting' the Search for Alien Life
# Tech by VICE
# ---------------
# You Had to Be a Little Insane to Be a Surgeon in the 1800s
# Health
# ---------------
# To Solve a Medical Mystery, This Doctor Drank Live Bacteria
# Tech by VICE
# ---------------
# The Company Making ‘Transformers’ from Luxury Cars Wants Everyone to Have One
# Tech by VICE
# ---------------
# This Teen Hacked 150,000 Printers to Show How the Internet of Things Is Shit
# Tech by VICE
# ---------------
# Can You Get Cancer from the Occasional Cigarette?
# Health
# ---------------
# Stop Calling the Police About This Crocodile Because It’s Just a Tire
# Tech by VICE
# ---------------
# What I Learned from Teaching High Yoga
# Health
# ---------------
# In Conversation with Nolan North and Troy Baker, the De Niro and Pacino of Video Games
# Games
# ---------------
# College Professors Are Using Smart Drugs to Grade Your Crappy Essays
# Health
# ---------------
# Apple’s Third Co-Founder Has Never Used an iPhone and Has No Regrets
# Tech by VICE
# ---------------
# The Plan to Shut Gitmo and Turn It Into an Ocean Research Lab
# Tech by VICE
# ---------------
# Americans Laugh and Cheer as Billionaire Fails to Guess the Price of Basic Household Items
# Tech by VICE
# ---------------
# What Cons Are Like When You're a Famous Cosplayer
# Games
# ---------------
# ​Can You Get Herpes from a Tanning Bed?
# Health
# ---------------
# A Thermostat, a Meditation On Humanity
# Tech by VICE
# ---------------
# A Guide to Making Your Own Tweeting Plant
# Tech by VICE
# ---------------
# Company Behind Disastrous Fyre Festival Warned Staff Not to Come
# Tech by VICE
# ---------------
# How Nextbit’s Robin Smartphone Uses the Cloud to Eliminate Storage Space Anxiety
# Tech by VICE
# ---------------
# I Tried to Turn an AI Bot into My BFF
# Tech by VICE
# ---------------
# Google’s Forgotten Service: How FeedBurner Became a Zombie
# Tech by VICE
# ---------------
# Canada Might Finally Reopen Its Prison Farms
# Tech by VICE
# ---------------
# Here’s a First Look at Elon Musk’s Ambitious Underground Tunnel Company
# Tech by VICE
# ---------------
# I Grew as a Person and It Sucks
# Health
# ---------------
# We Talked to the Creator of PokéVision About Losing 50 Million Users Overnight
# Tech by VICE
# ---------------
# The Truth About Organic Lubes
# Health
# ---------------
# Breaking Up Is Hard—Especially With Your Cable Company
# Tech by VICE
# ---------------
# Sec. of Transportation: US Has a 'Responsibility' to Support Hyperloop Research
# Tech by VICE
# ---------------
# A Yoga Sensation on Fitness, Fatness, and Trump
# Health
# ---------------
# What Should Parents Do When Their Kid's Favorite YouTuber Gets Racist?
# Games
# ---------------
# What It's Like to Date When You're Straight and HIV Positive
# Health
# ---------------
# PC Gaming Is Still Way Too Hard
# Tech by VICE
# ---------------
# How Psychedelics Helped Me Deal with Excruciating Cluster Headaches
# Health
# ---------------
# I Played 5 Professionally-Designed Drinking Games
# Games
# ---------------
# The Store of the Worlds
# Tech by VICE
# ---------------
# When a Game Just Feels Like Home
# Games
# ---------------
# I Tried ‘Free Bleeding’ and It Wasn’t a Total Disaster
# Health
# ---------------
# What It’s Like to Be a Cancer Patient on the Obamacare Repeal Rollercoaster
# Health
# ---------------
# T-Boz is Not Here for People Trolling Her About Illness or Trump
# Health
# ---------------
# The Only Thing That Will Save $150M In Locked Ethereum Is a Hard Fork
# Tech by VICE
# ---------------
# Human Enhancement is Happening Whether You Like it or Not
# Health
# ---------------
# Cancer, November 2016
# Cancer
# ---------------
# Google Trends Proves the Holiday Season Began Too Damn Early Again
# Tech by VICE
# ---------------
# Just How Big Has the Internet Become?
# Tech by VICE
# ---------------
# CES Attendees Get Crash Course in What’s Worth Being Paranoid About
# Tech by VICE
# ---------------
# These Apps Can Help You Finally Cancel That Subscription You Keep Forgetting
# Tech by VICE
# ---------------
# What the Future of HPV Looks Like Under Trump
# Health
# ---------------
# Inside Nintendo's Plan To Save Video Games From Congress
# Games
# ---------------
# How a 'World of Warcraft' Shitpost Gave This Streamer a Shot at His Dream
# Games
# ---------------
# 'Tacoma' Makes Space Feel Personal
# Games
# ---------------
# This Charger that Says 'Jews' Is Today's Tech Fail
# Tech by VICE
# ---------------
# What to Do if Your Partner Dies During Sex
# Health
# ---------------
# Here’s Who Should Get a Health Plan With a High Deductible
# Health
# ---------------
# Bug in Domino's Pizza App Allowed Hackers to Get Free Pizza for Life
# Tech by VICE
# ---------------
# In the Company of Heroes: An Interview with ‘Overwatch’ Designer Jeff Kaplan
# Games
# ---------------
# Artists Ai Weiwei and Kevin Abosch Are Using the Blockchain to Make Us Question What’s ‘PRICELESS’
# Tech by VICE
# ---------------
# Floridians Are Coping With Irma Using Memes and Fake Facebook Events
# Tech by VICE
# ---------------
# Dark Illustrations Show an Artist's Battle with Mental Illness
# Health
# ---------------
# Spend All of Jeff Bezos’ Money In This Choose-Your-Own-Adventure Game
# Tech by VICE
# ---------------
# We Talked to the Scholar Who Just Got $2.3 Million to Study Games
# Tech by VICE
# ---------------
# How Dangerous Is it to Black Out From Alcohol?
# Health
# ---------------
# Motherboard and iCracked Are Tearing Down an iPhone 7 on Facebook Live
# Tech by VICE
# ---------------
# Was It Wrong for Scientists to Create a Pig-Human Hybrid Embryo?
# Health
# ---------------
# This Is What It's Like to Be a Drunkorexic
# Health
# ---------------
# I Tried To Figure Out If A Controversial Illness Was “Real” or Not
# Health
# ---------------
# A Good Bundle Offers Games for Actual Change
# Games
# ---------------
# Indie Puzzle Game 'Hue' Is Unfinished but Still Highly Addictive
# Games
# ---------------
# What’s Round and Always in Do-Not-Disturb Mode? The ‘Anti-Smartphone’
# Tech by VICE
# ---------------
# How to Shrink the Entire Star Trek Galaxy
# Games
# ---------------
# This Woman Tried to Make Friends by Living Off the Sharing Economy for a Year
# Tech by VICE
# ---------------
# Mammogram Machines Can Make You ‘Feel Like You’re from Another Planet’ When You’re Disabled
# Tech by VICE
# ---------------
# The Makers of ‘Everybody’s Gone to the Rapture’ Reflect on Happiness and Horrors
# Games
# ---------------
# Why You Should Stop Trying to Please Everyone, by Me, an Autistic Woman
# Health
# ---------------
# The Sexual Assault News Cycle Is Hell for Survivors
# Health
# ---------------
# Artist Marcus Lyall is Working on a Concept that Could Change the Way We Drive
# Tech by VICE
# ---------------
# My Life As a Full-Time Human Guinea Pig
# Health
# ---------------
# The Importance of Play, Games, and Community in Dark Political Times
# Games
# ---------------
# What You Should Know Before Getting a Tattoo, According to Doctors
# Health
# ---------------
# People Tell Us the Stories Behind Their Most Gruesome Scars
# Health
# ---------------
# Twitter is Streaming the Conventions—and It Makes Perfect Sense
# Tech by VICE
# ---------------
# 'Conductrix' Is Like 'Guitar Hero' for Conducting an Orchestra
# Tech by VICE
# ---------------
# This Neuroscientist Wants Researchers to Study More Female Brains
# Tech by VICE
# ---------------
# Meet Instagram's Subway Surfing Daredevils
# Tech by VICE
# ---------------
# Turks Are Flocking to Tor After Government Orders Block of Anti-Censorship Tools
# Tech by VICE
# ---------------
# In the Future, the Holocaust Is Just Another Hologram
# Tech by VICE
# ---------------
# Barbie Now Has a Giant Tardigrade Steed
# Tech by VICE
# ---------------
# Coroners Might Be Hiding the Truth About Overdose Deaths
# Health
# ---------------
# My Cancer Doctor Suggested I Order a Vagina Egg
# Health
# ---------------
# The Inherent Bias of Facial Recognition
# Tech by VICE
# ---------------
# The Realistic Driving of iRacing Could Be a Future eSports Sensation
# Games
# ---------------
# ‘People’s Republic of Desire’ Shows the Dark Side of Livestreaming for a Living In China
# Tech by VICE
# ---------------
# A Roundtable of Hackers Dissects 'Mr. Robot' Season 3 Episode 4: 'Metadata'
# Tech by VICE
# ---------------
# A Weird Canadian Tax Incentive Could Get Space Mining Off the Ground
# Tech by VICE
# ---------------
# Who Gets Credit When a Meme Becomes a Movie?
# Tech by VICE
# ---------------
# Hung Out in Any Good Cemeteries Lately?
# Games
# ---------------
# A Look at the Science of Cuffing Season
# Health
# ---------------
# BuzzFeed CEO Says Ivanka Trump Told Him She'd Like to See a 'Mulatto Cock'
# Tech by VICE
# ---------------
# 'Freak' Orange Snow Sweeps Through Eastern Europe
# Tech by VICE
# ---------------
# The Last Pinball Doctors
# Tech by VICE
# ---------------
# Everything You Need to Know About Prosthetic Testicles
# Health
# ---------------
# We Talked to the Former Sumo Wrestler Who Joined the Oregon Militia Occupation
# Tech by VICE
# ---------------
# What It’s Like to Lose Your Husband in Your 30s
# Health
# ---------------
# Buy Low, Sell High In the Meme Economy With ‘MemeBroker’
# Tech by VICE
# ---------------
# The Forgotten History of 'The Oregon Trail,' As Told By Its Creators
# Tech by VICE
# ---------------
# Crowdfunded Healthcare is Saving Lives in the World's Poorest Countries
# Health
# ---------------
# My Spinal Injury Just Means I Can Stop Worrying About Leg Day
# Health
# ---------------
# Trump to America: This Hurricane Is Wet 'from the Standpoint of Water'
# Tech by VICE
# ---------------
# Bored Guy Busted for Cooking Meth Just to See if He Remembered How
# Tech by VICE
# ---------------
# Women Talk About How the Pill Has Completely Fucked Them Over
# Health
# ---------------
# Get to Know the Astrology Genius Behind All Your Broadly Horoscopes
# astrology
# ---------------
# The Creepy, Insane, and Undeniably Romantic World of Cryonics
# Health
# ---------------
# Beyond the Hype: This Is the Tech We Expect to Lay Hands on in 2016
# Tech by VICE
# ---------------
# No One Gives a Shit About Your Dry January
# Health
# ---------------
# Five Things Porn Tricks Us Into Thinking Everyone Does
# Health
# ---------------
# We Asked People How They Deal With Summer Depression
# Health
# ---------------
# Canned Food, Doomsday Fears, and the Y2K Hoarding Disaster That Didn't Happen
# Tech by VICE
# ---------------
# What It's Like to be Held in a Psych Ward Against Your Will
# Health
# ---------------
# The Only Good Future of Commuting Is No More Commuting
# Tech by VICE
# ---------------
# The Trans Community Isn’t Sure What to Do Under President Trump
# Tech by VICE
# ---------------
# Scientists Are Documenting All the Crap In Our Showerheads
# Health
# ---------------
# I Am The Boss Of All Velociraptor Princesses
# Games
# ---------------
# This Guy Matched with Over 1,000 Women on Tinder by Pretending to Be a Bagel
# Tech by VICE
# ---------------
# Being Hormonal Is Actually A Good Thing
# Health
# ---------------
# Curry agrees to lunar lab visit: NASA
# Science News
# ---------------
# Neil deGrasse Tyson and James Gunn Argue: What's "Good," Video Games?
# Games
# ---------------
# The Boring Truths I’ve Learned About Losing Weight and Keeping It Off
# Health
# ---------------
# Uncovering The Truth Behind The Swedish Fish Theory
# Tech by VICE
# ---------------
# Want to Make More Money? Get Better at Memorizing Basic Facts
# Tech by VICE
# ---------------
# What It's Like to Have an Illegal Abortion
# Health
# ---------------
# Why Does My High Last Longer Than My Friends'?
# Health
# ---------------
# 'They Think They Have a PhD in Whoreology:' How Lobbying for Sex Worker Rights Helps Educate Us All
# Tech by VICE
# ---------------
# Why This Guy Uploaded 134 Gigabytes of Syrian Civil War Footage
# Tech by VICE
# ---------------
# The DIY Music Tech Enthusiast Who Builds Custom Guitar Pedals
#
# Tech by VICE
# ---------------
# We Asked the Canadian Who Caught All the Pokémon If He’ll Ever Feel Joy Again
# Tech by VICE
# ---------------
# How to Tell If That Online Fundraiser Will Actually Help Immigrant Children at the Border
# Tech by VICE
# ---------------
# How Yoshinori Ono Brought Street Fighter Back from the Dead
# Games
# ---------------
# Here Are the 5 Finalists of the The Offensive: A DIY Zine-Making Competition
# Tech by VICE
# ---------------
# A Title Card vs Six Teraflops: How Metroid Stole Microsoft’s Thunder
# Games
# ---------------
# This Is What Happens When You Boil an iPhone 7
# Tech by VICE
# ---------------
# Letters: Bowie Love, Headline Hate, and the Continued Vagina Emoji Debate
# Tech by VICE
# ---------------
# Creators Are Concerned About Patreon’s Service Fee Change
# Tech by VICE
# ---------------
# How to Get Yourself to Exercise if You're Depressed
# Health
# ---------------
# Toronto Black Lives Matter Protesters Control Info with Social Media, Encryption
# Tech by VICE
# ---------------
# The Hell of Owning an iPhone 6 Plus With 'Touch Disease'
# Tech by VICE
# ---------------
# A Teen Went Viral for Befriending Deer, and You May Believe What Happened Next
# Tech by VICE
# ---------------
# This Trump FCC Transition Official Just Made a Great Accidental Argument for Net Neutrality
# Tech by VICE
# ---------------
# How Hackers Are Helping Dating Site Users Find True Love
# Tech by VICE
# ---------------
# You Need a Will Even if You're Young and Healthy
# Health
# ---------------
# There's a 'Rick and Morty' Porn Parody Called 'Dick and Morty' and I'm Sorry
# Tech by VICE
# ---------------
# Canada’s Police Allowed Journalists to ‘Embed’ to Argue For More Surveillance
# Tech by VICE
# ---------------
# I Asked an Expert if Thanos Is Right
# Tech by VICE
# ---------------
# A Sex Educator Is Finally Getting People Talking About Depression and Sex
# Health
# ---------------
# How Security Experts Are Adapting to the Ever-Present Threat of Mass Shootings
# Tech by VICE
# ---------------
# Tourists Are Flocking to Iceland to See the Glaciers Before They’re Gone
# Tech by VICE
# ---------------
# We Talked to the Scientists Turning Roadkill into Medicine
# Health
# ---------------
# We Asked People Who Bought Brand-New Apple Products Whether They Made Them Happy
# Tech by VICE
# ---------------
# Watch: Terminally Ill Serbians Are Risking Jail Time to Get Medicinal Cannabis Oil
# Health
# ---------------
# What It’s Like to Develop VR Games When You’re Legally Blind
# Games
# ---------------
# The US Is Finally Taking Aim at the Slave-Caught Seafood Industry
# Tech by VICE
# ---------------
# I Tried to Cure My 'Lesbian Tendencies' with Fake Medicine Derived from Fetal Tissue
# Health
# ---------------
# People Are Using 'No Man’s Sky' to Memorialize Lost Relatives
# Games
# ---------------
# This GIF Artist Imagines What Edo Japan Would Look Like If People Had Computers
# Tech by VICE
# ---------------
# Here’s What Making Cell Phone Calls in North Korea Sounds Like
# Tech by VICE
# ---------------
# The Beekeeper Who Makes Synth Music With His Bee Colonies
#
# Tech by VICE
# ---------------
# Beware the Microsecond
# Tech by VICE
# ---------------
# Someone Invented a Butt Wiping Machine, But at What Cost?
# Tech by VICE
# ---------------
# I Died, Met God, and Came Back as a Roots Healer
# Health
# ---------------
# This Is How Physical Abusers Manipulate Their Targets
# Health
# ---------------
# We Asked Scientists Whether He Who Smelt it Really Dealt It
# Health
# ---------------
# Meditation Can Make You Better at Sports, Psychologists Say
# Health
# ---------------
# David Kanaga’s Dog Opera, ‘Oikospiel’, Is Delirious Protest Art
# Games
# ---------------
# Why Throwing Raves in Forbidden Spaces is An Act of Political Resistance
# Tech by VICE
# ---------------
# It's So Good When Games Fix Weird Things, Like Michael Jordan's Bad Tongue
# Games
# ---------------
# There Are No Tricks to Losing 125 Pounds
# Health
# ---------------
# ASCII Pr0n Predates the Internet But it’s Still Everywhere
# Tech by VICE
# ---------------
# Ex-NSA Spy Shows Us How To Hack a Car
# Tech by VICE
# ---------------
# The Complete, Untold History of Halo
# Games
# ---------------
# How Dick Size Matters to Men's Health
# Tech by VICE
# ---------------
# What Animals Will Trend in 2016?
# Tech by VICE
# ---------------
# Margot Bowman Changing How We Express Ourselves When We Use Technology
# Tech by VICE
# ---------------
# How I Learned to Deal with My Bitcoin FOMO
# Tech by VICE
# ---------------
# Dear Conference Organizers: You’re Doing Chairs Wrong
# Tech by VICE
# ---------------
# How a Developer Released Their First Game, Despite Being Homeless
# Games
# ---------------
# Oculus Miffed
# Tech by VICE
# ---------------
# Twitter chief Jack Dorsey helps UK refugee entrepreneurs take payments
# Technology News
# ---------------
# Edward Snowden: Assange’s Arrest and the Mueller Report Show a ‘Two-Tiered System of Justice’
# Tech by VICE
# ---------------
# Pee Is So Much Crazier Than We Ever Realized
# Health
# ---------------
# People Are Slinging Overpriced Ethereum Rigs on Craigslist
# Tech by VICE
# ---------------
# The Entrepreneur Trying to Democratize Law with a Free Chatbot
#
# Tech by VICE
# ---------------
# I Was Suicidal and Addicted to Drugs Before I Found Yoga
# Health
# ---------------
# We Asked Couples Why They Chose Not to Have Kids
# Health
# ---------------
# Cod Can't Pick Up Foreign Fish Because They Have Regional Accents
# Tech by VICE
# ---------------
# A Progamer's Stunning QuakeCon Comeback After 12 Years in Retirement
# Games
# ---------------
# This Guy Served His Friends Tacos Made from His Own Amputated Leg
# Health
# ---------------
# Doctors Don’t Always Believe You When You’re a Black Woman
# Health
# ---------------
# 'I'm Going to Burn Them to the Ground': Hackers Explain Why They Hit the Stalkerware Market
# Tech by VICE
# ---------------
# Keeping Doctors Trapped in the US Is Bad for Everyone
# Health
# ---------------
# If You Hate Public Speaking, Learn to Fake Confidence
# Health
# ---------------
# 'Deadpool 2' and the Science Behind Being Lucky
# Tech by VICE
# ---------------
# What Happened When I Pushed Myself to Interview More Women
# Tech by VICE
# ---------------
# YTMND’s Owner Says the Site’s Database Was Accidentally Deleted
# Tech by VICE
# ---------------
# What It's Like to Be Young and Extremely Lonely in a Big City
# Health
# ---------------
# Norway Is Ultra-Restrictive on Buying Booze, and People Like It
# Health
# ---------------
# The Woman Who Makes Prosthetic Pinkies for Ex-Yakuza Members
# Tech by VICE
# ---------------
# Where Mr. Porter Went Wrong in '13 Reasons Why'
# Health
# ---------------
# Does Your Favorite Snack Make You Better at Games?
# Games
# ---------------
# Richard Stallman Braved a Winter Storm Last Night to March Against DRM
# Tech by VICE
# ---------------
# Digital Assistants Get Women's Names—Unless They're 'Lawyers'
# Tech by VICE
# ---------------
# Elon Musk Wants to Die in an Ultra-Democratic Society on Mars, Apparently
# Tech by VICE
# ---------------
# A Man Who Grew Up Playing Sim City is Now Building His Own Town
# Games
# ---------------
# We Asked People What It's Like to Live With Deadly Food Allergies
# Health
# ---------------
# 'Quick, Draw' is a Computer Judging Your Bad Pig Pictures
# Games
# ---------------
# Goodbye Rosetta, the Comet Orbiter Sacrificing Itself for Science
# Tech by VICE
# ---------------
# Letters to the Editor: Warcraft, Skipping Showers, and Pilot Week
# Tech by VICE
# ---------------
# The Divide Between People Who Hate and Love Artificial Intelligence Is Not Real
# Tech by VICE
# ---------------
# I Used AIM for the Last Month to See if It's Still Good
# Tech by VICE
# ---------------
# Why You're Better at Beer Pong After a Few Drinks
# Health
# ---------------
# Do Periods Really Stop in the Water?
# Health
# ---------------
# Eagerly We Await the Coming of the Sex Robots
# Tech by VICE
# ---------------
# An Astronaut Describes What It's Like to Come Back to Earth from Space
# Tech by VICE
# ---------------
# The Regrettable Rise of Sext-Shaming
# Tech by VICE
# ---------------
# How One Website Plans to Help NYC's Homeless Better Navigate the City's Shelters
# Tech by VICE
# ---------------
# How Gross Is Going Barefoot in a Locker Room Shower?
# Health
# ---------------
# Sony Is Finally Adding PlayStation 4 External Hard Drive Support
# Games
# ---------------
# Your City’s Cheapest Housing Is Also Most At Risk
# Tech by VICE
# ---------------
# The World Needs This Frog Friendship Sim from the Makers of ‘Neko Atsume’
# Games
# ---------------
# Meet the Man Helping Patients Bring Cheap HIV-Preventing Drugs to Canada
# Health
# ---------------
# Finally, Someone Asked Americans if We Actually Want Lab-Grown Meat
# Health
# ---------------
# What It's Like to Be a Professional Drug Hunter
# Health
# ---------------
# Crow Attacks Have Gotten So Bad That a Scientist Built a Tool to Map the Carnage
# Tech by VICE
# ---------------
# Dating With Depression Sucks
# Health
# ---------------
# What It's Like to Have an Irrational Fear of Thunderstorms
# Health
# ---------------
# I Got Married For Health Insurance
# Health
# ---------------
# Is Snapchat Making Us Forget What We Look Like?
# Social Media
# ---------------
# What Can I Do to Better Cope With Anxiety at Work?
# Health
# ---------------
# The ‘Stardew Valley’ Modder Who Added Jerk Off Schedules For Every Guy
# Games
# ---------------
# Research Confirms Dating Apps Are a Sad Game
# Tech by VICE
# ---------------
# Want to Own an Emoji? Come to This South Korean Pop-Up
# Tech by VICE
# ---------------
# One Man's Quest to Sell 1,000 Raccoon Penis Bones
# Tech by VICE
# ---------------
# I Tried Skype’s New 50-Person Video Calling Feature, My Personal Hell
# Tech by VICE
# ---------------
# My Corgi Winston Briefly Tasted the Sweet Nectar of Online Fame
# Tech by VICE
# ---------------
# Women Lawyers Are Being Driven to Drink
# Health
# ---------------
# What It's Like to Live with Epilepsy
# Health
# ---------------
# 80s Logo Generator Guy Just Wanted to Bring Joy to This Sick, Sad World
# Tech by VICE
# ---------------
# What I Learned From Revisiting My Three Worst Breakups
# Health
# ---------------
# Team USA's First Trans Athlete on the Future of Equality in Sports
# Health
# ---------------
# The Dirtiest Place in an Airport Is Not in the Bathroom
# Tech by VICE
# ---------------
# Relax, the Meltdown and Spectre CPU Patches Aren't Messing With Your Frame Rates
# Tech by VICE
# ---------------
# Steve Wozniak Says He Got Ripped Off By a Bitcoin Scammer
# Tech by VICE
# ---------------
# What Does a Former NASA Employee Think of 'No Man's Sky'?
# Games
# ---------------
# There’s No Need to Wash Your Turkey, and It Could Make You Sick If You Do
# Tech by VICE
# ---------------
# I Skipped Showering for Two Weeks and Bathed in Bacteria Instead
# Tech by VICE
# ---------------
# The Inmate I Took Under My Wing Didn't Survive Prison
# Health
# ---------------
# This Is What it Takes to Change Bad Luck
# Health
# ---------------
# Invite Us Over This Thanksgiving Weekend
# Games
# ---------------
# 'PC Building Simulator' Takes the Intimidation Out of Your First Build
# Tech by VICE
# ---------------
# 8-Ball Loves Community, Hates Capitalism
# Tech by VICE
# ---------------
# Chipotle Is Trying to Buy Your Friendship with Free Food Deals
# Health
# ---------------
# The Real Industry Behind Fake Electronics
# Tech by VICE
# ---------------
# An Open Letter to My Parents, Who Didn't Handle My Addiction Well
# Health
# ---------------
# We Talked to a Trans Teen Surviving the Shitshow that Is North Carolina
# Health
# ---------------
# Even IBM's Watson Is Getting Into 'Pokémon Go'
# Tech by VICE
# ---------------
# War As Easy As Typing: Alex Gibney Spills the Secrets of 'Zero Days'
# Tech by VICE
# ---------------
# Everything You Need to Survive the Big One
# Tech by VICE
# ---------------
# The Secret Shame of Steam Cheaters That Lasts Seven Years
# Games
# ---------------
# We Asked Women's March Protesters What Got Them Offline and on the Streets
# Tech by VICE
# ---------------
# How to Have a Baby When You're Young and Broke
# Health
# ---------------
# Fuck You And Die: An Oral History of Something Awful
# Tech by VICE
# ---------------
# What Game Should I Play on My Way to PAX East?
# Games
# ---------------
# So, What Happened to 'Routine,' That Promising Space Horror Game From 2013?
# Games
# ---------------
# Portrait of an Amazonian
# Tech by VICE
# ---------------
# The Tonic Guide to Vices in 2017
# Health
# ---------------
# Why Are Women Drinking More Than We Used To?
# Health
# ---------------
# The New Generation of Millennial Matchmakers Wants to Help Your Tinder Game
# Tech by VICE
# ---------------
# Teachers and Parents Share Stories From Inside the 'Fortnite' Phenomenon
# Games
# ---------------
# These Games Look Cool, I Sure Wish They Weren't in VR
# Games
# ---------------
# This Dating App Helps People Find Love Based on Their Mutual Hatred of Things
# Tech by VICE
# ---------------
# The Human Lifespan Has a Natural Limit. Scientists Might Know How to Break It
# Tech by VICE
# ---------------
# Think Stock Photos of Hackers Are Cheesy? Blame This Guy
# Tech by VICE
# ---------------
# A Bitcoin ‘Big Bang Theory’ Episode Is Coming, God Has Abandoned Us
# Tech by VICE
# ---------------
# Hotspot Vigilantes Are Trying to Beam the Internet to Julian Assange
# Tech by VICE
# ---------------
# Actionable Intelligence
# Tech by VICE
# ---------------
# What Are the Medical Benefits of Psychedelics?
# Health
# ---------------
# When Being Treated for Cancer Could Get You Deported
# Health
# ---------------
# The Making of Indie Puzzle Game ‘Hue,' Part II
# Games
# ---------------
# Take a Sunday Stroll Through Our Forums
# Games
# ---------------
# These Canadians Are Building the First Commercial Electric Snowmobile
# Tech by VICE
# ---------------
# The 'Badass Army' is Training Revenge Porn Victims to Fight Back
# Tech by VICE
# ---------------
# Harper Reed, Obama's Former CTO, Says Data Isn't Everything
# Tech by VICE
# ---------------
# Fridge Cam! BedPhones! Here's a First Look at the Gadgets and Trends at CES 2016
# Tech by VICE
# ---------------
# The TSA Spent $1.4 Million on an App That Tells You to Go Right or Left
# Tech by VICE
# ---------------
# Fat-Positive Activists Explain What It's Really Like to Be Fat
# Health
# ---------------
# Dreamers Are Not Safe Online
# Tech by VICE
# ---------------
# My Competitive Side Helped Me Get Sober and Lose 125 Pounds
# Health
# ---------------
# Kanye West Has Literally the Worst iPhone Passcode You Could Ever Have
# Tech by VICE
# ---------------
# The New Twitter @-Replies Are Giving Me an Ulcer
# Tech by VICE
# ---------------
# We Talked to a Professional Cuck About the 'Alt-Right'
# Tech by VICE
# ---------------
# A Redditor Archived Nearly 2 Million Gigabytes of Porn to Test Amazon’s ‘Unlimited’ Cloud Storage
# Tech by VICE
# ---------------
# Other People’s Money: The Murky World of Crowdfunded Poker
# Tech by VICE
# ---------------
# Intel Bets $16.7 Billion on the Massively Parallel Future of Computing
# Tech by VICE
# ---------------
# Nintendo's Reggie Fils-Aimé on Accessibility, What's Next, and, Uh, Waluigi
# Games
# ---------------
# Watch a Rubik's Cube World Record Holder Explain His Craft
# Tech by VICE
# ---------------
# 'Overwatch' Pro Player Fired for Saying the N-Word 60 Times
# Tech by VICE
# ---------------
# People Are Making the FCC Host 'Rick and Morty' GIFs
# Tech by VICE
# ---------------
# Election Anxiety Got You Down? This App Helps You Fall in Love with a Canadian
# Tech by VICE
# ---------------
# Facebook and Twitter Bring You Live Coverage of the Presidential Debates
# Tech by VICE
# ---------------
# Herpes: Symptoms, Treatments, and Facts
# Health
# ---------------
# The Forgotten Prisoner of a Spyware Deal Gone Wrong
# Tech by VICE
# ---------------
# This New Gaming Handheld Has a Crank (!!) And Looks Cool as Hell
# Games
# ---------------
# What to Expect From Donald Trump's Reddit AMA
# Tech by VICE
# ---------------
# The CIA’s Guide to Taking Pictures of UFOs
# Tech by VICE
# ---------------
# A History of SmarterChild
# Tech by VICE
# ---------------
# Exactly How Dangerous Is It to Drop a Baby?
# Health
# ---------------
# Life Can Be a Wes Anderson Film If You Look Close Enough
# Tech by VICE
# ---------------
# Richie Hawtin Made a New Mixer So We Asked Him a Bunch of Nerdy Questions
# Tech by VICE
# ---------------
# Is Relationship Anarchy the Future of Polyamory?
# Tech by VICE
# ---------------
# What It Feels Like to Give Your Partner Herpes
# Health
# ---------------
# We Can Now Stop Hallucinations in Parkinson's
# Health
# ---------------
# The Economy Needs to Be More Human: A Chat With Douglas Rushkoff
# Tech by VICE
# ---------------
# Why Are Investors Cold on Nintendo’s New Console?
# Tech by VICE
# ---------------
# What It Was Like to Grow Up Fat
# Health
# ---------------
# The Story Behind Reviving Obscure Neo Geo Classic 'Windjammers'
# Games
# ---------------
# The Women Pioneers of the Internet Say There Have Always Been Trolls
# Tech by VICE
# ---------------
# The Interruption
# Tech by VICE
# ---------------
# Episode 5: I Look Like Sad Cancer Lady
# Health
# ---------------
# How The Team Behind 'The Surge' Developed Their Disabled Protagonist
# Games
# ---------------
# I Froze My Face to Escape Wrinkles
# Health
# ---------------
# This Independence Day, Free Yourself from Trump
# Health
# ---------------
# I Didn't Want to Know if I Had the Condition That Killed My Brother
# Health
# ---------------
# The Video Game for Every Black Woman Who's Had a Stranger Grab Her Hair
# Games
# ---------------
# Why It Feels Like You Can Communicate with Nature on LSD
# Tech by VICE
# ---------------
# Using a Friend's Netflix Password Could Land You in Prison
# Tech by VICE
# ---------------
# Cancer, February 2017
# Cancer
# ---------------
# A Roundtable of Hackers Dissects 'Mr. Robot' Season 3 Episode 5: 'Runtime Error'
# Tech by VICE
# ---------------
# DIY Venues Need Better OpSec: A Guide
# Tech by VICE
# ---------------
# Today a Guy Carrying a Sack of Sloth Teeth Sat Next to Me
# Tech by VICE
# ---------------
# New Jersey Says Releasing Dolphin's Autopsy Would Infringe Its Privacy [Updated]
# Tech by VICE
# ---------------
# A Congressional Debate Was Hacked to Show Gay Porn
# Tech by VICE
# ---------------
# Vancouver's Pilot Program is More than a Victory for the City's Right to Party
# Tech by VICE
# ---------------
# The Bizarre Untold Origin Story of the Myers-Briggs Personality Indicator
# Health
# ---------------
# Your Eye Twitches Can Be Explained by Science, Sort Of
# Health
# ---------------
# Meet the Republican Mayor Fighting for Renewable Energy in Louisiana
# Tech by VICE
# ---------------
# The Owner of FuckFascism.com Is Leasing the Domain to Fund His Startup
# Tech by VICE
# ---------------
# Why Smartphones Are Now Adding Iris Scanners
# Tech by VICE
# ---------------
# A New Era of Assistive Technologies for People with Disabilities
# Tech by VICE
# ---------------
# We Asked What It's Like to Have a Mental Illness in Prison
# Health
# ---------------
# The Millennial Burnout Conversation Also Applies to Gamers
# Games
# ---------------
# A Canadian Government Ad Campaign Told Everyone They 'Need the D'
# Health
# ---------------
# Americans Could Eat Every American in Less Than Two Decades
# Tech by VICE
# ---------------
# Tips On Surviving the American Election, From Your Friends Who Survived Brexit
# Tech by VICE
# ---------------
# The Future Is Having Your Funeral Livestreamed
# Tech by VICE
# ---------------
# The Most Common Reasons People Need Medical Attention at Music Festivals
# Health
# ---------------
# This Is The Best Kind of Disguise To Conceal Your Identity
# Health
# ---------------
# Trump says rejected killing people to retaliate for Iran drone strike
# Energy
# ---------------
# Don’t Only Give Blood After a Tragedy
#
# Health
# ---------------
# Who You Should Hook Up with This Cuffing Season, According to Astrology
# astrology
# ---------------
# Darker Than Wax's Valentine's Day Mix Serves Up Soul From Singapore to New York
# Tech by VICE
# ---------------
# I Tried to Watch a Video of a Puppy and Accidentally Sent Every Photo I’ve Ever Taken to Google
# Tech by VICE
# ---------------
# The 15-Year-Old Modder Who Gave Kids Nightmarish Horns in ‘The Sims 4’
# Games
# ---------------
# This 17-Year-Old Has Become Michigan's Leading Right to Repair Advocate
# Tech by VICE
# ---------------
# A Most Elegant Solution
# Tech by VICE
# ---------------
# Nintendo Is Still Dreaming of a Sleep-Focused 'Quality of Life' Device
# Tech by VICE
# ---------------
# Once Upon a Time, This Tech Company Actively Recruited Furries
# Tech by VICE
# ---------------
# A Woman I Met in World of Warcraft Helped Me Lose 100 Pounds
# Health
# ---------------
# We Asked People How Drug Use Affected Their Relationships
# Health
# ---------------
# Most College Students Keep at Least 5 Dating Prospects on the Back Burner
# Health
# ---------------
# Dating While Black: The Privacy Risks and Rewards of Niche Dating Apps
# Tech by VICE
# ---------------
# We Asked Some Psychologists to Explain the Science Behind Your Crippling FOMO
# Tech by VICE
# ---------------
# Whitehouse.com, Your Favorite 90s Porn Site, Is Now Protesting the Trump Presidency
# Tech by VICE
# ---------------
# It's a Dog's Life
# Tech by VICE
# ---------------
# Some People Are Irrationally Attached to Their Running Shoes
# Health
# ---------------
# Mass Shootings Attract Conspiracy Theories Because the Reality Is Too Bleak to Accept
# Tech by VICE
# ---------------
# What Life for a Bangladeshi Click Farmer Looks Like
# Tech by VICE
# ---------------
# I Asked a Scientist to Explain What the Hell My Cat Wants From Me
# Tech by VICE
# ---------------
# How Your Low-Key Cocaine Habit Actually Affects Your Body
# Health
# ---------------
# Robot Story II
# Tech by VICE
# ---------------
# Are Microbiome Diagnostic Tests Worth It?
# Health
# ---------------
# When Should I Stop Drinking to Avoid a Hangover?
# Health
# ---------------
# Pipe Dreams: A Conversation with the Engineers at the Hyperloop Competition
# Tech by VICE
# ---------------
# Now You Can Build Your Own Private Mesh Network With Phones and Radios
# Tech by VICE
# ---------------
# ‘Accessible’ Fashion Lines Have a Disability Problem
# Tech by VICE
# ---------------
# Inside Twitter’s Command Center, Where the Threat Model Is Boy Band Tweets
# Tech by VICE
# ---------------
# Here's What's Coming in the New Season of CYBERWAR
# Tech by VICE
# ---------------
# The Science of How Your Taste Buds Mature
# Health
# ---------------
# This New Card Game Pits Cthulhu Against Donald Trump
# Games
# ---------------
# How a Major JRPG Wound Up Getting Totally Re-Written Months After Release
# Games
# ---------------
# Why The First Wave of Chat Bots Are a Bit of a Mess
# Tech by VICE
# ---------------
# We Asked Smokers if They Would Pay $33 for a Pack of Cigarettes
# Health
# ---------------
# Mallory Ortberg's Internet
# Tech by VICE
# ---------------
# Women, Let This Email Plugin Teach You to Be Confident Like A Man
# Tech by VICE
# ---------------
# Meet the Terrified Player Who Discovered Aliens in 'Elite: Dangerous'
# Games
# ---------------
# THQ Nordic Held Q&A on a Website Banned for Suspected Child Pornography
# Games
# ---------------
# I Appreciate Games the Most After I Take a Break From Them
# Games
# ---------------
# Own One-Sixth of a Porsche With This Blockchain Luxury Company
# Tech by VICE
# ---------------
# AT&T Says It’s Invented ‘Transformative, Multi-Gigabit’ Broadband Mesh Nets
# Tech by VICE
# ---------------
# The 'Persona 5' Ban Shows Video Game Streamers Have Volatile Jobs
# Tech by VICE
# ---------------
# Kellyanne Conway Recommends Eating Ice Cream and French Fries Instead of Buying Fentanyl
# Health
# ---------------
# New Chatbots Will Help People Accept Death
# Tech by VICE
# ---------------
# This Is How Living in a City Affects Your Immune System
# Health
# ---------------
# The 'Robots Replacing Foxconn Workers' Story Is Less Sexy Than You Think
# Tech by VICE
# ---------------
# Episode 7: The Day I Said Goodbye to My Right Breast
# Health
# ---------------
# Man Fined $500 for Crime of Writing 'I Am An Engineer' in an Email to the Government
# Tech by VICE
# ---------------

# %%
''' These functions, as the names suggest, are for cleaning queries and predicting LDA topics on short user-input data. 
The output from the topic_predict function is the name of the primary topic, followed by the name(s) of any secondary
topic(s)'''

def clean_query(query):
    '''Tokenize, remove special characters, lemmatize '''
    tokenized = regexp_tokenize(query,pattern)
    indiv_words = [word for word in tokenized if word.isalpha()]
    lemmatized = func_lemmatize(indiv_words)
    words = [word.lower() for word in lemmatized if word not in stop]

    return words


def topic_predict(query):  
    tokenized_input = clean_query(query)
    
    corpus = id2word.doc2bow(tokenized_input)
    
    np.random.seed(4)
    output = list(lda_model[corpus])
    
    ordered = sorted(output,key=lambda x:x[1],reverse=True)
    
    # Determine primary topic
    primary_topic = ordered[0][0]
    # Set threshold for any secondary topics, as explained in greater detail in lda_compute function
    threshold = 0.5
    
    # Identify secondary topics, if any
    secondary_topics = [pair[0] for pair in ordered[1:] if pair[1] / ordered[0][1] > threshold]
    
    # Name the primary topic by reference to the topics_dict
    print(f'primary topic: {topics_dict[primary_topic]}')
    # Name any secondary topics if there are any
    if secondary_topics:
        print('-' * 10, '\n', 'other topics:')
        for topic in secondary_topics:
            print(topics_dict[topic])

# %%
p = 'hello how are you?'
#p = 'The 20-year US military presence in Afghanistan is over. The head of US Central Command, Gen Kenneth McKenzie, announced that the last flight out of Kabul “is now clearing the airspace above Afghanistan”.'
#p = 'Western powers have been forced to accept the reality of the Taliban’s control of Afghanistan as they swung behind a watered down UN resolution that says it “expects” the Taliban to honour a commitment to allow Afghans to leave the country and “requests” that Kabul airport be securely reopened, but falls short of demanding a UN-sponsored safe zone in the Afghan capital.'
#p = 'British troops and international allies could return to Kabul airport to help police a UN safe zone in the capital in order to allow safe passage for people trying to leave Afghanistan.'
#p = "If you're looking to drop your quarantine 15, lower your stress level, sleep better, or boost your immunity amid the pandemic, we've tested plenty of smart health and fitness products and apps to help you meet your goals."
#p = "Nervous about going to the gym amid the COVID-19 pandemic, or just too lazy to get your butt out of bed and travel there in the morning?"
#p = 'Gaining insight into your sleeping patterns is the first step toward identifying problems and fixing them. When you’re evaluating wearable options, look for a device with continuous heart rate monitoring and an SpO2 (or Pulse Ox) sensor that tracks your blood oxygen saturation levels as you sleep.'
#p = 'I’m not going to pretend that I know how to interpret the jobs and inflation data of the past few months. My view is that this is still an economy warped by the pandemic, and that the dynamics are so strange and so unstable that it will be some time before we know its true state. But the reaction to the early numbers and anecdotes has revealed something deeper and more constant in our politics.'

#p = 'The Defense Department’s space agency on Aug. 30 released a request for proposals from satellite manufacturers that would compete for contracts to build as many as 144 satellites. The satellites will make up the Space Development Agency’s Transport Layer Tranche 1 — a mesh network of communications satellites in low Earth orbit projected to start launching in late 2024.'
#p = "There are details from the R. Kelly trial intended to startle us: The accusation that the singer believed he had gotten then 15-year-old singer Aaliyah pregnant and arranged to marry her so she couldn't testify against him. The accusation that he knowingly spread herpes to several of his young victims. The accusation that one of the victims, then 16, was slapped and choked until she passed out because she texted a friend. \
#But sexual assault experts say some revelations should not be surprising: that Black girls were brutally victimized, that many individuals around Kelly were complicit and that it's taken more than two decades for much of the public to care." 
#158

#p = 'are you suffering from some mental illness?'
p = 'are robots going to take over the world?' 
#video games 2
p = 'what percentage of people in latin america have access to smartphones?'
p = 'Up to 2 million people in and around New Orleans were without power after Hurricane Ida, a 150mph monster storm that was the most powerful ever to hit Louisiana. At least one person was killed, by a falling tree, but the governor, John Bel Edwards, warned that the death toll will probably rise'
p = 'Igot chatting to an American consultant a few days ago who mentioned that her boyfriend was soon arriving in London from New York. “So I’m taking some PTO next week,” she said. PTO? Was this some kind of new sexual slang I didn’t know about? Best to ask and make sure. “Oh, no, no,” she explained, “it’s, like, paid time off.” I think I might have preferred it to be something more alarming and athletic. “Like a holiday?” I asked. The American nodded.'
#61
p = 'International donors including the World Bank and European Union froze funding to Afghanistan shortly afterwards. “One of the great risks for the health system here is basically to collapse because of lack of support,” said Filipe Ribeiro, Afghanistan representative for Doctors Without Borders (Medecins Sans Frontieres, or MSF), one of the largest medical aid agencies in the country.'
p = '‘Our hospital right now is at capacity’ Lee Health CEO calls for more vaccinations, unity\
On Sunday, Lee Health admitted 92 COVID-19 positive patients to its hospitals, the most in a single day throughout the pandemic. \
Lee Health CEO Larry Antonucci said, “That 92 is just chilling to me,” during a news conference Monday at Golisano Children’s Hospital.'
p = "In an effort to understand how the internal state of the body influences the brain's decision-making processes, scientists analyzed the data from a previous study pre-clinical study. They found that two of the brain's decision-making centers contain neurons that may exclusively monitor the body's internal dynamics. Furthermore, a heightened state of arousal appeared to rewire one of the centers by turning some decision-making neurons into internal state monitors."
p = 'The breast milk of lactating mothers vaccinated against COVID-19 contains a significant supply of antibodies that may help protect nursing infants from the illness, according to new research from the University of Florida. "Our findings show that vaccination results in a significant increase in antibodies against SARS-CoV-2 -- the virus that causes COVID-19 -- in breast milk, suggesting that vaccinated mothers can pass on this immunity to their babies, something we are working to confirm in our ongoing research," said Joseph Larkin III, Ph.D., senior author of the study and an associate professor in the UF/IFAS department of microbiology and cell science."'
p = 'what is the future of ai going to be?'
p = "Scientists at Cambridge and Leeds have successfully reversed age-related memory loss in mice and say their discovery could lead to the development of treatments to prevent memory loss in people as they age. In a study published today in Molecular Psychiatry, the team show that changes in the extracellular matrix of the brain -- 'scaffolding' around nerve cells -- lead to loss of memory with ageing, but that it is possible to reverse these using genetic treatments."
p = "People taking certain drugs to lower blood sugar for type 2 diabetes had less amyloid in the brain, a biomarker of Alzheimer's disease, when compared to both people with type 2 diabetes not taking the drugs and people without diabetes. The new study also found people taking these drugs, called dipeptidyl peptidase-4 inhibitors, showed slower cognitive decline than people in the other two groups."
p = "If you are forgetful or make mistakes when in a hurry, a new study from Michigan State University -- the largest of its kind to-date -- found that meditation could help you to become less error prone. The research, published in Brain Sciences, tested how open monitoring meditation -- or, meditation that focuses awareness on feelings, thoughts or sensations as they unfold in one's mind and body -- altered brain activity in a way that suggests increased error recognition."
p = 'i suffer from various sports injuries, since i used to play soccer'
p = 'Sending human travelers to Mars would require scientists and engineers to overcome a range of technological and safety obstacles. One of them is the grave risk posed by particle radiation from the sun, distant stars and galaxies.'
p = "Your smart device could soon be even smarter with a new infrared light emitting diode (LED) that is 'tuneable' to different wavelengths of light -- it could enable your fridge to tell you when your food is going off and your phone to tell you if that Gucci purse is real. The technology has been developed by the University of Melbourne, the Lawrence Berkeley National Laboratory, the University of California, Berkeley, and the Australian Research Council Centre of Excellence for Transformative Meta-Optical Systems (TMOS). They have come up with a device that could identify a suite of gases, potentially including lethal ones, improving the safety of firefighters, miners, the military, and your local plumber. The work appeared in the journal, Nature."



topic_predict(p)
# Out:
# primary topic: artificial intelligence
# ----------
#  other topics:
# ???
# education & student life
# astronomy & astrophysics

# %% [markdown]
# ### Word2vec Alternative to LDA
# Several different versions of LDA were tried as an alternative to the LDA approach. Most of the iterations were attempts to make it run faster. For this, a portion of the article was used (specifically the title plus a short 'intro', typically 30 words. Attempts to cluster the resulting vectors did not produce good results; we later found that it would have been worth creating vectors only for the most commonly occurring words, rather than for each and every word. This may well have produced better
# clustering results, and significantly reduced processing time. Due to time constraints, this avenue was left unexplored.

# %%
def create_w2v(col1,col2,max_epochs,vec_size,window,min_count,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    # Create a list of words for each article
    word_list = [[words for words in line] for line in col1]
    # unpack it to create a flat list of all words in the corpus
    unpacked_word_list = [word for line in word_list for word in line]
    
    filename = 'model.sav'
    
    # Either train a new model, or open a saved model and load pre-calculated vectors 
    # depending on whether resume=True or False
    if resume == False:
        model = Word2Vec(col1,vector_size=vec_size,window=window,min_count=min_count,workers=-1)
        model.train(col1,total_examples=len(col1),epochs=max_epochs)
        print('word2vec model has been trained.')
        pickle.dump(model,open(filename,'wb'))
    else:
        file = open(filename,'rb')
        model = pickle.load(file)
        
    averaged_vectors = [] if resume == False else pd.read_csv('intermediate_results.csv',index_col=0)
    
    if resume == True:
        averaged_vectors = [list(averaged_vectors.loc[val,:]) for val in averaged_vectors.index]
    
    j = start_index= len(averaged_vectors)
    # Report on percentage completion before starting
    if j != 0:
        print(f'{round(j/len(col1),3) * 100}% complete.')
    start_checkpoint_time = time.time()
    
    progress_indicators = []
    
    print('Now to create vectors...')
    for row in range(j,len(col1)):
        list_of_words = col1[row]
        list_of_vectors = [model.wv[word] for word in list_of_words if unpacked_word_list.count(word) >= min_count]
        # Compute an average vector of all vectors in the document
        avg_vector = np.mean(list_of_vectors,axis=0) if list_of_vectors else np.zeros(vec_size)
        averaged_vectors.append(avg_vector)
        
        j += 1
        
        # Every j records, we save the results so far
        if j % 10000000 == 0:
            intermediate_results = pd.DataFrame(averaged_vectors)
            intermediate_results.to_csv('intermediate_results.csv')
            
        percent_complete = round(j/len(col1) * 100)
        if (percent_complete % 10 == 0) & (percent_complete not in progress_indicators):
            cum_time_raw = (time.time() - start_time)/60
            cum_time = round((time.time() - start_time)/60,1)
            print('{}% complete. Time elapsed: {} min'.format(percent_complete,cum_time))
            progress_indicators.append(percent_complete)
            
            remaining_time = cum_time_raw * (len(col1) - j) / (j - start_index)
            
            est_finish_time = datetime.now() + timedelta(minutes=remaining_time)
            est_finish_time = est_finish_time.strftime('%D:%H:%M:%S')
            print(f'Estimated finish time: {est_finish_time}')
            print('-' * 15)
    
    # Create df of averaged vectors and append the col of titles to create final output df
    df_of_vectors = pd.DataFrame(averaged_vectors)
        
    intermediate_table = pd.concat([col2,df_of_vectors],axis=1)
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return model, final_table, removed_comments

# %%
df_clean_test = df[:10000]

# %%
df_clean_test.shape
# Out:
# (10000, 15)

# %%
model, final_table, removed_comments = create_w2v(df_clean_test['article_words'],df_clean_test['title'],12,32,5,6)
# Out:
# started at 15:40:24
# word2vec model has been trained.
# Now to create vectors...
# 0% complete. Time elapsed: 0.0 min
# Estimated finish time: 09/01/21:15:48:28
# ---------------
# 10% complete. Time elapsed: 0.6 min
# Estimated finish time: 09/01/21:15:46:58
# ---------------
# 20% complete. Time elapsed: 1.3 min
# Estimated finish time: 09/01/21:15:47:10
# ---------------
# 30% complete. Time elapsed: 2.0 min
# Estimated finish time: 09/01/21:15:47:11
# ---------------
# 40% complete. Time elapsed: 2.7 min
# Estimated finish time: 09/01/21:15:47:13
# ---------------
# 50% complete. Time elapsed: 3.4 min
# Estimated finish time: 09/01/21:15:47:15
# ---------------
# 60% complete. Time elapsed: 4.0 min
# Estimated finish time: 09/01/21:15:47:11
# ---------------
# 70% complete. Time elapsed: 4.7 min
# Estimated finish time: 09/01/21:15:47:08
# ---------------
# 80% complete. Time elapsed: 5.3 min
# Estimated finish time: 09/01/21:15:47:06
# ---------------
# 90% complete. Time elapsed: 6.1 min
# Estimated finish time: 09/01/21:15:47:12
# ---------------
# 100% complete. Time elapsed: 6.9 min
# Estimated finish time: 09/01/21:15:47:18
# ---------------
# -------------------------
# Finished. That took 6.9 min.
# Actual finish time: 15:47:18

# %%
file = open('model.sav','rb')
model = pickle.load(file)

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
# Out:
# [=============================================-----] 90.9% 1511.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=================================================-] 99.9% 1661.9/1662.8MB downloaded

# %%
filename = 'wv.pkl'
pickle.dump(wv,open(filename,'wb'))

# %%
final_table
# Out:
#                                                  title         0         1  \
# 0    Blood-Drinking White Nationalist Augustus Sol ... -0.000605 -0.006243
# 1    7'6" Tacko Fall Hilariously Crushing NBA All-S... -0.001506 -0.004733
# 2    Diddy and Future Ride Jet Skis in Miami, No Ba... -0.001536 -0.005365
# 3       Teresa Giudice Says Joe Made Her Sign a Prenup -0.003308 -0.004476
# 4    Deshaun Watson Parties For Smokin' Hot Model G... -0.000638 -0.005164
# ..                                                 ...       ...       ...
# 995  Thousands of protesters march in Hong Kong, ta... -0.001606 -0.003971
# 996  GRAINS-U.S. wheat, soybeans maintain trade aro... -0.001754 -0.003692
# 997  Indonesia's top court bars plantation activity... -0.000900 -0.006288
# 998  Louisville pounds Mississippi State in Music C...  0.000169 -0.007635
# 999  Catalan separatists ERC reaffirm abstention in... -0.001203 -0.004510
#
#             2         3         4         5         6         7         8  \
# 0    0.004921  0.008215 -0.003610 -0.009190  0.012097  0.007827 -0.007459
# 1    0.006476  0.009223 -0.004918 -0.007279  0.012278  0.008090 -0.004250
# 2    0.006279  0.010038 -0.006711 -0.006252  0.011247  0.009217 -0.004643
# 3    0.005751  0.010023 -0.005718 -0.007607  0.011692  0.008058 -0.004116
# 4    0.006295  0.008395 -0.004369 -0.005744  0.011664  0.008124 -0.003841
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.005529  0.010431 -0.006318 -0.007483  0.014894  0.005884 -0.004427
# 996  0.006071  0.008879 -0.004978 -0.007814  0.012594  0.007965 -0.003782
# 997  0.007222  0.008562 -0.006824 -0.005623  0.011263  0.006428 -0.004865
# 998  0.004418  0.010149 -0.003550 -0.006456  0.010407  0.008568 -0.004324
# 999  0.006401  0.006251 -0.003727 -0.006503  0.011510  0.007187 -0.002997
#
#      ...        22        23        24        25        26        27  \
# 0    ...  0.013707 -0.007273  0.004699 -0.001444 -0.003752  0.006744
# 1    ...  0.013761 -0.006336  0.005625 -0.001943 -0.002035  0.007474
# 2    ...  0.013012 -0.005645  0.005994 -0.002998 -0.002464  0.004610
# 3    ...  0.013897 -0.006695  0.007948 -0.002395 -0.000758  0.004718
# 4    ...  0.012784 -0.004430  0.006240 -0.003484 -0.001750  0.005462
# ..   ...       ...       ...       ...       ...       ...       ...
# 995  ...  0.012890 -0.005857  0.006109 -0.005710 -0.000500  0.004571
# 996  ...  0.014035 -0.006440  0.005894 -0.004394 -0.002331  0.006427
# 997  ...  0.012968 -0.006415  0.005289 -0.000614 -0.001714  0.003032
# 998  ...  0.013198 -0.004455  0.006592 -0.001808 -0.001230  0.003866
# 999  ...  0.013876 -0.006935  0.004736 -0.001730 -0.001181  0.004271
#
#            28        29        30        31
# 0   -0.005175 -0.007744 -0.007225 -0.003199
# 1   -0.002311 -0.003758 -0.005967  0.000006
# 2   -0.003649 -0.007745 -0.005570 -0.002505
# 3   -0.001802 -0.004820 -0.005878 -0.001522
# 4   -0.001104 -0.005720 -0.006495  0.000040
# ..        ...       ...       ...       ...
# 995 -0.001157 -0.005949 -0.006397 -0.001053
# 996 -0.001155 -0.004889 -0.007471 -0.000932
# 997 -0.003538 -0.007346 -0.007920 -0.003392
# 998 -0.003047 -0.006924 -0.007418 -0.001899
# 999 -0.000384 -0.005861 -0.008117 -0.000821
#
# [1000 rows x 33 columns]

# %% [markdown]
# ### W2V Other Versions

# %%
######EXPERIMENTAL VERSION!!!!!!!!!!!!!
def create_w2vexp(col1,col2,max_epochs,vec_size,window,min_count,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    word_list = [[words for words in line] for line in col1]
    unpacked_word_list = [word for line in word_list for word in line]
    
    filename = 'model.sav'
    
    if resume == False:
        model = Word2Vec(col1,vector_size=vec_size,window=window,min_count=min_count,workers=3)
        model.train(col1,total_examples=len(col1),epochs=max_epochs)
        print('word2vec model has been trained.')
        pickle.dump(model,open(filename,'wb'))
    else:
        file = open(filename,'rb')
        model = pickle.load(file)
        
    averaged_vectors = [] if resume == False else pd.read_csv('intermediate_results.csv',index_col=0)
    
    if resume == True:
        averaged_vectors = [list(averaged_vectors.loc[val,:]) for val in averaged_vectors.index]
    
    j = start_index= len(averaged_vectors)
    # Report on percentage completion before starting
    if j != 0:
        print(f'{round(j/len(col1),3) * 100}% complete.')
    start_checkpoint_time = time.time()
    
    progress_indicators = []
    
    print('Now to create vectors...'

    
    averaged_vectors = [np.mean([model.wv[word] for word in list_of_words if unpacked_word_list.count(word) >= min_count],axis=0) for list_of_words in col1] 
    
    
    
    
    print('vectors created!')
            
    df_of_vectors = pd.DataFrame(averaged_vectors)
    print(f'df_of_vectors.shape:{df_of_vectors.shape}')
        
    intermediate_table = pd.concat([col2,df_of_vectors],axis=1)
    print(f'intermediate_table.shape:{intermediate_table.shape}')
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return final_table, removed_comments

# %%
######EXPERIMENTAL VERSION!!!!!!!!!!!!!
def create_w2vexp2(col1,col2,max_epochs,vec_size,window,min_count,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    word_list = [[words for words in line] for line in col1]
    unpacked_word_list = [word for line in word_list for word in line]
    
    filename = 'model.sav'
    
    if resume == False:
        model = Word2Vec(col1,vector_size=vec_size,window=window,min_count=min_count,workers=-1)
        model.train(col1,total_examples=len(col1),epochs=max_epochs)
        print('word2vec model has been trained.')
        pickle.dump(model,open(filename,'wb'))
    else:
        file = open(filename,'rb')
        model = pickle.load(file)
        
    averaged_vectors = [] if resume == False else pd.read_csv('intermediate_results.csv',index_col=0)
    
    if resume == True:
        averaged_vectors = [list(averaged_vectors.loc[val,:]) for val in averaged_vectors.index]
    
    j = start_index= len(averaged_vectors)
    # Report on percentage completion before starting
    if j != 0:
        print(f'{round(j/len(col1),3) * 100}% complete.')
    start_checkpoint_time = time.time()
    
    progress_indicators = []
    
    vectors_dict = {}
 
    for row in range(j,len(col1)):
        list_of_words = [word for word in col1[row] if unpacked_word_list.count(word) >= min_count]
        list_of_vectors = [vectors_dict[word] if word in vectors_dict.keys() else model.wv[word] for word in list_of_words]
        
        vectors_dict.update({word:vector for word,vector in zip(list_of_words,list_of_vectors)})
        
        avg_vector = np.mean(list_of_vectors,axis=0) if list_of_vectors else np.zeros(vec_size)
               
        
        averaged_vectors.append(avg_vector)
        
        j += 1

        if j % 1000 == 0:
            intermediate_results = pd.DataFrame(averaged_vectors)
            intermediate_results.to_csv('intermediate_results.csv')
            
        percent_complete = round(j/len(col1) * 100)
        if (percent_complete % 10 == 0) & (percent_complete not in progress_indicators):
            cum_time_raw = (time.time() - start_time)/60
            cum_time = round((time.time() - start_time)/60,1)
            print('{}% complete. Time elapsed: {} min'.format(percent_complete,cum_time))
            progress_indicators.append(percent_complete)
            
            remaining_time = cum_time_raw * (len(col1) - j) / (j - start_index)
            
            est_finish_time = datetime.now() + timedelta(minutes=remaining_time)
            est_finish_time = est_finish_time.strftime('%D:%H:%M:%S')
            print(f'Estimated finish time: {est_finish_time}')
            print('-' * 15)
            
    df_of_vectors = pd.DataFrame(averaged_vectors)
    print(f'df_of_vectors.shape:{df_of_vectors.shape}')
        
    intermediate_table = pd.concat([col2,df_of_vectors],axis=1)
    print(f'intermediate_table.shape:{intermediate_table.shape}')
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return final_table, removed_comments

# %%
######EXPERIMENTAL VERSION!!!!!!!!!!!!!
def create_w2vexp3(col1,col2,max_epochs,vec_size,window,min_count,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    word_list = [[words for words in line] for line in col1]
    unpacked_word_list = [word for line in word_list for word in line]
    
    filename = 'model.sav'
    
    if resume == False:
        model = Word2Vec(col1,vector_size=vec_size,window=window,min_count=min_count,workers=-1)
        model.train(col1,total_examples=len(col1),epochs=max_epochs)
        print('word2vec model has been trained.')
        pickle.dump(model,open(filename,'wb'))
    else:
        file = open(filename,'rb')
        model = pickle.load(file)
        
    averaged_vectors = [] if resume == False else pd.read_csv('intermediate_results.csv',index_col=0)
    
    
    
    if resume == True:
        averaged_vectors = [list(averaged_vectors.loc[val,:]) for val in averaged_vectors.index]
    
    j = start_index= len(averaged_vectors)
    # Report on percentage completion before starting
    if j != 0:
        print(f'{round(j/len(col1),3) * 100}% complete.')
    start_checkpoint_time = time.time()
    
    progress_indicators = []

    for row in range(j,len(col1)):
        list_of_words = [word for word in col1[row] if unpacked_word_list.count(word) >= min_count]

        avg_vector = [model[' '.join(words)] for words in list_of_words]
               
        
        averaged_vectors.append(avg_vector)

        j += 1

        if j % 1000 == 0:
            intermediate_results = pd.DataFrame(averaged_vectors)
            intermediate_results.to_csv('intermediate_results.csv')
            
        percent_complete = round(j/len(col1) * 100)
        if (percent_complete % 10 == 0) & (percent_complete not in progress_indicators):
            cum_time_raw = (time.time() - start_time)/60
            cum_time = round((time.time() - start_time)/60,1)
            print('{}% complete. Time elapsed: {} min'.format(percent_complete,cum_time))
            progress_indicators.append(percent_complete)
            
            remaining_time = cum_time_raw * (len(col1) - j) / (j - start_index)
            
            est_finish_time = datetime.now() + timedelta(minutes=remaining_time)
            est_finish_time = est_finish_time.strftime('%D:%H:%M:%S')
            print(f'Estimated finish time: {est_finish_time}')
            print('-' * 15)
            
    df_of_vectors = pd.DataFrame(averaged_vectors)
    print(f'df_of_vectors.shape:{df_of_vectors.shape}')
        
    intermediate_table = pd.concat([col2,df_of_vectors],axis=1)
    print(f'intermediate_table.shape:{intermediate_table.shape}')
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return final_table, removed_comments

# %%
final_table_orig, removed_comments = create_w2v(df_clean_test['article_words'],df_clean_test['title'],12,32,5,6)
# Out:
# started at 14:56:08
# word2vec model has been trained.
# Now to create vectors...
# 0% complete. Time elapsed: 0.0 min
# Estimated finish time: 09/01/21:15:05:23
# ---------------
# 10% complete. Time elapsed: 0.7 min
# Estimated finish time: 09/01/21:15:03:00
# ---------------
# 20% complete. Time elapsed: 1.4 min
# Estimated finish time: 09/01/21:15:03:10
# ---------------
# 30% complete. Time elapsed: 2.1 min
# Estimated finish time: 09/01/21:15:03:11
# ---------------
# 40% complete. Time elapsed: 2.8 min
# Estimated finish time: 09/01/21:15:03:12
# ---------------
# 50% complete. Time elapsed: 3.5 min
# Estimated finish time: 09/01/21:15:03:15
# ---------------
# 60% complete. Time elapsed: 4.2 min
# Estimated finish time: 09/01/21:15:03:11
# ---------------
# 70% complete. Time elapsed: 4.9 min
# Estimated finish time: 09/01/21:15:03:09
# ---------------
# 80% complete. Time elapsed: 5.6 min
# Estimated finish time: 09/01/21:15:03:07
# ---------------
# 90% complete. Time elapsed: 6.3 min
# Estimated finish time: 09/01/21:15:03:10
# ---------------
# 100% complete. Time elapsed: 7.1 min
# Estimated finish time: 09/01/21:15:03:15
# ---------------
# -------------------------
# Finished. That took 7.1 min.
# Actual finish time: 15:03:15

# %%
final_table, removed_comments = create_w2vexp2(df_clean_test['article_words'],df_clean_test['title'],12,32,5,6)
# Out:
# started at 13:29:51
# word2vec model has been trained.
# 0% complete. Time elapsed: 0.0 min
# Estimated finish time: 09/01/21:13:38:57
# ---------------
# 10% complete. Time elapsed: 0.7 min
# Estimated finish time: 09/01/21:13:37:12
# ---------------
# 20% complete. Time elapsed: 1.5 min
# Estimated finish time: 09/01/21:13:37:41
# ---------------
# 30% complete. Time elapsed: 2.3 min
# Estimated finish time: 09/01/21:13:37:49
# ---------------
# 40% complete. Time elapsed: 3.3 min
# Estimated finish time: 09/01/21:13:38:18
# ---------------
# 50% complete. Time elapsed: 4.2 min
# Estimated finish time: 09/01/21:13:38:23
# ---------------
# 60% complete. Time elapsed: 5.1 min
# Estimated finish time: 09/01/21:13:38:26
# ---------------
# 70% complete. Time elapsed: 5.8 min
# Estimated finish time: 09/01/21:13:38:15
# ---------------
# 80% complete. Time elapsed: 6.6 min
# Estimated finish time: 09/01/21:13:38:06
# ---------------
# 90% complete. Time elapsed: 7.3 min
# Estimated finish time: 09/01/21:13:38:03
# ---------------
# 100% complete. Time elapsed: 8.2 min
# Estimated finish time: 09/01/21:13:38:04
# ---------------
# df_of_vectors.shape:(1000, 32)
# intermediate_table.shape:(1000, 33)
# -------------------------
# Finished. That took 8.2 min.
# Actual finish time: 13:38:04

# %%
######EXPERIMENTAL VERSION!!!!!!!!!!!!!
def create_w2vexp4(col1,col2,min_count,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    word_list = [[words for words in line] for line in col1]
    unpacked_word_list = [word for line in word_list for word in line]
    
    filename = 'model.sav'
    
    averaged_vectors = [] if resume == False else pd.read_csv('intermediate_results.csv',index_col=0)
    
    if resume == True:
        averaged_vectors = [list(averaged_vectors.loc[val,:]) for val in averaged_vectors.index]
    
    j = start_index = len(averaged_vectors)
    # Report on percentage completion before starting
    if j != 0:
        print(f'{round(j/len(col1),3) * 100}% complete.')
    start_checkpoint_time = time.time()
    
    progress_indicators = []
    
    print('Now to create vectors...')
        
    filename = 'wv.pkl'
    file = open(filename,'rb')
    wv = pickle.load(file)
    
    
    for row in range(j,len(col1)):

        list_of_words = [word for word in list_of_words if (unpacked_word_list.count(word) >= min_count) & \
                                                                   (word in wv.key_to_index)]
        avg_vector = wv[list_of_words]
        
        averaged_vectors.append(avg_vector)
        
        j += 1
        print(f'{j} done')
        if j % 10000000 == 0:
            intermediate_results = pd.DataFrame(averaged_vectors)
            intermediate_results.to_csv('intermediate_results.csv')
            
        percent_complete = round(j/len(col1) * 100)
        if (percent_complete % 10 == 0) & (percent_complete not in progress_indicators):
            cum_time_raw = (time.time() - start_time)/60
            cum_time = round((time.time() - start_time)/60,1)
            print('{}% complete. Time elapsed: {} min'.format(percent_complete,cum_time))
            progress_indicators.append(percent_complete)
            
            remaining_time = cum_time_raw * (len(col1) - j) / (j - start_index)
            
            est_finish_time = datetime.now() + timedelta(minutes=remaining_time)
            est_finish_time = est_finish_time.strftime('%D:%H:%M:%S')
            print(f'Estimated finish time: {est_finish_time}')
            print('-' * 15)
            
    df_of_vectors = pd.DataFrame(averaged_vectors)
        
    intermediate_table = pd.concat([col2,df_of_vectors],axis=1)
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return model, final_table, removed_comments

# %%
final_table_new, removed_comments = create_w2vexp4(df_clean_test['article_words'],df_clean_test['title'],6)

# %%
######EXPERIMENTAL VERSION!!!!!!!!!!!!!
def create_w2vexp5(col1,col2,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    word_list = [[words for words in line] for line in col1]
    unpacked_word_list = [word for line in word_list for word in line]
    
#    filename = 'model.sav'
    
    filename = 'wv.pkl'
    file = open(filename,'rb')
    wv = pickle.load(file)
    
    print('Now to create vectors...')
    
    averaged_vectors = [[wv[word] for word in list_of_words if word in wv.key_to_index] for list_of_words in col1] 
    
    
    
    
    print('vectors created!')
 
    df_of_vectors = pd.DataFrame(averaged_vectors)
    print(f'df_of_vectors.shape:{df_of_vectors.shape}')
    
    return df_of_vectors
        
    intermediate_table = pd.concat([col2,df_of_vectors],axis=1)
    print(f'intermediate_table.shape:{intermediate_table.shape}')
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return final_table, removed_comments

# %%
df_of_vectors = create_w2vexp5(df_clean_test['article_words'],df_clean_test['title'])
# Out:
# started at 17:52:09
# Now to create vectors...
# vectors created!
# df_of_vectors.shape:(1000, 223)

# %%
######EXPERIMENTAL VERSION!!!!!!!!!!!!!
def create_w2vexp6(col1,col2,max_epochs,vec_size,window,min_count,resume=False):
    now  = datetime.now()
    start_time_str = now.strftime('%H:%M:%S')
    print('started at',start_time_str)
        
    start_time = time.time()
    word_list = [[words for words in line] for line in col1]
    unpacked_word_list = [word for line in word_list for word in line]

    filename = 'model.sav'

    if resume == False:
        model = Word2Vec(col1,vector_size=vec_size,window=window,min_count=min_count,workers=3)
        model.train(col1,total_examples=len(col1),epochs=max_epochs)
        print('word2vec model has been trained.')
        pickle.dump(model,open(filename,'wb'))
    else:
        file = open(filename,'rb')
        model = pickle.load(file)
        
    print('Now to create vectors...')
    
    averaged_vectors = [np.mean([model.wv[word] for word in list_of_words if word in model.wv.key_to_index],axis=0) for list_of_words in col1]
    
    filename = 'models/intermediate_pickle.pkl'
    pickle.dump(averaged_vectors,open(filename,'wb'))
    
    
    print('vectors created!')

    df_of_vectors = pd.DataFrame(averaged_vectors)
    print(f'df_of_vectors.shape:{df_of_vectors.shape}')
    
    df_of_vectors.to_csv('df_of_vectors.csv')

    df_of_vectors['title'] = col2
    intermediate_table = df_of_vectors.copy()
    
    
    print(f'intermediate_table.shape:{intermediate_table.shape}')
        
    rows_to_remove = [ind for ind in intermediate_table.index if intermediate_table.iloc[ind,2] == 0]
        
    removed_comments = pd.DataFrame(col2[rows_to_remove])
    final_table = intermediate_table.drop(rows_to_remove,axis=0)
        
    interval = round((time.time() - start_time)/60,1)
    print('-' * 25)
    print(f'Finished. That took {interval} min.')
    now = datetime.now()
    end_time_str = now.strftime('%H:%M:%S')
    print(f'Actual finish time: {end_time_str}')
        
    return final_table, removed_comments

# %%
# Est finish time: 10:30pm
final_table,removed_comments = create_w2vexp6(df_clean_summ['article_words'],df_clean_summ['title'],20,256,5,6)
# Out:
# started at 12:36:51
# word2vec model has been trained.
# Now to create vectors...
# vectors created!

# %% [markdown]
# ## Try LDA on Summaries

# %%
df_clean_summ = pd.read_csv('df_clean_summ.csv')

# %%
inds = np.random.choice(df_clean_summ.index,1000000,replace=False)
df_clean_summ = df_clean_summ.loc[inds,:]
df_clean_summ.reset_index(drop=True,inplace=True)

# %%
df_clean_summ.shape
# Out:
# (1000000, 13)

# %%
df_clean_summ['article_words'] = [eval(words) for words in df_clean_summ['article_words']]
df_clean_summ.head(1)
# Out:
#    Unnamed: 0        date  year  month  day  \
# 0     1239833  2016-03-08  2016    3.0    8
#
#                                 author  \
# 0  Bozorgmehr Sharafedin, Doina Chiacu
#
#                                                title  \
# 0  Iran fires ballistic missiles, U.S. hints at d...
#
#                                                  url     section publication  \
# 0  http://www.reuters.com/article/iran-missiles-i...  World News     Reuters
#
#                                                intro  \
# 0  DUBAI/WASHINGTON (Reuters) - Iran’s Islamic Re...
#
#                                          title_intro  \
# 0  Iran fires ballistic missiles, U.S. hints at d...
#
#                                        article_words
# 0  [iran, fire, ballistic, missile, u, hint, dipl...

# %%
#22:58
df_clean_summ, lda_model, corpus = lda_compute(df_clean_summ,num_topics=265,passes=14)
# Out:
# The time is 2021-09-04 22:58:10.800612
# Now for LDA modeling...

# %% [markdown]
# ## Try LDA on 500k (full) Records

# %%
df_9 = pd.read_csv('df9_clean.csv')
df_10 = pd.read_csv('df10_clean.csv')

# %%
dfs = [df_9,df_10]
df_9_10 = pd.DataFrame()
for df in dfs:
    df_9_10 = df_9_10.append(df)
df_9_10.reset_index(drop=True,inplace=True)
df_9_10['article_words'] = [eval(words) for words in df_9_10['article_words']]

# %%
df_9_10.shape
# Out:
# (584165, 14)

# %%
df_test = df_9_10.loc[:,['title','article_words']]
df_test.info(memory_usage='deep',verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584165 entries, 0 to 584164
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   title          584165 non-null  object
#  1   article_words  584165 non-null  object
# dtypes: object(2)
# memory usage: 1.7 GB

# %%
# 1000 records, 4.0 MB, 5 passes: 1.4 mins
# 10,000 records, 37.9 MB, 5 passes: 10.59 mins
# All 584k records, 1.7 GB, 5 passes: ...     mins. Est runtime: 618 mins. Est finish time: 00:48
df_test, lda_model, corpus = lda_compute(df_test,num_topics=265,passes=5)
# Out:
# The time is 2021-09-05 14:29:40.032143
# Now for LDA modeling...
# LDA done!
# ----------
# lda_lists[-1]: [(18, 0.040069945), (38, 0.04205921), (58, 0.033842996), (62, 0.22275679), (65, 0.04956388), (70, 0.047659423), (124, 0.12391218), (132, 0.016120192), (133, 0.036833566), (145, 0.16715892), (149, 0.010586675), (227, 0.029774087), (234, 0.020300869), (261, 0.06283979), (263, 0.0126904175)]
# lda_coeffs[-1]: [0.040069945, 0.04205921, 0.033842996, 0.22275679, 0.04956388, 0.047659423, 0.12391218, 0.016120192, 0.036833566, 0.16715892, 0.010586675, 0.029774087, 0.020300869, 0.06283979, 0.0126904175]
# lda_inds[-1]: [18, 38, 58, 62, 65, 70, 124, 132, 133, 145, 149, 227, 234, 261, 263]
# lda_argmax[-1]: 3
# That  took 1092.74 mins.

# %%
df_test.to_csv('models/5passes_df_test.csv')

# %%
lda_model.save('models/5passes_265_topics_ldamodel')

# %%
id2word = corpora.Dictionary(df_test['article_words'])
filename = 'models/5passes_id2word_265.pkl'
pickle.dump(id2word,open(filename,'wb'))
